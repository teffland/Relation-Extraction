# %%
from __future__ import print_function
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import re
import collections
import random
from time import time

from gensim.models import Word2Vec
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA, FastICA

import data_handler as dh
import semeval_data_helper as sdh
# plot settings
% matplotlib inline
# print(plt.rcParams.keys())
plt.rcParams['figure.figsize'] = (16,9)

# %%
# reload(sdh)

# %%
# print(DH.max_seq_len)
# paths, targets = DH.readable_data(show_dep=True)
# for p, t in zip(paths, targets) :
#     t = t.split(", ")
#     print("%s (%s) %s" % (t[0], p, t[1]))
# print('<X>' in DH.vocab)

# %%
class RelEmbed(object):
    """ Encapsulation of the dependency RNN lang model
    
    Largely inspired by https://github.com/tensorflow/tensorflow/blob/master/tensorflow/models/rnn/ptb/ptb_word_lm.py
    """
    def __init__(self, config):
#         self.batch_size = config['batch_size']
        self.max_num_steps = config['max_num_steps']
        self.word_embed_size = config['word_embed_size']
        self.dep_embed_size = config['dep_embed_size']
        self.input_size = self.word_embed_size + self.dep_embed_size
        self.hidden_size = 2 * self.word_embed_size #config['hidden_size']
        self.pretrained_word_embeddings = config['pretrained_word_embeddings'] # None if we don't provide them
        if np.any(self.pretrained_word_embeddings):
            assert self.word_embed_size == self.pretrained_word_embeddings.shape[1]
        self.num_classes = config['num_predict_classes']
        self.max_grad_norm = config['max_grad_norm']
        
        self.vocab_size = config['vocab_size']
        self.dep_vocab_size = config['dep_vocab_size']
        self.name = config['model_name']
        self.checkpoint_prefix = config['checkpoint_prefix'] + self.name
        self.summary_prefix = config['summary_prefix'] + self.name
        
        self.initializer = tf.random_uniform_initializer(-1., 1.)
        with tf.name_scope(self.name):
            with tf.name_scope("Forward"):
                self._build_forward_graph()
                self._build_classification_graph()
            with tf.name_scope("Backward"):
                self._build_train_graph()
                self._build_class_train_graph()
            with tf.name_scope("Nearby"):
                self._build_similarity_graph()
        
        self._valid_accuracy = tf.Variable(0.0, trainable=False)
        self._valid_acc_summary = tf.merge_summary([tf.scalar_summary("Valid_accuracy", self._valid_accuracy)])

        self.saver = tf.train.Saver(tf.all_variables())
            
        self.session = tf.InteractiveSession()
        self.session.run(tf.initialize_all_variables())        
        self.summary_writer = tf.train.SummaryWriter(self.summary_prefix, self.session.graph_def)
        
    def save_validation_accuracy(self, new_score):
        assign_op = self._valid_accuracy.assign(new_score)
        _, summary = self.session.run([assign_op, self._valid_acc_summary])
        self.summary_writer.add_summary(summary)
        
    def _build_forward_graph(self):
        # input tensor of zero padded indices to get to max_num_steps
        # None allows for variable batch sizes
        with tf.name_scope("Inputs"):
            self._input_phrases = tf.placeholder(tf.int32, [None, self.max_num_steps, 2]) # [batch_size, w_{1:N}, 2]
            self._input_targets = tf.placeholder(tf.int32, [None, 2]) # [batch_size, w_x]
            self._input_labels = tf.placeholder(tf.int32, [None, 1]) # [batch_size, from true data?] \in {0,1}
            self._input_lengths = tf.placeholder(tf.int32, [None, 1]) # [batch_size, N] (len of each sequence)
            batch_size = tf.shape(self._input_lengths)[0]
        
        with tf.name_scope("Embeddings"):
            if np.any(self.pretrained_word_embeddings):
                self._word_embeddings = tf.Variable(self.pretrained_word_embeddings,name="word_embeddings")
                self._left_target_embeddings = tf.Variable(self.pretrained_word_embeddings, name="left_target_embeddings")
                self._right_target_embeddings = tf.Variable(self.pretrained_word_embeddings, name="right_target_embeddings")
            else:
                self._word_embeddings = tf.get_variable("word_embeddings", 
                                                        [self.vocab_size, self.word_embed_size],
                                                        dtype=tf.float32)
                self._left_target_embeddings = tf.get_variable("left_target_embeddings", 
                                                        [self.vocab_size, self.word_embed_size],
                                                        dtype=tf.float32)
                self._right_target_embeddings = tf.get_variable("right_target_embeddings", 
                                                        [self.vocab_size, self.word_embed_size],
                                                        dtype=tf.float32)
            
            self._dependency_embeddings = tf.get_variable("dependency_embeddings", 
                                                    [self.dep_vocab_size, self.dep_embed_size],
                                                    dtype=tf.float32)
            # TODO: Add POS embeddings
            
            input_embeds = tf.nn.embedding_lookup(self._word_embeddings, 
                                                  tf.slice(self._input_phrases, [0,0,0], [-1, -1, 1]))
            dep_embeds = tf.nn.embedding_lookup(self._dependency_embeddings,
                                                tf.slice(self._input_phrases, [0,0,1], [-1, -1, 1]))
            left_target_embeds = tf.nn.embedding_lookup(self._left_target_embeddings, 
                                                        tf.slice(self._input_targets, [0,0], [-1, 1]))
            right_target_embeds = tf.nn.embedding_lookup(self._right_target_embeddings, 
                                                        tf.slice(self._input_targets, [0,1], [-1, 1]))
#             print(tf.slice(self._input_phrases, [0,0,1], [-1, -1, 1]).get_shape(), dep_embeds.get_shape())
#             print(left_target_embeds.get_shape(), right_target_embeds.get_shape())
            self._target_embeds = tf.squeeze(tf.concat(2, [left_target_embeds, right_target_embeds]), [1])
#             print(target_embeds.get_shape())
            # TODO: Add dropout to embeddings
        
        with tf.name_scope("RNN"):
            # start off with a basic configuration
            self.cell = tf.nn.rnn_cell.GRUCell(self.hidden_size, 
                                                input_size=self.input_size)
            # TODO: Add Dropout wrapper
            # TODO: Make it multilevel
#             self._initial_state = self.cell.zero_state(batch_size, tf.float32)
#             print(self._initial_state.get_shape())
            input_words = [ tf.squeeze(input_, [1, 2]) for input_ in tf.split(1, self.max_num_steps, input_embeds)]
            input_deps = [ tf.squeeze(input_, [1, 2]) for input_ in tf.split(1, self.max_num_steps, dep_embeds)]
            inputs = [ tf.concat(1, [input_word, input_dep]) 
                      for (input_word, input_dep) in zip(input_words, input_deps)]

            _, state = tf.nn.rnn(self.cell, inputs, 
                                 sequence_length=tf.squeeze(self._input_lengths, [1]),
                                 dtype=tf.float32)
#                                  initial_state=self._initial_state)
            self._final_state = state
            
        with tf.name_scope("Loss"):
            flat_states = tf.reshape(state, [-1])
            flat_target_embeds = tf.reshape(self._target_embeds, [-1])
#             assert self.hidden_size == (self.word_embed_size), "Hidden state must equal concated inputs" 
            flat_logits = tf.mul(flat_states, flat_target_embeds)
            logits = tf.reduce_sum(tf.reshape(flat_logits, tf.pack([batch_size, -1])), 1)
            self._loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits, 
                                                                    tf.to_float(self._input_labels)),
                                        name="neg_sample_loss")
            
        with tf.name_scope("Summaries"):
            
            self._train_cost_summary = tf.merge_summary([tf.scalar_summary("Train_NEG_Loss", self._loss)])
            self._valid_cost_summary = tf.merge_summary([tf.scalar_summary("Validation_NEG_Loss", self._loss)])
        
    def _build_classification_graph(self):
        with tf.name_scope("Classifier"):
            self._softmax_input = tf.concat(1, [self._final_state, self._target_embeds], name="concat_input")
            self._softmax_w = tf.get_variable("softmax_w", [self._softmax_input.get_shape()[1], self.num_classes])
            self._softmax_b = tf.Variable(tf.zeros([self.num_classes], dtype=tf.float32), name="softmax_b")

            class_logits = tf.matmul(self._softmax_input, self._softmax_w) + self._softmax_b
            self._predictions = tf.argmax(class_logits, 1, name="predict")
            self._predict_probs = tf.nn.softmax(class_logits, name="predict_probabilities")
        
        with tf.name_scope("Loss"):
            self._class_labels = tf.placeholder(tf.int64, [None, 1])
            self._class_loss = tf.nn.sparse_softmax_cross_entropy_with_logits(class_logits, 
                                                                              tf.squeeze(self._class_labels, [1]))
            self._avg_class_loss = tf.reduce_mean(self._class_loss)
            self._train_class_loss_summary = tf.merge_summary([tf.scalar_summary("Train_Avg_Class_Xent", self._avg_class_loss)])
            self._valid_class_loss_summary = tf.merge_summary([tf.scalar_summary("Valid_Avg_Class_Xent", self._avg_class_loss)])

    def _build_train_graph(self):
        with tf.name_scope("Unsupervised_Trainer"):
            self._global_step = tf.Variable(0, name="global_step", trainable=False)
#             self._lr = tf.Variable(1.0, trainable=False)
            self._optimizer = tf.train.AdagradOptimizer(1.0)
            
            # clip and apply gradients
            grads_and_vars = self._optimizer.compute_gradients(self._loss)
#             for gv in grads_and_vars:
#                 print(gv, gv[1] is self._cost)
            clipped_grads_and_vars = [(tf.clip_by_norm(gv[0], self.max_grad_norm), gv[1]) 
                                      for gv in grads_and_vars if gv[0] is not None] # clip_by_norm doesn't like None
            
            with tf.name_scope("Summaries"):
                grad_summaries = []
                for g, v in grads_and_vars:
                    if g is not None:
                        grad_hist_summary = tf.histogram_summary("{}/grad/hist".format(v.name), g)
                        sparsity_summary = tf.scalar_summary("{}/grad/sparsity".format(v.name), tf.nn.zero_fraction(g))
                        grad_summaries.append(grad_hist_summary)
                        grad_summaries.append(sparsity_summary)
                self._grad_summaries = tf.merge_summary(grad_summaries)
            self._train_op = self._optimizer.apply_gradients(clipped_grads_and_vars, global_step=self._global_step)
            
    def _build_class_train_graph(self):
        with tf.name_scope("Classification_Trainer"):
            self._class_global_step = tf.Variable(0, name="class_global_step", trainable=False)
#             self._lr = tf.Variable(1.0, trainable=False)
            self._class_optimizer = tf.train.AdagradOptimizer(1.0)
            
            # clip and apply gradients
            grads_and_vars = self._class_optimizer.compute_gradients(self._class_loss)
#             for gv in grads_and_vars:
#                 print(gv, gv[1] is self._cost)
            clipped_grads_and_vars = [(tf.clip_by_norm(gv[0], self.max_grad_norm), gv[1]) 
                                      for gv in grads_and_vars if gv[0] is not None] # clip_by_norm doesn't like None
            
            with tf.name_scope("Summaries"):
                grad_summaries = []
                for g, v in grads_and_vars:
                    if g is not None:
                        grad_hist_summary = tf.histogram_summary("class_{}/grad/hist".format(v.name), g)
                        sparsity_summary = tf.scalar_summary("class_{}/grad/sparsity".format(v.name), tf.nn.zero_fraction(g))
                        grad_summaries.append(grad_hist_summary)
                        grad_summaries.append(sparsity_summary)
                self._class_grad_summaries = tf.merge_summary(grad_summaries)
            self._class_train_op = self._class_optimizer.apply_gradients(clipped_grads_and_vars, 
                                                                         global_step=self._class_global_step)
            
    def _build_similarity_graph(self):
        tf.get_variable_scope().reuse_variables()
        with tf.name_scope("Inputs"):
            # word or phrase we want similarities for
#             self._query_word = tf.placeholder(tf.int32, [1], name="q_word")
            self._query_phrase = tf.placeholder(tf.int32, [self.max_num_steps, 2], name="q_phrase")
            self._query_length = tf.placeholder(tf.int32, [1], name="q_len") # lengths for RNN
            # words and phrases to compute similarities over
#             self._sim_words = tf.placeholder(tf.int32, [None, 1])
            self._sim_phrases = tf.placeholder(tf.int32, [None, self.max_num_steps, 2])
            self._sim_lengths = tf.placeholder(tf.int32, [None, 1]) # lengths for RNN
            sim_size = tf.shape(self._sim_lengths)[0]
        
        with tf.name_scope("Embeddings"):
            query_phrase_embed = tf.nn.embedding_lookup(self._word_embeddings, 
                                                  tf.slice(self._query_phrase, [0,0], [-1, 1]))
            query_dep_embed = tf.nn.embedding_lookup(self._dependency_embeddings,
                                                tf.slice(self._query_phrase, [0,1], [-1, 1]))
#             query_word_embed = tf.nn.embedding_lookup(self._word_embeddings, self._query_word)
#             query_phrase_embed = tf.nn.embedding_lookup(self._word_embeddings, self._query_phrase)
#             sim_word_embed = tf.nn.embedding_lookup(self._word_embeddings, tf.squeeze(self._sim_words, [1]))
            sim_phrase_embed = tf.nn.embedding_lookup(self._word_embeddings, 
                                                  tf.slice(self._sim_phrases, [0, 0, 0], [-1, -1, 1]))
            sim_dep_embed = tf.nn.embedding_lookup(self._dependency_embeddings, 
                                                  tf.slice(self._sim_phrases, [0, 0, 1], [-1, -1, 1]))
        
        with tf.name_scope("RNN"):
            # compute rep of a query phrase
            query_phrase = [tf.squeeze(qw, [1]) for qw in tf.split(0, self.max_num_steps, query_phrase_embed)]
            query_dep = [tf.squeeze(qd, [1]) for qd in tf.split(0, self.max_num_steps, query_dep_embed)]
#             print(query_phrase[0].get_shape(), query_dep[0].get_shape())
            query_input = [ tf.concat(1, [qw, qd]) for (qw, qd) in zip(query_phrase, query_dep)]
            _, query_phrase_state = tf.nn.rnn(self.cell, query_input, 
                                              sequence_length=self._query_length, 
                                              dtype=tf.float32)
            # compute reps of similarity phrases
            sim_phrases = [tf.squeeze(qw, [1,2]) for qw in tf.split(1, self.max_num_steps, sim_phrase_embed)]
            sim_deps = [tf.squeeze(qd, [1,2]) for qd in tf.split(1, self.max_num_steps, sim_dep_embed)]
            sim_input = [ tf.concat(1, [qw, qd]) for (qw, qd) in zip(sim_phrases, sim_deps)]
            _, sim_phrase_states = tf.nn.rnn(self.cell, sim_input, 
                                             sequence_length=tf.squeeze(self._sim_lengths, [1]), 
                                             dtype=tf.float32)
            
        with tf.name_scope("Similarities"):
            with tf.name_scope("Normalize"):
#                 print(query_phrase.get_shape())
                query_phrase = tf.nn.l2_normalize(query_phrase_state, 1)
#                 query_word = tf.nn.l2_normalize(query_word_embed, 1)
                sim_phrases = tf.nn.l2_normalize(sim_phrase_states, 1)
#                 sim_word = tf.nn.l2_normalize(sim_word_embed, 1)                

            with tf.name_scope("Calc_distances"):
                # do for words
#                 print(q)
#                 query_word_nearby_dist = tf.matmul(query_word, sim_word, transpose_b=True)
#                 qw_nearby_val, qw_nearby_idx = tf.nn.top_k(query_word_nearby_dist, min(1000, self.vocab_size))
#                 self.qw_nearby_val = tf.squeeze(qw_nearby_val)
#                 self.qw_nearby_idx = tf.squeeze(qw_nearby_idx)
#                 self.qw_nearby_words = tf.squeeze(tf.gather(self._sim_words, qw_nearby_idx))

                # do for phrases
                query_phrase_nearby_dist = tf.matmul(query_phrase, sim_phrases, transpose_b=True)
                qp_nearby_val, qp_nearby_idx = tf.nn.top_k(query_phrase_nearby_dist, min(1000, sim_size))
#                 self.sanity_check = tf.squeeze(tf.matmul(query_phrase, query_phrase, transpose_b=True))
                self.qp_nearby_val = tf.squeeze(qp_nearby_val)
                self.qp_nearby_idx = tf.squeeze(qp_nearby_idx)
#                 self.qp_nearby_lens = tf.squeeze(tf.gather(self._sim_lengths, qp_nearby_idx))
            
    def partial_class_fit(self, input_phrases, input_targets, class_labels, input_lengths):
        """Fit a mini-batch
        
        Expects a batch_x: [self.batch_size, self.max_num_steps]
                  batch_y: the same
                  batch_seq_lens: [self.batch_size]
                  
        Returns average batch perplexity
        """
        loss, _, g_summaries, c_summary = self.session.run([self._avg_class_loss, self._class_train_op, 
                                                            self._class_grad_summaries,
                                                            self._train_class_loss_summary],
                                                           {self._input_phrases:input_phrases,
                                                            self._input_targets:input_targets,
                                                            self._class_labels:class_labels,
                                                            self._input_lengths:input_lengths})
        self.summary_writer.add_summary(g_summaries)
        self.summary_writer.add_summary(c_summary)
        return loss
    
    def partial_unsup_fit(self, input_phrases, input_targets, input_labels, input_lengths):
        """Fit a mini-batch
        
        Expects a batch_x: [self.batch_size, self.max_num_steps]
                  batch_y: the same
                  batch_seq_lens: [self.batch_size]
                  
        Returns average batch perplexity
        """
        loss, _, g_summaries, c_summary = self.session.run([self._loss, self._train_op, 
                                                            self._grad_summaries,
                                                            self._train_cost_summary],
                                                           {self._input_phrases:input_phrases,
                                                            self._input_targets:input_targets,
                                                            self._input_labels:input_labels,
                                                            self._input_lengths:input_lengths})
        self.summary_writer.add_summary(g_summaries)
        self.summary_writer.add_summary(c_summary)
        return loss
    
    def validation_loss(self, valid_phrases, valid_targets, valid_labels, valid_lengths):
        """Calculate loss on validation inputs, but don't run trainer"""
        loss, v_summary = self.session.run([self._loss, self._valid_cost_summary],
                                           {self._input_phrases:valid_phrases,
                                            self._input_targets:valid_targets,
                                            self._input_labels:valid_labels,
                                            self._input_lengths:valid_lengths})
        self.summary_writer.add_summary(v_summary)
        return loss
    
    def validation_class_loss(self, valid_phrases, valid_targets, valid_labels, valid_lengths):
        """Calculate loss on validation inputs, but don't run trainer"""
        loss, v_summary = self.session.run([self._avg_class_loss, self._valid_class_loss_summary],
                                           {self._input_phrases:valid_phrases,
                                            self._input_targets:valid_targets,
                                            self._class_labels:valid_labels,
                                            self._input_lengths:valid_lengths})
        self.summary_writer.add_summary(v_summary)
        return loss
    
    def validation_phrase_nearby(self, q_phrase, q_phrase_len, sim_phrases, sim_phrase_lens):
        """Return nearby phrases from the similarity set
        """
        nearby_vals, nearby_idx = self.session.run([self.qp_nearby_val, self.qp_nearby_idx],
                                                                   {self._query_phrase:q_phrase, 
                                                                    self._query_length:q_phrase_len,
                                                                    self._sim_phrases:sim_phrases,
                                                                    self._sim_lengths:sim_phrase_lens})
#         print("Sanity check: %r" % sanity)
        return nearby_vals, nearby_idx
    
    def embed_phrases_and_targets(self, phrases, targets, lengths):
        phrase_reps, target_reps = self.session.run([self._final_state, self._target_embeds],
                                                    { self._input_phrases:phrases,
                                                      self._input_targets:targets,
                                                      self._input_lengths:lengths})
        return phrase_reps, target_reps
    
#     def validation_word_nearby(self, q_word, sim_words):
#         """Return nearby phrases from the similarity set
#         """
#         nearby_vals, nearby_idx = self.session.run([self.qw_nearby_val, 
#                                                       self.qw_nearby_idx],
#                                                        {self._query_word:q_word, 
#                                                         self._sim_words:sim_words})
#         return nearby_vals, nearby_idx
        
    def predict(self, paths, targets, path_lens, return_probs=False):
        if return_probs:
            predictions, distributions = self.session.run([self._predictions, self._predict_probs],
                                                          {self._input_phrases:paths,
                                                           self._input_targets:targets,
                                                           self._input_lengths:path_lens})
            distributions = distributions.reshape([path_lens.shape[0], -1])
            return list(predictions), list(distributions)
#             pred_list = []
#             dist_list = []
#             for i, seq_len in enumerate(path_lens):
#                 pred_list.append(list(predictions[i, :path_len]))
#                 dist_list.append([distributions[i,j,:] for j in range(path_len)])
#             return pred_list, dist_list
        
        else:
            predictions = self.session.run(self._predictions,
                                           {self._predict_inputs:paths,
                                            self._predict_targets:targets,
                                            self._predict_lengths:path_lens})
            return list(predictions)
#             pred_list = []
#             for i, seq_len in enumerate(seq_lens):
#                 pred_list.append(list(predictions[i, :seq_len])) 
#             return pred_list
            
    def checkpoint(self):
        self.saver.save(self.session, self.checkpoint_prefix + '.ckpt', global_step=self._global_step)
        
    def restore(self, model_ckpt_path):
        self.saver.restore(self.session, model_ckpt_path)
        
    def __repr__(self):
        return ("<DPNN: W:%i, D:%i, H:%i, V:%i>" 
                % (self.word_embed_size, self.dep_embed_size, self.hidden_size, self.vocab_size))

# %%
reload(dh)
DH = dh.DataHandler('data/shuffled_wiki_sdp_50000', valid_percent=1)
# Out:
# Creating Data objects...
# Done creating Data objects
# 707073 total examples :: 700002 training : 7071 valid (99:1 split)
# Vocab size: 14798 Dep size: 50

# %%
print('<X>' in DH.vocab)
# Out:
# True

# %%
# %time
# load the pretrained word embeddings
fname = 'data/GoogleNews-vectors-negative300.bin'
word2vec = Word2Vec.load_word2vec_format(fname, binary=True)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.05 µs

# %%
reload(sdh)
train, valid, test, label2int, int2label = sdh.load_semeval_data()
num_classes = len(int2label.keys())
# Out:
# Didn't find common ancestor
# 1790	"The imams were removed from a US Airways <e1>flight</e1> awaiting departure from the Minneapolis-St. Paul <e2>airport</e2>."
#
# (The imams were removed from a US Airways flight awaiting departure from the Minneapolis - St . Paul airport ., flight , airport )
# Bad sentence: '1790\t"The imams were removed from a US Airways <e1>flight</e1> awaiting departure from the Minneapolis-St. Paul <e2>airport</e2>."\r\n'
# ((The imams were removed from a US Airways flight awaiting departure from the Minneapolis - St . Paul airport ., flight , airport ), None)
# Skipping this one... '1790\t"The imams were removed from a US Airways <e1>flight</e1> awaiting departure from the Minneapolis-St. Paul <e2>airport</e2>."\r\n'
# (None, None, None, 10)
# Num training: 7108
# Num valididation: 891
# Didn't find common ancestor
# 8310	"Tributes have been paid to the <e1>writer</e1> who created Goodness Gracious Me, the hit BBC television <e2>series</e2>."
#
# (Tributes have been paid to the writer who created Goodness Gracious Me , the hit BBC television series ., writer , series )
# Bad sentence: '8310\t"Tributes have been paid to the <e1>writer</e1> who created Goodness Gracious Me, the hit BBC television <e2>series</e2>."\r\n'
# ((Tributes have been paid to the writer who created Goodness Gracious Me , the hit BBC television series ., writer , series ), None)
# Skipping this one... '8000\t"The <e1>surgeon</e1> cuts a small <e2>hole</e2> in the skull and lifts the edge of the brain to expose the nerve."\r\n'
# ((The surgeon cuts a small hole in the skull and lifts the edge of the brain to expose the nerve ., surgeon , hole ), None, None, 8)
# Num testing: 2717

# %%
# %%bash
# git pull

# %%
# convert the semeval data to indices under the wiki vocab:
train['sdps'] = DH.sentences_to_sequences(train['sdps'])
valid['sdps'] = DH.sentences_to_sequences(valid['sdps'])
test['sdps'] = DH.sentences_to_sequences(test['sdps'])
    
train['targets'] = DH.sentences_to_sequences(train['targets'])
valid['targets'] = DH.sentences_to_sequences(valid['targets'])
test['targets'] = DH.sentences_to_sequences(test['targets'])
# Out:
# uprises sash 14793
# crucible sash 14793
# ml sash 14793
# pipetted sash 14793
# whistles sash 14793
# pans sash 14793
# pertinent sash 14793
# illuminating sash 14793
# pains sash 14793
# transmit sash 14793
# swap sash 14793
# widgets sash 14793
# abnormality sash 14793
# shower sash 14793
# tattoo sash 14793
# poured sash 14793
# exploding sash 14793
# migrating sash 14793
# objection sash 14793
# ding sash 14793
# cleaned sash 14793
# distilled sash 14793
# hailed sash 14793
# extracted sash 14793
# rescheduled sash 14793
# aerosol sash 14793
# ingredient sash 14793
# calibrates sash 14793
# microscope sash 14793
# distilled sash 14793
# peels sash 14793
# tubing sash 14793
# blowing sash 14793
# plowing sash 14793
# attaches sash 14793
# bins sash 14793
# stuffed sash 14793
# trove sash 14793
# hagler sash 14793
# fetched sash 14793
# stirs sash 14793
# migrating sash 14793
# poured sash 14793
# illustrating sash 14793
# beverage sash 14793
# coiled sash 14793
# poured sash 14793
# warmed sash 14793
# mss sash 14793
# departs sash 14793
# slipped sash 14793
# nasal sash 14793
# stuffed sash 14793
# commandment sash 14793
# poured sash 14793
# plowing sash 14793
# encloses sash 14793
# operas sash 14793
# specialises sash 14793
# fetched sash 14793
# unwinded sash 14793
# analysed sash 14793
# fifths sash 14793
# rescheduled sash 14793
# scratched sash 14793
# poured sash 14793
# evaporated sash 14793
# quadriceps sash 14793
# anathema sash 14793
# glad sash 14793
# herniated sash 14793
# rinse sash 14793
# inquires sash 14793
# mellitus sash 14793
# blooms sash 14793
# cleaned sash 14793
# drank sash 14793
# rso sash 14793
# nrc sash 14793
# searched sash 14793
# banquet sash 14793
# basket sash 14793
# downstairs sash 14793
# wiping sash 14793
# dryness sash 14793
# rashes sash 14793
# dragged sash 14793
# triggers sash 14793
# intestines sash 14793
# dragged sash 14793
# misplaced sash 14793
# piled sash 14793
# freshness sash 14793
# melting sash 14793
# avoidance sash 14793
# antipsychotic sash 14793
# emphasised sash 14793
# dangling sash 14793
# cleo sash 14793
# treats sash 14793
# mononucleosis sash 14793
# stuffed sash 14793
# allege sash 14793
# amnii sash 14793
# colourless sash 14793
# flop sash 14793
# evaporated sash 14793
# paste sash 14793
# stuffed sash 14793
# stuffed sash 14793
# portrays sash 14793
# eluded sash 14793
# criticizes sash 14793
# gamut sash 14793
# ligaments sash 14793
# misplaced sash 14793
# injected sash 14793
# attaches sash 14793
# jug sash 14793
# sails sash 14793
# stitching sash 14793
# machined sash 14793
# poured sash 14793
# fermented sash 14793
# distilled sash 14793
# outlined sash 14793
# swore sash 14793
# hailed sash 14793
# retracts sash 14793
# advertises sash 14793
# distilled sash 14793
# embarrassment sash 14793
# imaginations sash 14793
# derive sash 14793
# recipes sash 14793
# implanted sash 14793
# poured sash 14793
# explores sash 14793
# venting sash 14793
# evaporated sash 14793
# priming sash 14793
# pinning sash 14793
# gist sash 14793
# billions sash 14793
# tore sash 14793
# pertinent sash 14793
# encloses sash 14793
# hallucinations sash 14793
# machined sash 14793
# wrenches sash 14793
# poured sash 14793
# melt sash 14793
# paced sash 14793
# diagnoses sash 14793
# revolves sash 14793
# summarising sash 14793
# tray sash 14793
# searched sash 14793
# prolongation sash 14793
# asserts sash 14793
# plurality sash 14793
# scrum sash 14793
# poured sash 14793
# portrays sash 14793
# whirling sash 14793
# nectaring sash 14793
# distilled sash 14793
# stirred sash 14793
# snorgled sash 14793
# synthesizes sash 14793
# hearts sash 14793
# translates sash 14793
# severing sash 14793
# tonsurans sash 14793
# denote sash 14793
# stuffed sash 14793
# dumped sash 14793
# folder sash 14793
# swirling sash 14793
# -russell sash 14793
# recounted sash 14793
# encloses sash 14793
# leaked sash 14793
# scaled sash 14793
# houghton sash 14793
# flashing sash 14793
# acupuncture sash 14793
# rhinos sash 14793
# poured sash 14793
# leaked sash 14793
# hilt sash 14793
# parody sash 14793
# accesses sash 14793
# injected sash 14793
# misplaced sash 14793
# awlaki sash 14793
# analysed sash 14793
# narrating sash 14793
# poured sash 14793
# donating sash 14793
# bopet sash 14793
# stuffed sash 14793
# denotes sash 14793
# bakes sash 14793
# migrating sash 14793
# explores sash 14793
# secreted sash 14793
# inquire sash 14793
# fetched sash 14793
# summarised sash 14793
# stack sash 14793
# insist sash 14793
# poured sash 14793
# furnishes sash 14793
# rescheduled sash 14793
# lambasted sash 14793
# nigra sash 14793
# emission sash 14793
# gallons sash 14793
# hailed sash 14793
# baggy sash 14793
# stacked sash 14793
# blasts sash 14793
# pretinned sash 14793
# liberated sash 14793
# sequencing sash 14793
# .with sash 14793
# illnesses sash 14793
# summarised sash 14793
# poured sash 14793
# subsidising sash 14793
# encloses sash 14793
# headaches sash 14793
# hid sash 14793
# plethora sash 14793
# carve sash 14793
# portrays sash 14793
# inquire sash 14793
# pressures sash 14793
# injected sash 14793
# liens sash 14793
# popped sash 14793
# hailed sash 14793
# copes sash 14793
# shanks sash 14793
# inventing sash 14793
# encloses sash 14793
# piercings sash 14793
# prophesy sash 14793
# hid sash 14793
# journeyed sash 14793
# bumps sash 14793
# sequencer sash 14793
# eluded sash 14793
# morasko sash 14793
# crests sash 14793
# analyzes sash 14793
# plated sash 14793
# threaten sash 14793
# hides sash 14793
# journeyed sash 14793
# outlined sash 14793
# poured sash 14793
# assembles sash 14793
# paste sash 14793
# silencing sash 14793
# manipulated sash 14793
# rescheduled sash 14793
# stacked sash 14793
# liberated sash 14793
# masonry sash 14793
# pried sash 14793
# outputs sash 14793
# infertility sash 14793
# denoting sash 14793
# overrun sash 14793
# flannery sash 14793
# journeyed sash 14793
# tucked sash 14793
# bakes sash 14793
# sores sash 14793
# implanted sash 14793
# pencil sash 14793
# outlined sash 14793
# digs sash 14793
# beverage sash 14793
# heap sash 14793
# profiling sash 14793
# ponies sash 14793
# sneezing sash 14793
# dragged sash 14793
# unleashes sash 14793
# summarised sash 14793
# manipulates sash 14793
# absconded sash 14793
# wields sash 14793
# departs sash 14793
# basket sash 14793
# mesh sash 14793
# toils sash 14793
# plow sash 14793
# cultivator sash 14793
# leaked sash 14793
# imbalance sash 14793
# tore sash 14793
# shreds sash 14793
# explores sash 14793
# inject sash 14793
# julep sash 14793
# leaked sash 14793
# dangling sash 14793
# hydration sash 14793
# headaches sash 14793
# stemmed sash 14793
# provoking sash 14793
# liberate sash 14793
# summarises sash 14793
# journeyed sash 14793
# coined sash 14793
# leaked sash 14793
# fries sash 14793
# stuffed sash 14793
# scaled sash 14793
# modulating sash 14793
# depiction sash 14793
# taxies sash 14793
# opiates sash 14793
# dependence sash 14793
# dragged sash 14793
# carves sash 14793
# scrapes sash 14793
# distilled sash 14793
# evaporated sash 14793
# relaxes sash 14793
# migrating sash 14793
# fulfills sash 14793
# poured sash 14793
# dumped sash 14793
# gist sash 14793
# repertoire sash 14793
# workwear sash 14793
# spooled sash 14793
# poured sash 14793
# journeyed sash 14793
# clip sash 14793
# whittle sash 14793
# packets sash 14793
# notifies sash 14793
# intestine sash 14793
# summarising sash 14793
# attaches sash 14793
# folder sash 14793
# departs sash 14793
# mccourt sash 14793
# colorants sash 14793
# preservatives sash 14793
# dryness sash 14793
# rashes sash 14793
# itchiness sash 14793
# baked sash 14793
# speeding sash 14793
# stresses sash 14793
# distilled sash 14793
# plurality sash 14793
# poured sash 14793
# slapping sash 14793
# popped sash 14793
# copes sash 14793
# coagulating sash 14793
# pouring sash 14793
# outlined sash 14793
# urgency sash 14793
# gallons sash 14793
# informing sash 14793
# dragged sash 14793
# stuns sash 14793
# departs sash 14793
# clamp sash 14793
# instigated sash 14793
# piled sash 14793
# departs sash 14793
# piled sash 14793
# poured sash 14793
# ate sash 14793
# steak sash 14793
# distilled sash 14793
# ingredient sash 14793
# transact sash 14793
# emanated sash 14793
# fetched sash 14793
# belying sash 14793
# instigated sash 14793
# overview sash 14793
# fetched sash 14793
# fatigue sash 14793
# stuffed sash 14793
# pencils sash 14793
# migrating sash 14793
# screaming sash 14793
# acidity sash 14793
# wields sash 14793
# pulses sash 14793
# injected sash 14793
# popped sash 14793
# analysed sash 14793
# blowing sash 14793
# gleam sash 14793
# stuffed sash 14793
# cultivate sash 14793
# knots sash 14793
# copied sash 14793
# poured sash 14793
# departs sash 14793
# accesses sash 14793
# sup sash 14793
# blows sash 14793
# hydrants sash 14793
# okay sash 14793
# popped sash 14793
# dwellers sash 14793
# blasts sash 14793
# foe sash 14793
# dumped sash 14793
# irritation sash 14793
# pneumonitis sash 14793
# fashioned sash 14793
# disorientation sash 14793
# poured sash 14793
# instigated sash 14793
# completes sash 14793
# informing sash 14793
# notebook sash 14793
# gel sash 14793
# injected sash 14793
# seafloor sash 14793
# erupts sash 14793
# oven sash 14793
# stirring sash 14793
# burst sash 14793
# remnant sash 14793
# invent sash 14793
# assembles sash 14793
# departs sash 14793
# sewn sash 14793
# diminished sash 14793
# pouring sash 14793
# norms sash 14793
# sliced sash 14793
# tabled sash 14793
# searched sash 14793
# assemblage sash 14793
# discussing sash 14793
# parody sash 14793
# midges sash 14793
# horseflies sash 14793
# launcher sash 14793
# stirs sash 14793
# drawer sash 14793
# illustrating sash 14793
# liberate sash 14793
# sculpts sash 14793
# pony sash 14793
# tapped sash 14793
# pollen sash 14793
# sins sash 14793
# migrating sash 14793
# adopts sash 14793
# latex sash 14793
# pouring sash 14793
# absconded sash 14793
# stapled sash 14793
# joists sash 14793
# ingredient sash 14793
# eruption sash 14793
# poured sash 14793
# pertain sash 14793
# extracted sash 14793
# attaches sash 14793
# funnel sash 14793
# forgot sash 14793
# copes sash 14793
# treats sash 14793
# bailed sash 14793
# popped sash 14793
# tackled sash 14793
# chopped sash 14793
# spawned sash 14793
# encloses sash 14793
# folders sash 14793
# pylori sash 14793
# denotes sash 14793
# drawer sash 14793
# dempseys sash 14793
# spawned sash 14793
# summarised sash 14793
# blasts sash 14793
# inventoried sash 14793
# tackling sash 14793
# candida sash 14793
# monilia sash 14793
# nausea sash 14793
# exhaustion sash 14793
# manipulates sash 14793
# retriever sash 14793
# unleashes sash 14793
# torrent sash 14793
# manipulates sash 14793
# sedan sash 14793
# retract sash 14793
# cheering sash 14793
# defaced sash 14793
# calibrates sash 14793
# bolts sash 14793
# swirls sash 14793
# dragged sash 14793
# leaked sash 14793
# injected sash 14793
# landslides sash 14793
# outlined sash 14793
# depiction sash 14793
# fetched sash 14793
# criticizing sash 14793
# lampooning sash 14793
# caring sash 14793
# surveying sash 14793
# peerbot sash 14793
# reel sash 14793
# cartload sash 14793
# smog sash 14793
# outlines sash 14793
# ate sash 14793
# predictions sash 14793
# poured sash 14793
# nuts sash 14793
# dab sash 14793
# emanated sash 14793
# cleaned sash 14793
# removes sash 14793
# protections sash 14793
# dough sash 14793
# propose sash 14793
# whiplash sash 14793
# wields sash 14793
# bailed sash 14793
# accuses sash 14793
# poured sash 14793
# sores sash 14793
# dragged sash 14793
# resigns sash 14793
# remade sash 14793
# sinuses sash 14793
# vaporized sash 14793
# waveform sash 14793
# narrates sash 14793
# relaxes sash 14793
# kronendal sash 14793
# reburied sash 14793
# springing sash 14793
# dragged sash 14793
# domed sash 14793
# filigreed sash 14793
# jewel sash 14793
# commuters sash 14793
# horizons sash 14793
# sabotaged sash 14793
# concludes sash 14793
# manipulates sash 14793
# drawer sash 14793
# avatars sash 14793
# penned sash 14793
# stuffed sash 14793
# absconded sash 14793
# poured sash 14793
# bailed sash 14793
# urethra sash 14793
# poured sash 14793
# plucked sash 14793
# injects sash 14793
# disinfection sash 14793
# tackled sash 14793
# injected sash 14793
# injected sash 14793
# sewn sash 14793
# distilled sash 14793
# governs sash 14793
# threaten sash 14793
# extracted sash 14793
# verbatim sash 14793
# poured sash 14793
# ligated sash 14793
# rescheduled sash 14793
# solicited sash 14793
# sewed sash 14793
# poured sash 14793
# injected sash 14793
# journeyed sash 14793
# watered sash 14793
# speeding sash 14793
# pills sash 14793
# headaches sash 14793
# overuse sash 14793
# hounds sash 14793
# encoded sash 14793
# nod sash 14793
# freezer sash 14793
# dragged sash 14793
# rescheduled sash 14793
# extensor sash 14793
# sashayed sash 14793
# distilled sash 14793
# gallons sash 14793
# poured sash 14793
# pancreas sash 14793
# pops sash 14793
# differentiating sash 14793
# departs sash 14793
# dumped sash 14793
# distilled sash 14793
# blinded sash 14793
# pentoxide sash 14793
# distilled sash 14793
# dioxides sash 14793
# obligate sash 14793
# carves sash 14793
# tuck sash 14793
# drawer sash 14793
# disasters sash 14793
# tabulate sash 14793
# pouch sash 14793
# criticising sash 14793
# overuse sash 14793
# extracted sash 14793
# defaced sash 14793
# conjured sash 14793
# swirl sash 14793
# cheque sash 14793
# casket sash 14793
# battered sash 14793
# colds sash 14793
# throat sash 14793
# pertained sash 14793
# sleeps sash 14793
# documenting sash 14793
# bailed sash 14793
# implanted sash 14793
# inventing sash 14793
# eluded sash 14793
# crafted sash 14793
# smuck sash 14793
# jellyfish sash 14793
# bullhorns sash 14793
# bullfight sash 14793
# gallons sash 14793
# leaked sash 14793
# piled sash 14793
# preservatives sash 14793
# dryness sash 14793
# copes sash 14793
# illnesses sash 14793
# hid sash 14793
# poured sash 14793
# breakouts sash 14793
# unconsciousness sash 14793
# misplaced sash 14793
# piled sash 14793
# injected sash 14793
# commences sash 14793
# underperforming sash 14793
# frustrations sash 14793
# hinges sash 14793
# sprang sash 14793
# conduced sash 14793
# mudslides sash 14793
# journeyed sash 14793
# distilled sash 14793
# squids sash 14793
# migrating sash 14793
# soaps sash 14793
# spreads sash 14793
# inquires sash 14793
# implanted sash 14793
# catched sash 14793
# gizmo sash 14793
# spreads sash 14793
# debugger sash 14793
# fabricates sash 14793
# scaled sash 14793
# leaked sash 14793
# departs sash 14793
# distilled sash 14793
# dragged sash 14793
# crucible sash 14793
# rudders sash 14793
# distilled sash 14793
# skirts sash 14793
# absconded sash 14793
# attaches sash 14793
# crucible sash 14793
# insist sash 14793
# dragged sash 14793
# precleaned sash 14793
# instigated sash 14793
# patched sash 14793
# baring sash 14793
# discomfort sash 14793
# ticks sash 14793
# syrup sash 14793
# stirs sash 14793
# triumph sash 14793
# pimples sash 14793
# tasted sash 14793
# mortgaged sash 14793
# leaked sash 14793
# poured sash 14793
# removes sash 14793
# takeoffs sash 14793
# tenkiller sash 14793
# hailed sash 14793
# wields sash 14793
# laborers sash 14793
# splashes sash 14793
# emiting sash 14793
# flashes sash 14793
# sweeps sash 14793
# crammed sash 14793
# fries sash 14793
# potatoes sash 14793
# poured sash 14793
# synthesizes sash 14793
# angiotensinogen sash 14793
# molding sash 14793
# leaked sash 14793
# wilde sash 14793
# thornhill sash 14793
# hopping sash 14793
# departs sash 14793
# journeyed sash 14793
# stacked sash 14793
# narrate sash 14793
# spreads sash 14793
# battered sash 14793
# encloses sash 14793
# injected sash 14793
# poured sash 14793
# emanated sash 14793
# jongg sash 14793
# stuffed sash 14793
# clues sash 14793
# instigates sash 14793
# extracted sash 14793
# manipulates sash 14793
# inspecting sash 14793
# stemmed sash 14793
# migrating sash 14793
# poured sash 14793
# dragged sash 14793
# encloses sash 14793
# headaches sash 14793
# uprises sash 14793
# punched sash 14793
# scaled sash 14793
# poured sash 14793
# scratched sash 14793
# tuckered sash 14793
# emanated sash 14793
# removes sash 14793
# crucible sash 14793
# accent sash 14793
# nausea sash 14793
# concerto sash 14793
# convulsions sash 14793
# implanted sash 14793
# bunch sash 14793
# popped sash 14793
# piled sash 14793
# orbiters sash 14793
# poured sash 14793
# elbow sash 14793
# departs sash 14793
# ingredient sash 14793
# tastes sash 14793
# cooks sash 14793
# departs sash 14793
# encloses sash 14793
# knitted sash 14793
# colds sash 14793
# poured sash 14793
# storing sash 14793
# spuds sash 14793
# potatoes sash 14793
# migrating sash 14793
# leaked sash 14793
# dumped sash 14793
# stemmed sash 14793
# popped sash 14793
# sheath sash 14793
# leaked sash 14793
# welded sash 14793
# stuffed sash 14793
# flare sash 14793
# buddies sash 14793
# distilled sash 14793
# folder sash 14793
# mitigating sash 14793
# mold sash 14793
# dissatisfaction sash 14793
# poured sash 14793
# implanted sash 14793
# drowning sash 14793
# commuters sash 14793
# dragged sash 14793
# interjected sash 14793
# dumping sash 14793
# poured sash 14793
# rescheduled sash 14793
# otters sash 14793
# sticker sash 14793
# poured sash 14793
# dragged sash 14793
# blowing sash 14793
# journeyed sash 14793
# misplaced sash 14793
# uprises sash 14793
# smog sash 14793
# poured sash 14793
# discussing sash 14793
# daly sash 14793
# thickening sash 14793
# swirls sash 14793
# plurality sash 14793
# rescheduled sash 14793
# labelled sash 14793
# lever sash 14793
# manipulates sash 14793
# nosebleeds sash 14793
# popped sash 14793
# oz sash 14793
# tore sash 14793
# overview sash 14793
# horrors sash 14793
# poured sash 14793
# summarises sash 14793
# lowered sash 14793
# poured sash 14793
# battered sash 14793
# irritation sash 14793
# deprivation sash 14793
# attest sash 14793
# cardiology sash 14793
# reminds sash 14793
# attaches sash 14793
# leaked sash 14793
# navigate sash 14793
# disconcerting sash 14793
# fetched sash 14793
# donating sash 14793
# alleging sash 14793
# instigates sash 14793
# protects sash 14793
# hatches sash 14793
# collegue sash 14793
# scaled sash 14793
# cantilevered sash 14793
# utilizes sash 14793
# popped sash 14793
# lymphoma sash 14793
# peanuts sash 14793
# okra sash 14793
# peas sash 14793
# leapt sash 14793
# dragged sash 14793
# stemmed sash 14793
# attach sash 14793
# cricothyrotomy sash 14793
# telegram sash 14793
# financiers sash 14793
# prosthesis sash 14793
# hypochlorite sash 14793
# popped sash 14793
# popped sash 14793
# fashioned sash 14793
# coughing sash 14793
# itching sash 14793
# leaked sash 14793
# instigates sash 14793
# bailed sash 14793
# /spiders/cockroaches sash 14793
# taxied sash 14793
# suckles sash 14793
# popped sash 14793
# misplaced sash 14793
# leaked sash 14793
# distilled sash 14793
# sweeps sash 14793
# implanted sash 14793
# poured sash 14793
# stemmed sash 14793
# stemmed sash 14793
# parrots sash 14793
# poured sash 14793
# inundated sash 14793
# ziti sash 14793
# beads sash 14793
# asserting sash 14793
# journeyed sash 14793
# imbalance sash 14793
# sewn sash 14793
# charted sash 14793
# sustains sash 14793
# troubling sash 14793
# goldfish sash 14793
# headaches sash 14793
# colas sash 14793
# tore sash 14793
# laughing sash 14793
# journeyed sash 14793
# emiting sash 14793
# summarise sash 14793
# suffocation sash 14793
# depiction sash 14793
# shortages sash 14793
# fulfillment sash 14793
# wield sash 14793
# sawed sash 14793
# nitroglycerin sash 14793
# throat sash 14793
# laboring sash 14793
# mash sash 14793
# marrow sash 14793
# chasing sash 14793
# retrieved sash 14793
# derive sash 14793
# radiated sash 14793
# stashes sash 14793
# abele sash 14793
# wielded sash 14793
# glides sash 14793
# ounces sash 14793
# emits sash 14793
# lever sash 14793
# pastries sash 14793
# radiated sash 14793
# fabricated sash 14793
# etching sash 14793
# distilled sash 14793
# malt sash 14793
# hunched sash 14793
# cultivate sash 14793
# wield sash 14793
# alleviates sash 14793
# wrapper sash 14793
# sawed sash 14793
# distilled sash 14793
# begets sash 14793
# bounce sash 14793
# flavours sash 14793
# polypropylene sash 14793
# bulb sash 14793
# distilled sash 14793
# liberating sash 14793
# squatted sash 14793
# fabricated sash 14793
# distilled sash 14793
# shaves sash 14793
# stocking sash 14793
# emits sash 14793
# wielded sash 14793
# corgis sash 14793
# nicked sash 14793
# sawed sash 14793
# fabricated sash 14793
# astride sash 14793
# sawed sash 14793
# emits sash 14793
# emits sash 14793
# wielding sash 14793
# utensil sash 14793
# distilled sash 14793
# shielding sash 14793
# pounded sash 14793
# liquids sash 14793
# obtainable sash 14793
# procreated sash 14793
# basket sash 14793
# temptations sash 14793
# deprivation sash 14793
# grabbed sash 14793
# engulfed sash 14793
# begets sash 14793
# radiated sash 14793
# distilled sash 14793
# radiated sash 14793
# deviate sash 14793
# grinds sash 14793
# presses sash 14793
# sucklers sash 14793
# paraphernalia sash 14793
# fabricated sash 14793
# emits sash 14793
# radiated sash 14793
# distilled sash 14793
# emits sash 14793
# downed sash 14793
# counteract sash 14793
# emits sash 14793
# bucked sash 14793
# mated sash 14793
# fabricates sash 14793
# dumped sash 14793
# narrate sash 14793
# simplex sash 14793
# emanated sash 14793
# poured sash 14793
# canvases sash 14793
# dripper sash 14793
# analyzes sash 14793
# ecotec sash 14793
# apprehend sash 14793
# outputting sash 14793
# poured sash 14793
# tub sash 14793
# unleashes sash 14793
# bladder sash 14793
# germs sash 14793
# synthesized sash 14793
# poured sash 14793
# t-4 sash 14793
# wheelers sash 14793
# grabs sash 14793
# beaters sash 14793
# assembles sash 14793
# formatted sash 14793
# extracted sash 14793
# belenzian sash 14793
# cultivar sash 14793
# punching sash 14793
# flourishes sash 14793
# captures sash 14793
# speculations sash 14793
# poured sash 14793
# criticizes sash 14793
# frugal sash 14793
# mausoleums sash 14793
# alleging sash 14793
# revolves sash 14793
# completes sash 14793
# 0 sash 14793
# 0 acl 45
# encloses sash 14793
# battling sash 14793
# flattens sash 14793
# marred sash 14793
# bazaar sash 14793
# stresses sash 14793
# ingredient sash 14793
# shortens sash 14793
# sewn sash 14793
# denote sash 14793
# importing sash 14793
# pencilled sash 14793
# piled sash 14793
# coil sash 14793
# fractures sash 14793
# hams sash 14793
# chronologically sash 14793
# copes sash 14793
# uprises sash 14793
# drunkenness sash 14793
# hatshepsut sash 14793
# stuffed sash 14793
# stirs sash 14793
# popped sash 14793
# mocked sash 14793
# drawer sash 14793
# informing sash 14793
# pettway sash 14793
# hires sash 14793
# ploughed sash 14793
# swore sash 14793
# eluded sash 14793
# poured sash 14793
# departs sash 14793
# attaches sash 14793
# tub sash 14793
# uprises sash 14793
# hid sash 14793
# journeyed sash 14793
# surveying sash 14793
# journeyed sash 14793
# centrifuge sash 14793
# slab sash 14793
# shocks sash 14793
# commenting sash 14793
# implanted sash 14793
# fermenting sash 14793
# suitcase sash 14793
# migrating sash 14793
# thieving sash 14793
# digs sash 14793
# poured sash 14793
# lures sash 14793
# biting sash 14793
# poured sash 14793
# dump sash 14793
# extracted sash 14793
# blower sash 14793
# outlined sash 14793
# reap sash 14793
# imaginations sash 14793
# crucell sash 14793
# prometheus sash 14793
# spreadsheet sash 14793
# yesterd sash 14793
# charted sash 14793
# portrays sash 14793
# poured sash 14793
# dragged sash 14793
# perch sash 14793
# nymphs sash 14793
# tick sash 14793
# sprout sash 14793
# imaginations sash 14793
# rub sash 14793
# butt sash 14793
# drank sash 14793
# floor/ceiling sash 14793
# sentinels sash 14793
# provosts sash 14793
# leaked sash 14793
# truths sash 14793
# lifts sash 14793
# buildup sash 14793
# microfossil sash 14793
# outlined sash 14793
# rescheduled sash 14793
# cassette sash 14793
# decanting sash 14793
# injects sash 14793
# departs sash 14793
# distributes sash 14793
# revolutionized sash 14793
# yourselfer sash 14793
# propose sash 14793
# splitting sash 14793
# slips sash 14793
# headaches sash 14793
# dl sash 14793
# trove sash 14793
# flurry sash 14793
# madero sash 14793
# energetics sash 14793
# magnification sash 14793
# poured sash 14793
# asserting sash 14793
# synthesizes sash 14793
# quizzes sash 14793
# activates sash 14793
# comradeship sash 14793
# esophagus sash 14793
# analyzes sash 14793
# interprets sash 14793
# instigates sash 14793
# asserts sash 14793
# emulator sash 14793
# extracted sash 14793
# touching sash 14793
# concealing sash 14793
# spawned sash 14793
# sequels sash 14793
# injected sash 14793
# relaxes sash 14793
# leaked sash 14793
# poured sash 14793
# encloses sash 14793
# rearward sash 14793
# evaporated sash 14793
# stirs sash 14793
# flanking sash 14793
# evaporated sash 14793
# sails sash 14793
# eluded sash 14793
# commenting sash 14793
# departs sash 14793
# stirs sash 14793
# reacts sash 14793
# prying sash 14793
# eats sash 14793
# dumped sash 14793
# leaked sash 14793
# protects sash 14793
# misplaced sash 14793
# bakes sash 14793
# cough sash 14793
# throat sash 14793
# runny sash 14793
# aches sash 14793
# headache sash 14793
# lagged sash 14793
# colds sash 14793
# illnesses sash 14793
# overload sash 14793
# basket sash 14793
# flutes sash 14793
# assesses sash 14793
# battered sash 14793
# flurry sash 14793
# evaporated sash 14793
# nudge sash 14793
# defaced sash 14793
# deriving sash 14793
# leaked sash 14793
# predominating sash 14793
# tackling sash 14793
# poured sash 14793
# explores sash 14793
# discussing sash 14793
# battered sash 14793
# peels sash 14793
# knuckle sash 14793
# dumped sash 14793
# khyl sash 14793
# poured sash 14793
# poured sash 14793
# wields sash 14793
# compeers sash 14793
# ratpack sash 14793
# fulfills sash 14793
# extracted sash 14793
# packs sash 14793
# bladder sash 14793
# hid sash 14793
# drawer sash 14793
# buzzing sash 14793
# pestis sash 14793
# emanated sash 14793
# denoting sash 14793
# clothed sash 14793
# revolved sash 14793
# blasts sash 14793
# protections sash 14793
# verging sash 14793
# flapping sash 14793
# quacked sash 14793
# encloses sash 14793
# rashes sash 14793
# reminds sash 14793
# popped sash 14793
# extracted sash 14793
# outlines sash 14793
# reeased sash 14793
# departs sash 14793
# summarise sash 14793
# leaked sash 14793
# pertinent sash 14793
# proceeding sash 14793
# sequencing sash 14793
# negligence sash 14793
# flowed sash 14793
# syrup sash 14793
# tangere sash 14793
# oeuvre sash 14793
# prose sash 14793
# notified sash 14793
# depart sash 14793
# liter sash 14793
# boiled sash 14793
# cathode sash 14793
# slices sash 14793
# scaled sash 14793
# inserting sash 14793
# poured sash 14793
# smog sash 14793
# pertaining sash 14793
# drawer sash 14793
# poured sash 14793
# folder sash 14793
# stuffed sash 14793
# trove sash 14793
# manoeuvred sash 14793
# bestowing sash 14793
# tightens sash 14793
# rescheduled sash 14793
# narrate sash 14793
# summarised sash 14793
# drawer sash 14793
# leaked sash 14793
# auditors sash 14793
# pats sash 14793
# carves sash 14793
# narrates sash 14793
# frustration sash 14793
# migrating sash 14793
# bladder sash 14793
# bedrooms sash 14793
# encloses sash 14793
# pastry sash 14793
# departs sash 14793
# rash sash 14793
# throat sash 14793
# poured sash 14793
# wadded sash 14793
# asserts sash 14793
# imbalance sash 14793
# explores sash 14793
# poured sash 14793
# blasts sash 14793
# stacked sash 14793
# optimism sash 14793
# fragment sash 14793
# colds sash 14793
# flashes sash 14793
# ghosts sash 14793
# dissapeared sash 14793
# determinism sash 14793
# sped sash 14793
# pouring sash 14793
# sequenced sash 14793
# nisqually sash 14793
# sails sash 14793
# poured sash 14793
# distilled sash 14793
# relaxes sash 14793
# tore sash 14793
# personifies sash 14793
# gist sash 14793
# swelling sash 14793
# spawned sash 14793
# leaked sash 14793
# ibis sash 14793
# anus sash 14793
# imbalance sash 14793
# unleashes sash 14793
# governs sash 14793
# dragged sash 14793
# stuffing sash 14793
# blueprints sash 14793
# slab sash 14793
# poured sash 14793
# bales sash 14793
# lump sash 14793
# syrup sash 14793
# journeyed sash 14793
# fetched sash 14793
# jeans sash 14793
# documenting sash 14793
# ounce sash 14793
# crust sash 14793
# fatigue sash 14793
# spawned sash 14793
# revolves sash 14793
# disorientation sash 14793
# poured sash 14793
# recycled sash 14793
# greed sash 14793
# whittling sash 14793
# lathing sash 14793
# unleashes sash 14793
# leaked sash 14793
# blowing sash 14793
# leaked sash 14793
# dyspareunia sash 14793
# diffuse sash 14793
# pertaining sash 14793
# encloses sash 14793
# bakes sash 14793
# distilled sash 14793
# assembles sash 14793
# drank sash 14793
# outlined sash 14793
# emanated sash 14793
# popped sash 14793
# sweeps sash 14793
# cradle sash 14793
# disassembler sash 14793
# lawsonite sash 14793
# flask sash 14793
# oblivion sash 14793
# burst sash 14793
# virtuoso sash 14793
# trays sash 14793
# blossom sash 14793
# grenadiers sash 14793
# hounds sash 14793
# commotion sash 14793
# grouse sash 14793
# timer sash 14793
# headaches sash 14793
# mold sash 14793
# stack sash 14793
# carton sash 14793
# lagoons sash 14793
# calluses sash 14793
# councilor sash 14793
# elicitation sash 14793
# meteor sash 14793
# colliers sash 14793
# tiller sash 14793
# recurrence sash 14793
# scars sash 14793
# stitches sash 14793
# knob sash 14793
# toads sash 14793
# discourse sash 14793
# causal sash 14793
# cowpea sash 14793
# brucellosis sash 14793
# rout sash 14793
# pumpkin sash 14793
# lawsuits sash 14793
# cabal sash 14793
# epithelium sash 14793
# artworks sash 14793
# tsunami sash 14793
# leakage sash 14793
# corrosion sash 14793
# horde sash 14793
# crossbowmen sash 14793
# swelling sash 14793
# vibration sash 14793
# programmer sash 14793
# basket sash 14793
# shoemaker sash 14793
# canteen sash 14793
# carafe sash 14793
# acetone sash 14793
# roses sash 14793
# necklace sash 14793
# suction sash 14793
# babel sash 14793
# pigeons sash 14793
# biographies sash 14793
# screwdriver sash 14793
# infantrymen sash 14793
# malfunctions sash 14793
# dwarves sash 14793
# bloodhound sash 14793
# muster sash 14793
# maze sash 14793
# scourge sash 14793
# mosquitoes sash 14793
# riffraff sash 14793
# mercenaries sash 14793
# discomfort sash 14793
# coven sash 14793
# sorcerers sash 14793
# lorries sash 14793
# programmers sash 14793
# scarab sash 14793
# tides sash 14793
# nebulizer sash 14793
# lobes sash 14793
# liquor sash 14793
# tardiness sash 14793
# flask sash 14793
# deluge sash 14793
# steamer sash 14793
# pencil sash 14793
# ale sash 14793
# molds sash 14793
# plow sash 14793
# ulna sash 14793
# disarray sash 14793
# nasal sash 14793
# cellophane sash 14793
# reel sash 14793
# planter sash 14793
# notepad sash 14793
# snarl sash 14793
# corrosion sash 14793
# koala sash 14793
# pouch sash 14793
# moles sash 14793
# contractions sash 14793
# irritation sash 14793
# subsidization sash 14793
# necklace sash 14793
# buzzards sash 14793
# warts sash 14793
# compeers sash 14793
# paddle sash 14793
# ewer sash 14793
# microsimulation sash 14793
# folder sash 14793
# passel sash 14793
# pigeons sash 14793
# baskets sash 14793
# belly sash 14793
# flyer sash 14793
# shoal sash 14793
# bookmarks sash 14793
# nanoparticle sash 14793
# revelation sash 14793
# herons sash 14793
# indenter sash 14793
# cruisers sash 14793
# fittings sash 14793
# kirpan sash 14793
# shiver sash 14793
# doll sash 14793
# stockings sash 14793
# choreographer sash 14793
# carbonated sash 14793
# pail sash 14793
# blackout sash 14793
# barricade sash 14793
# jars sash 14793
# oocytes sash 14793
# morbidity sash 14793
# geoid sash 14793
# ellipsoid sash 14793
# flask sash 14793
# dizziness sash 14793
# sinus sash 14793
# handcart sash 14793
# fistful sash 14793
# coupons sash 14793
# mummy sash 14793
# packing sash 14793
# cistern sash 14793
# sagas sash 14793
# refrigerator sash 14793
# mule sash 14793
# buds sash 14793
# venter sash 14793
# draught sash 14793
# salmons sash 14793
# poodle sash 14793
# avalanches sash 14793
# pocketwatch sash 14793
# mainspring sash 14793
# raspberry sash 14793
# syrup sash 14793
# heavens sash 14793
# peep sash 14793
# chickens sash 14793
# commotion sash 14793
# honeycomb sash 14793
# throng sash 14793
# foes sash 14793
# relaxation sash 14793
# devastation sash 14793
# deficits sash 14793
# blackboard sash 14793
# wedge sash 14793
# illnesses sash 14793
# rectangles sash 14793
# billions sash 14793
# glamour sash 14793
# resetting sash 14793
# mesencephalon sash 14793
# tectum sash 14793
# jug sash 14793
# crate sash 14793
# vapor sash 14793
# oceans sash 14793
# depo sash 14793
# meinie sash 14793
# patella sash 14793
# condoms sash 14793
# blasts sash 14793
# macaque sash 14793
# congressmen sash 14793
# handbag sash 14793
# intestines sash 14793
# faults sash 14793
# cancellations sash 14793
# asparagus sash 14793
# mustering sash 14793
# stork sash 14793
# craniopharyngioma sash 14793
# sinus sash 14793
# monkeys sash 14793
# quiver sash 14793
# cobras sash 14793
# roach sash 14793
# heartwood sash 14793
# hematoxylin sash 14793
# splints sash 14793
# duffel sash 14793
# niece sash 14793
# peanut sash 14793
# cookies sash 14793
# stratification sash 14793
# cranberry sash 14793
# mules sash 14793
# protections sash 14793
# cypress sash 14793
# tenant sash 14793
# sorrow sash 14793
# eruption sash 14793
# comma sash 14793
# scribe sash 14793
# pellets sash 14793
# cavities sash 14793
# winemaker sash 14793
# insulation sash 14793
# carafe sash 14793
# irritation sash 14793
# hamper sash 14793
# goodies sash 14793
# impetus sash 14793
# camaraderie sash 14793
# kinship sash 14793
# grandparents sash 14793
# negligence sash 14793
# mug sash 14793
# glut sash 14793
# nuts sash 14793
# guys sash 14793
# waistband sash 14793
# underwear sash 14793
# catamaran sash 14793
# tiller sash 14793
# blogging sash 14793
# jars sash 14793
# paddle sash 14793
# microaccelerometer sash 14793
# hookah sash 14793
# trembling sash 14793
# finches sash 14793
# hairdresser sash 14793
# toners sash 14793
# pushpins sash 14793
# bountiful sash 14793
# hamper sash 14793
# luminaries sash 14793
# basket sash 14793
# biscuits sash 14793
# dryer sash 14793
# cholesterol sash 14793
# gulls sash 14793
# cigarettes sash 14793
# preservatives sash 14793
# itchiness sash 14793
# dentists sash 14793
# hounds sash 14793
# quilt sash 14793
# pyrotechnics sash 14793
# breakouts sash 14793
# scissors sash 14793
# stylist sash 14793
# plowing sash 14793
# plow sash 14793
# pups sash 14793
# deceit sash 14793
# lapwings sash 14793
# mentality sash 14793
# preeclampsia sash 14793
# matchboxes sash 14793
# robbers sash 14793
# comb sash 14793
# padlock sash 14793
# pane sash 14793
# fridge sash 14793
# comradeship sash 14793
# spoon sash 14793
# ale sash 14793
# carton sash 14793
# dominions sash 14793
# stove sash 14793
# indigestion sash 14793
# malfunction sash 14793
# physiotherapy sash 14793
# comradeship sash 14793
# technician sash 14793
# troubadour sash 14793
# broadsides sash 14793
# oven sash 14793
# conveyor sash 14793
# psychiatrists sash 14793
# asterisk sash 14793
# cashier sash 14793
# corpse sash 14793
# noose sash 14793
# pouches sash 14793
# wallabies sash 14793
# shoemaker sash 14793
# gam sash 14793
# mater sash 14793
# saline sash 14793
# stuffed sash 14793
# martyrs sash 14793
# therapist sash 14793
# deers sash 14793
# catnip sash 14793
# fistful sash 14793
# redistribution sash 14793
# tonsillitis sash 14793
# constellation sash 14793
# philosophers sash 14793
# strikers sash 14793
# roach sash 14793
# rug sash 14793
# mathematicians sash 14793
# scroll sash 14793
# compeers sash 14793
# snowshoes sash 14793
# headache sash 14793
# bulbs sash 14793
# acorn sash 14793
# cartographer sash 14793
# interrogation sash 14793
# canister sash 14793
# liquor sash 14793
# phial sash 14793
# suitcase sash 14793
# marihuana sash 14793
# organism sash 14793
# kettle sash 14793
# hippopotami sash 14793
# adhesive sash 14793
# controversies sash 14793
# oblivion sash 14793
# capscrews sash 14793
# buzzards sash 14793
# passel sash 14793
# brats sash 14793
# harssement sash 14793
# bladder sash 14793
# meltdown sash 14793
# ginger sash 14793
# tomorrow sash 14793
# convulsions sash 14793
# plugs sash 14793
# plugboard sash 14793
# dryer sash 14793
# irritation sash 14793
# clip sash 14793
# fable sash 14793
# creep sash 14793
# tortoises sash 14793
# headaches sash 14793
# cache sash 14793
# clams sash 14793
# bucket sash 14793
# dwellers sash 14793
# defendant sash 14793
# coil sash 14793
# galvanometer sash 14793
# coven sash 14793
# witches sash 14793
# craftsmen sash 14793
# infestation sash 14793
# lice sash 14793
# garbages sash 14793
# meningitis sash 14793
# racehorses sash 14793
# kinship sash 14793
# capitalists sash 14793
# fluther sash 14793
# jellyfish sash 14793
# implant sash 14793
# slideshows sash 14793
# cops sash 14793
# statesman sash 14793
# fumes sash 14793
# coconut sash 14793
# dehydrated sash 14793
# parcel sash 14793
# nape sash 14793
# sociological sash 14793
# wort sash 14793
# bucket sash 14793
# throng sash 14793
# quotation sash 14793
# explorations sash 14793
# gel sash 14793
# sheath sash 14793
# folder sash 14793
# questionnaires sash 14793
# bedrooms sash 14793
# shipment sash 14793
# cask sash 14793
# stonework sash 14793
# sacrifices sash 14793
# volcano sash 14793
# wrench sash 14793
# chefs sash 14793
# chimpanzees sash 14793
# stapler sash 14793
# anvil sash 14793
# byelection sash 14793
# dishwasher sash 14793
# tub sash 14793
# tsunamis sash 14793
# deregulation sash 14793
# anthrax sash 14793
# suitcase sash 14793
# crate sash 14793
# catastrophe sash 14793
# metaphor sash 14793
# basket sash 14793
# canister sash 14793
# watchdog sash 14793
# estrogen sash 14793
# osteoporosis sash 14793
# jeans sash 14793
# kettle sash 14793
# superfluity sash 14793
# blogosphere sash 14793
# parameter sash 14793
# constructor sash 14793
# feather sash 14793
# basket sash 14793
# germs sash 14793
# illnesses sash 14793
# stitches sash 14793
# drawer sash 14793
# billions sash 14793
# subsection sash 14793
# oven sash 14793
# rum sash 14793
# scissors sash 14793
# marksmen sash 14793
# dieters sash 14793
# bonfire sash 14793
# rhumba sash 14793
# rattlesnakes sash 14793
# directives sash 14793
# leaflet sash 14793
# entitlements sash 14793
# pyrolysis sash 14793
# directory sash 14793
# scream sash 14793
# hamper sash 14793
# canister sash 14793
# entitlements sash 14793
# cashier sash 14793
# geodiversity sash 14793
# bevy sash 14793
# roebucks sash 14793
# washer sash 14793
# harlot sash 14793
# hornpipe sash 14793
# paw sash 14793
# archers sash 14793
# kortdage sash 14793
# slice sash 14793
# beaker sash 14793
# psychiatrist sash 14793
# handgrip sash 14793
# suitcase sash 14793
# oranges sash 14793
# vial sash 14793
# tittering sash 14793
# magpies sash 14793
# spirits sash 14793
# helix sash 14793
# inhibitors sash 14793
# coloring sash 14793
# revellers sash 14793
# canteen sash 14793
# bristles sash 14793
# molding sash 14793
# paperboard sash 14793
# biofilm sash 14793
# vibration sash 14793
# dragoons sash 14793
# surges sash 14793
# mycoses sash 14793
# microphone sash 14793
# implants sash 14793
# transmitters sash 14793
# orangutans sash 14793
# hygrometer sash 14793
# menage sash 14793
# goatfish sash 14793
# barbels sash 14793
# closet sash 14793
# swelling sash 14793
# setbacks sash 14793
# mattress sash 14793
# bisexuality sash 14793
# infraction sash 14793
# clot sash 14793
# raccoons sash 14793
# strawberry sash 14793
# saws sash 14793
# accompaniment sash 14793
# condiments sash 14793
# robbers sash 14793
# skulk sash 14793
# peakeffect sash 14793
# insert sash 14793
# trespass sash 14793
# spirits sash 14793
# forceps sash 14793
# reliquary sash 14793
# headache sash 14793
# impulses sash 14793
# heartbeat sash 14793
# migraines sash 14793
# scroll sash 14793
# interrogators sash 14793
# newsreels sash 14793
# overflow sash 14793
# cigarettes sash 14793
# evaporation sash 14793
# wren sash 14793
# nests sash 14793
# delusions sash 14793
# fatigue sash 14793
# corrosion sash 14793
# handpiece sash 14793
# coil sash 14793
# modem sash 14793
# broach sash 14793
# yolk sash 14793
# perchlorate sash 14793
# youngster sash 14793
# lantern sash 14793
# stovetop sash 14793
# rookery sash 14793
# herons sash 14793
# freezer sash 14793
# plums sash 14793
# bratpack sash 14793
# pornographers sash 14793
# sisterhood sash 14793
# pouch sash 14793
# rotors sash 14793
# suitcase sash 14793
# lithium sash 14793
# ember sash 14793
# turnip sash 14793
# orca sash 14793
# epigraphs sash 14793
# wafers sash 14793
# flyers sash 14793
# menage sash 14793
# coffeemaker sash 14793
# candle sash 14793
# grammars sash 14793
# stack sash 14793
# crank sash 14793
# serpent sash 14793
# cradle sash 14793
# soda sash 14793
# nye sash 14793
# pheasants sash 14793
# technician sash 14793
# discolouration sash 14793
# incursion sash 14793
# stockings sash 14793
# microphone sash 14793
# swordsmen sash 14793
# tsunami sash 14793
# kaleidoscope sash 14793
# butterflies sash 14793
# tomato sash 14793
# lobes sash 14793
# examiner sash 14793
# ticker sash 14793
# pistachios sash 14793
# tapir sash 14793
# confetti sash 14793
# automobiles sash 14793
# bumpers sash 14793
# torsion sash 14793
# photons sash 14793
# bundles sash 14793
# electrician sash 14793
# noon sash 14793
# poppy sash 14793
# kettle sash 14793
# whale sash 14793
# extinction sash 14793
# helicobacter sash 14793
# ulcer sash 14793
# ringworm sash 14793
# infantrymen sash 14793
# mania sash 14793
# myth sash 14793
# sender sash 14793
# refrigerator sash 14793
# percentages sash 14793
# syringe sash 14793
# beaker sash 14793
# gaggle sash 14793
# geese sash 14793
# oven sash 14793
# deprivation sash 14793
# backpack sash 14793
# padlock sash 14793
# huddle sash 14793
# charger sash 14793
# suitcase sash 14793
# junk sash 14793
# germs sash 14793
# necklace sash 14793
# crust sash 14793
# sows sash 14793
# palettes sash 14793
# microscope sash 14793
# jatropha sash 14793
# superfamily sash 14793
# nightingales sash 14793
# pythons sash 14793
# thicket sash 14793
# contradictions sash 14793
# beneficiaries sash 14793
# shanks sash 14793
# rake sash 14793
# dragoons sash 14793
# posters sash 14793
# dissimulation sash 14793
# helve sash 14793
# hatchet sash 14793
# wisp sash 14793
# snipes sash 14793
# lifeguard sash 14793
# spirits sash 14793
# midbrain sash 14793
# candle sash 14793
# warmers sash 14793
# bratpack sash 14793
# rout sash 14793
# sentries sash 14793
# dermatitis sash 14793
# itchiness sash 14793
# parodies sash 14793
# rig sash 14793
# vinegar sash 14793
# rout sash 14793
# foes sash 14793
# lid sash 14793
# toxin sash 14793
# camels sash 14793
# sandwiches sash 14793
# knapsack sash 14793
# frustration sash 14793
# phalanx sash 14793
# toe sash 14793
# knob sash 14793
# pochards sash 14793
# raft sash 14793
# turkeys sash 14793
# concerto sash 14793
# wastes sash 14793
# unkindness sash 14793
# pikemen sash 14793
# gunmen sash 14793
# barbels sash 14793
# catfish sash 14793
# lobes sash 14793
# workgangs sash 14793
# deathbed sash 14793
# irritation sash 14793
# jams sash 14793
# marijuana sash 14793
# suitcase sash 14793
# corona sash 14793
# lavas sash 14793
# eruption sash 14793
# prickle sash 14793
# hedgehogs sash 14793
# toolkit sash 14793
# cysts sash 14793
# quiver sash 14793
# chime sash 14793
# rouleau sash 14793
# dairymen sash 14793
# kindle sash 14793
# kittens sash 14793
# antacids sash 14793
# repetition sash 14793
# acupressure sash 14793
# stir sash 14793
# rung sash 14793
# clutter sash 14793
# stuff sash 14793
# spilling sash 14793
# cuffs sash 14793
# lows sash 14793
# executioners sash 14793
# hardship sash 14793
# overflows sash 14793
# clique sash 14793
# oranges sash 14793
# template sash 14793
# scoop sash 14793
# pelicans sash 14793
# bask sash 14793
# crocodiles sash 14793
# ospreys sash 14793
# facades sash 14793
# pleiad sash 14793
# beauties sash 14793
# sacrifices sash 14793
# melter sash 14793
# murderers sash 14793
# swarm sash 14793
# candle sash 14793
# showers sash 14793
# peach sash 14793
# syrup sash 14793
# cleric sash 14793
# kettle sash 14793
# lambs sash 14793
# comradeship sash 14793
# yoke sash 14793
# chronicle sash 14793
# cosmopolites sash 14793
# litho sash 14793
# coma sash 14793
# puppy sash 14793
# candle sash 14793
# toothpick sash 14793
# shoebox sash 14793
# gangster sash 14793
# cancellations sash 14793
# impairment sash 14793
# concatenation sash 14793
# glint sash 14793
# goldfish sash 14793
# wedge sash 14793
# geese sash 14793
# ceramist sash 14793
# rabble sash 14793
# flashbacks sash 14793
# discomfort sash 14793
# cranes sash 14793
# fats sash 14793
# pills sash 14793
# contortions sash 14793
# citations sash 14793
# vinegar sash 14793
# starches sash 14793
# nectar sash 14793
# drawer sash 14793
# phial sash 14793
# blizzards sash 14793
# bouquets sash 14793
# smile sash 14793
# amazement sash 14793
# floats sash 14793
# curbside sash 14793
# cache sash 14793
# overdose sash 14793
# homepage sash 14793
# tutorial sash 14793
# crossbow sash 14793
# rout sash 14793
# phalanx sash 14793
# mug sash 14793
# criticisms sash 14793
# neat sash 14793
# outbreaks sash 14793
# vans sash 14793
# sailor sash 14793
# oxidase sash 14793
# prickle sash 14793
# porcupines sash 14793
# longings sash 14793
# fraudsters sash 14793
# polysilicon sash 14793
# buttock sash 14793
# slugs sash 14793
# helix sash 14793
# applet sash 14793
# apricot sash 14793
# nectar sash 14793
# overpopulation sash 14793
# hydrophone sash 14793
# setbacks sash 14793
# soot sash 14793
# unificationists sash 14793
# coalitions sash 14793
# cupboard sash 14793
# acne sash 14793
# reliance sash 14793
# reconstructions sash 14793
# outsiders sash 14793
# progenitor sash 14793
# flyer sash 14793
# burghers sash 14793
# eruptions sash 14793
# marijuana sash 14793
# tortoise sash 14793
# wrack sash 14793
# seismic sash 14793
# tourniquet sash 14793
# fizzy sash 14793
# substantia sash 14793
# debtors sash 14793
# basket sash 14793
# tripe sash 14793
# alchemists sash 14793
# memoir sash 14793
# peroxisomes sash 14793
# flukes sash 14793
# frustrations sash 14793
# compassion sash 14793
# marmalade sash 14793
# pryde sash 14793
# griffins sash 14793
# chandlers sash 14793
# candles sash 14793
# piezos sash 14793
# spectrometer sash 14793
# corpses sash 14793
# wrappings sash 14793
# rogues sash 14793
# stuffed sash 14793
# dystrophies sash 14793
# caffeine sash 14793
# aberrations sash 14793
# civility sash 14793
# berserkers sash 14793
# trampoline sash 14793
# slugs sash 14793
# katanas sash 14793
# programmers sash 14793
# callus sash 14793
# snowstorm sash 14793
# catastrophe sash 14793
# spirits sash 14793
# glaucoma sash 14793
# germs sash 14793
# influenza sash 14793
# agar sash 14793
# polyethylene sash 14793
# vagina sash 14793
# dilator sash 14793
# omissions sash 14793
# muck sash 14793
# spirits sash 14793
# basket sash 14793
# cigarettes sash 14793
# pitying sash 14793
# turtledoves sash 14793
# pendant sash 14793
# nausea sash 14793
# dissatisfaction sash 14793
# laughing sash 14793
# gimmicks sash 14793
# adenosine sash 14793
# bucket sash 14793
# chisel sash 14793
# marmalade sash 14793
# oranges sash 14793
# geldings sash 14793
# reproof sash 14793
# grenade sash 14793
# steppingmotor sash 14793
# coil sash 14793
# platonists sash 14793
# storytelling sash 14793
# crows sash 14793
# sleeve sash 14793
# misuse sash 14793
# plump sash 14793
# wildfowls sash 14793
# nanotechnology sash 14793
# dataset sash 14793
# surfer sash 14793
# scribe sash 14793
# quire sash 14793
# dessert sash 14793
# vulcano sash 14793
# glaucoma sash 14793
# alcoholism sash 14793
# gulp sash 14793
# cormorants sash 14793
# debtor sash 14793
# redemption sash 14793
# slapshot sash 14793
# agave sash 14793
# nectar sash 14793
# discourse sash 14793
# scissors sash 14793
# randomization sash 14793
# shotguns sash 14793
# carpet sash 14793
# strips sash 14793
# devastations sash 14793
# stent sash 14793
# polyethylene sash 14793
# thinkers sash 14793
# vaccum sash 14793
# jacks sash 14793
# harness sash 14793
# breakouts sash 14793
# harem sash 14793
# turntable sash 14793
# sleeves sash 14793
# sweater sash 14793
# diaphragm sash 14793
# albatross sash 14793
# dissertations sash 14793
# lobe sash 14793
# ginger sash 14793
# extinction sash 14793
# dragoons sash 14793
# telepresence sash 14793
# vial sash 14793
# seismic sash 14793
# suitcase sash 14793
# malware sash 14793
# suitcase sash 14793
# bellowing sash 14793
# bullfinches sash 14793
# jiffy sash 14793
# referees sash 14793
# broom sash 14793
# particulars sash 14793
# pug sash 14793
# quench sash 14793
# effluent sash 14793
# tsunami sash 14793
# suitcase sash 14793
# cricketers sash 14793
# brood sash 14793
# vipers sash 14793
# meteorite sash 14793
# stent sash 14793
# junk sash 14793
# sounder sash 14793
# switchboard sash 14793
# froth sash 14793
# scribe sash 14793
# marshmallow sash 14793
# nitric sash 14793
# horseshoes sash 14793
# blacksmith sash 14793
# screaming sash 14793
# lapse sash 14793
# walkout sash 14793
# hive sash 14793
# cask sash 14793
# padlock sash 14793
# salad sash 14793
# basket sash 14793
# eucharist sash 14793
# cigarettes sash 14793
# secretions sash 14793
# suitcase sash 14793
# cupboard sash 14793
# kilns sash 14793
# geese sash 14793
# flotilla sash 14793
# lorry sash 14793
# cocoa sash 14793
# disarray sash 14793
# raisin sash 14793
# craftsman sash 14793
# hermit sash 14793
# piles sash 14793
# multiword sash 14793
# lorries sash 14793
# suitcase sash 14793
# fingerlings sash 14793
# archaeologists sash 14793
# churn sash 14793
# sect sash 14793
# heretics sash 14793
# brickwork sash 14793
# bricklayer sash 14793
# anemia sash 14793
# curbs sash 14793
# sidewalks sash 14793
# clump sash 14793
# buss sash 14793
# rudders sash 14793
# miscarriage sash 14793
# cohort sash 14793
# shelves sash 14793
# dossier sash 14793
# pod sash 14793
# airmen sash 14793
# attenuator sash 14793
# crate sash 14793
# bracelet sash 14793
# ziplock sash 14793
# candle sash 14793
# wicks sash 14793
# granules sash 14793
# scribe sash 14793
# vat sash 14793
# undulation sash 14793
# pups sash 14793
# goo sash 14793
# sizzle sash 14793
# orbiter sash 14793
# rig sash 14793
# tsunami sash 14793
# discomfort sash 14793
# braces sash 14793
# fireworks sash 14793
# comb sash 14793
# furnace sash 14793
# dames sash 14793
# grate sash 14793
# watermarks sash 14793
# scrawl sash 14793
# raccoons sash 14793
# soy sash 14793
# clothier sash 14793
# refrigerator sash 14793
# hedgehogs sash 14793
# cache sash 14793
# jewels sash 14793
# dentists sash 14793
# sedation sash 14793
# insoles sash 14793
# excerpt sash 14793
# fentermine sash 14793
# ulcers sash 14793
# stethoscope sash 14793
# handgrip sash 14793
# teleworker sash 14793
# outbreaks sash 14793
# jumper sash 14793
# ox sash 14793
# alternators sash 14793
# refrigerator sash 14793
# hailstorm sash 14793
# gunships sash 14793
# nostrils sash 14793
# pamphlet sash 14793
# binder sash 14793
# suitcase sash 14793
# recogniser sash 14793
# mop sash 14793
# wad sash 14793
# husk sash 14793
# hares sash 14793
# pliers sash 14793
# electrician sash 14793
# parcel sash 14793
# clique sash 14793
# renegades sash 14793
# boars sash 14793
# therapist sash 14793
# defendant sash 14793
# heatsink sash 14793
# cutlery sash 14793
# drawer sash 14793
# hibernation sash 14793
# devision sash 14793
# archers sash 14793
# civilisation sash 14793
# coughing sash 14793
# allergies sash 14793
# chai sash 14793
# basket sash 14793
# ferrets sash 14793
# happiness sash 14793
# suitcase sash 14793
# suitcase sash 14793
# obsession sash 14793
# blackmail sash 14793
# wallet sash 14793
# radiology sash 14793
# disasters sash 14793
# masterpiece sash 14793
# basket sash 14793
# butchers sash 14793
# strawberry sash 14793
# syrup sash 14793
# devastations sash 14793
# psittacosis sash 14793
# parrots sash 14793
# harness sash 14793
# microcapsules sash 14793
# spirits sash 14793
# servomotor sash 14793
# outbreaks sash 14793
# ...
# ferret sash 14793
# paw sash 14793
# cradle sash 14793
# farrow sash 14793
# piglets sash 14793
# saws sash 14793
# polonium sash 14793
# tantalum sash 14793
# immunizations sash 14793
# propellor sash 14793
# busloads sash 14793
# contention sash 14793
# sweater sash 14793
# remuda sash 14793
# locusts sash 14793
# bumpers sash 14793
# mischief sash 14793
# acidity sash 14793
# injector sash 14793
# mug sash 14793
# harras sash 14793
# raft sash 14793
# hamper sash 14793
# anecdote sash 14793
# parasites sash 14793
# predominant sash 14793
# societal sash 14793
# swordsmen sash 14793
# narration sash 14793
# clot sash 14793
# fireworks sash 14793
# waiters sash 14793
# mop sash 14793
# lapwings sash 14793
# norms sash 14793
# flapper sash 14793
# amplifier sash 14793
# carafe sash 14793
# citations sash 14793
# wallet sash 14793
# oven sash 14793
# chickenpox sash 14793
# wrinkles sash 14793
# dependencies sash 14793
# disturbances sash 14793
# polyethylene sash 14793
# suitcase sash 14793
# mosaicism sash 14793
# handycam sash 14793
# gelatin sash 14793
# suitcase sash 14793
# wiki sash 14793
# windmills sash 14793
# deleveraging sash 14793
# dizziness sash 14793
# interplay sash 14793
# cytoplasm sash 14793
# fainting sash 14793
# unconsciousness sash 14793
# bevy sash 14793
# doves sash 14793
# pie sash 14793
# pandemic sash 14793
# brilliance sash 14793
# liquids sash 14793
# idiot sash 14793
# exaltation sash 14793
# larks sash 14793
# camaraderie sash 14793
# methadone sash 14793
# buzz sash 14793
# handgun sash 14793
# discourse sash 14793
# lid sash 14793
# rotors sash 14793
# hurts sash 14793
# raft sash 14793
# astronauts sash 14793
# archers sash 14793
# paw sash 14793
# moderator sash 14793
# stricture sash 14793
# scars sash 14793
# parcels sash 14793
# lid sash 14793
# dossier sash 14793
# phrase sash 14793
# gunman sash 14793
# buns sash 14793
# steamer sash 14793
# dehydration sash 14793
# wipes sash 14793
# fling sash 14793
# oxbirds sash 14793
# toxins sash 14793
# odor sash 14793
# reel sash 14793
# electroscope sash 14793
# crayons sash 14793
# rags sash 14793
# receptacle sash 14793
# folder sash 14793
# tonsillitis sash 14793
# hiccups sash 14793
# spasm sash 14793
# biomass sash 14793
# metaphors sash 14793
# mummy sash 14793
# coffins sash 14793
# memes sash 14793
# ossicone sash 14793
# cartilage sash 14793
# pineapples sash 14793
# puppy sash 14793
# garbage sash 14793
# landslides sash 14793
# irritation sash 14793
# humiliation sash 14793
# initiations sash 14793
# abstracts sash 14793
# vapor sash 14793
# swelling sash 14793
# nitrite sash 14793
# scuttle sash 14793
# superfluity sash 14793
# booths sash 14793
# programmers sash 14793
# brew sash 14793
# cauldron sash 14793
# thrushes sash 14793
# technician sash 14793
# shank sash 14793
# vat sash 14793
# dataset sash 14793
# loaf sash 14793
# swelling sash 14793
# bootlegger sash 14793
# staples sash 14793
# clump sash 14793
# prequels sash 14793
# testosterone sash 14793
# quake sash 14793
# tritium sash 14793
# malodor sash 14793
# clashes sash 14793
# patio sash 14793
# coma sash 14793
# stratospheric sash 14793
# laugh sash 14793
# plum sash 14793
# worm sash 14793
# stack sash 14793
# balm sash 14793
# tears sash 14793
# tidbits sash 14793
# trunks sash 14793
# shoal sash 14793
# log- sash 14793
# bloodshed sash 14793
# cheque sash 14793
# flink sash 14793
# evaporators sash 14793
# disputation sash 14793
# biosurfactant sash 14793
# isopropanol sash 14793
# rudders sash 14793
# towboats sash 14793
# iou sash 14793
# sunflower sash 14793
# cerebrum sash 14793
# hemispheres sash 14793
# clowder sash 14793
# casing sash 14793
# nucleocapsids sash 14793
# hornets sash 14793
# camels sash 14793
# niece sash 14793
# coals sash 14793
# acne sash 14793
# moons sash 14793
# sleeve sash 14793
# pail sash 14793
# interrogation sash 14793
# nuts sash 14793
# resistors sash 14793
# turrets sash 14793
# stew sash 14793
# cauldron sash 14793
# sedge sash 14793
# bitterns sash 14793
# phosphorus sash 14793
# furnace sash 14793
# thermostat sash 14793
# mover sash 14793
# hamburger sash 14793
# wallet sash 14793
# desserts sash 14793
# irritation sash 14793
# flakeboard sash 14793
# guardrail sash 14793
# princesses sash 14793
# marijuana sash 14793
# thermostat sash 14793
# refrigerator sash 14793
# metamorphism sash 14793
# phalanx sash 14793
# comrades sash 14793
# flange sash 14793
# baboons sash 14793
# mastiffs sash 14793
# potentiometer sash 14793
# nide sash 14793
# pheasants sash 14793
# monsoons sash 14793
# sadness sash 14793
# padding sash 14793
# fridge sash 14793
# hallucinogens sash 14793
# chills sash 14793
# joke sash 14793
# whisky sash 14793
# cistern sash 14793
# liquids sash 14793
# catapult sash 14793
# decedent sash 14793
# blaze sash 14793
# bean sash 14793
# reels sash 14793
# jug sash 14793
# paddle sash 14793
# canister sash 14793
# plurality sash 14793
# sugars sash 14793
# catheter sash 14793
# vaccines sash 14793
# motives sash 14793
# arbitrator sash 14793
# acne sash 14793
# oily sash 14793
# acne sash 14793
# canteen sash 14793
# sandalwood sash 14793
# coil sash 14793
# galvanometer sash 14793
# rabble sash 14793
# receptacle sash 14793
# cerebellum sash 14793
# pillow sash 14793
# foam sash 14793
# unread sash 14793
# remnant sash 14793
# epochs sash 14793
# keyframe sash 14793
# blackboard sash 14793
# fairies sash 14793
# syrup sash 14793
# cask sash 14793
# rainbows sash 14793
# refraction sash 14793
# candlestick sash 14793
# archers sash 14793
# burner sash 14793
# dryer sash 14793
# humpback sash 14793
# flipper sash 14793
# bakers sash 14793
# frosting sash 14793
# contractions sash 14793
# prostaglandins sash 14793
# folks sash 14793
# twilight sash 14793
# casket sash 14793
# casket sash 14793
# suitcase sash 14793
# sweeper sash 14793
# abridger sash 14793
# cupboard sash 14793
# brood sash 14793
# grower sash 14793
# moldboard sash 14793
# handbags sash 14793
# timers sash 14793
# faiths sash 14793
# dule sash 14793
# turkeys sash 14793
# hemiparesis sash 14793
# obesity sash 14793
# frontpage sash 14793
# reliquary sash 14793
# blank sash 14793
# carton sash 14793
# meinie sash 14793
# sparrows sash 14793
# salad sash 14793
# transformer sash 14793
# impulsivity sash 14793
# cadre sash 14793
# sleeve sash 14793
# blouse sash 14793
# metaphor sash 14793
# paragraph sash 14793
# anthology sash 14793
# bastard sash 14793
# dentist sash 14793
# proverb sash 14793
# molds sash 14793
# storylines sash 14793
# padlock sash 14793
# caisson sash 14793
# mallet sash 14793
# ultrasound sash 14793
# lathe sash 14793
# deterioration sash 14793
# canister sash 14793
# glitch sash 14793
# horde sash 14793
# hackers sash 14793
# latency sash 14793
# pointer sash 14793
# oatmeal sash 14793
# cookies sash 14793
# clamour sash 14793
# rooks sash 14793
# grenade sash 14793
# intellect sash 14793
# baboons sash 14793
# coughing sash 14793
# inhaling sash 14793
# profligates sash 14793
# intestine sash 14793
# dishwasher sash 14793
# suitcase sash 14793
# facemasks sash 14793
# basket sash 14793
# collagen sash 14793
# shavings sash 14793
# keypad sash 14793
# vest sash 14793
# dangers sash 14793
# slit sash 14793
# sailor sash 14793
# cudgel sash 14793
# menage sash 14793
# pads sash 14793
# peanut sash 14793
# cookies sash 14793
# lumberjacks sash 14793
# epistemology sash 14793
# cupboard sash 14793
# hourglass sash 14793
# pandemic sash 14793
# switchboard sash 14793
# cheeses sash 14793
# acne sash 14793
# irritants sash 14793
# filename sash 14793
# verbalizations sash 14793
# anthology sash 14793
# sadness sash 14793
# dissatisfaction sash 14793
# hinge sash 14793
# oyster sash 14793
# fitter sash 14793
# frustration sash 14793
# debugging sash 14793
# screaming sash 14793
# excerpt sash 14793
# rhyme sash 14793
# cask sash 14793
# papillomavirus sash 14793
# warts sash 14793
# meteor sash 14793
# coughing sash 14793
# suffocation sash 14793
# derivation sash 14793
# extinction sash 14793
# duckling sash 14793
# stethoscope sash 14793
# baboons sash 14793
# coma sash 14793
# devastation sash 14793
# sleeve sash 14793
# coil sash 14793
# fetus sash 14793
# ticks sash 14793
# discomfort sash 14793
# shovel sash 14793
# laptop sash 14793
# disarray sash 14793
# convicts sash 14793
# hounds sash 14793
# copse sash 14793
# paragraphs sash 14793
# frig sash 14793
# cabal sash 14793
# murderers sash 14793
# derailment sash 14793
# devastation sash 14793
# roundtables sash 14793
# suitcase sash 14793
# cockatiel sash 14793
# ferrets sash 14793
# slices sash 14793
# basket sash 14793
# ubiquity sash 14793
# sparrows sash 14793
# osteoarthitis sash 14793
# lactoferrin sash 14793
# turnip sash 14793
# tutorial sash 14793
# necklace sash 14793
# giraffes sash 14793
# lice sash 14793
# infestation sash 14793
# undulation sash 14793
# directory sash 14793
# reads sash 14793
# dotterel sash 14793
# cognac sash 14793
# chickens sash 14793
# snarl sash 14793
# covey sash 14793
# grouse sash 14793
# curate sash 14793
# blackcurrent sash 14793
# shaman sash 14793
# believers sash 14793
# boars sash 14793
# pod sash 14793
# interferon sash 14793
# verb sash 14793
# tsunami sash 14793
# robe sash 14793
# rabble sash 14793
# appetites sash 14793
# cancellations sash 14793
# motet sash 14793
# cornucopia sash 14793
# predisposition sash 14793
# poultry sash 14793
# sleeve sash 14793
# flask sash 14793
# solute sash 14793
# micelle sash 14793
# emission sash 14793
# swordsmen sash 14793
# caisson sash 14793
# quake sash 14793
# swarm sash 14793
# devastation sash 14793
# martyrdom sash 14793
# huddle sash 14793
# hens sash 14793
# cigars sash 14793
# humidor sash 14793
# gossipers sash 14793
# beaker sash 14793
# pikemen sash 14793
# metrosexuals sash 14793
# moisturizers sash 14793
# grenadiers sash 14793
# blonde sash 14793
# rig sash 14793
# meatballs sash 14793
# phrase sash 14793
# tapir sash 14793
# hoof sash 14793
# carafe sash 14793
# dulcimers sash 14793
# jeans sash 14793
# pineapple sash 14793
# swarm sash 14793
# beavers sash 14793
# ointment sash 14793
# eyelid sash 14793
# rhinoceroses sash 14793
# kerosene sash 14793
# forkful sash 14793
# suitcase sash 14793
# junk sash 14793
# lactic sash 14793
# dextrose sash 14793
# backpack sash 14793
# laptop sash 14793
# nanotubes sash 14793
# disuse sash 14793
# hilt sash 14793
# katana sash 14793
# ambition sash 14793
# devastation sash 14793
# tsunami sash 14793
# scars sash 14793
# grits sash 14793
# banduras sash 14793
# skein sash 14793
# geese sash 14793
# manna sash 14793
# musketeers sash 14793
# quarrel sash 14793
# backfill sash 14793
# apostrophes sash 14793
# messenger sash 14793
# trash sash 14793
# shower sash 14793
# spanner sash 14793
# artworks sash 14793
# mishandling sash 14793
# creditors sash 14793
# candies sash 14793
# shortages sash 14793
# donkeys sash 14793
# quake sash 14793
# disuse sash 14793
# sord sash 14793
# mallards sash 14793
# aristocrats sash 14793
# anthology sash 14793
# scaffold sash 14793
# coughing sash 14793
# appendix sash 14793
# workpackage sash 14793
# forepaw sash 14793
# artisan sash 14793
# burin sash 14793
# suitcase sash 14793
# broom sash 14793
# mews sash 14793
# carp sash 14793
# ewer sash 14793
# joystick sash 14793
# chimpanzees sash 14793
# teflon sash 14793
# tsunami sash 14793
# ignorance sash 14793
# nunt sash 14793
# horseshoes sash 14793
# blacksmiths sash 14793
# kidneys sash 14793
# stratosphere sash 14793
# bowels sash 14793
# cleaners sash 14793
# gestures sash 14793
# nosebleeds sash 14793
# redcurrent sash 14793
# syrup sash 14793
# sweater sash 14793
# brew sash 14793
# kettle sash 14793
# cadre sash 14793
# swordsmen sash 14793
# tankard sash 14793
# appellant sash 14793
# malice sash 14793
# tenacity sash 14793
# asses sash 14793
# infestation sash 14793
# fleas sash 14793
# roms sash 14793
# antiboitics sash 14793
# acne sash 14793
# hormonal sash 14793
# coupling sash 14793
# fragment sash 14793
# ligature sash 14793
# benchmarking sash 14793
# cadre sash 14793
# shovel sash 14793
# gardeners sash 14793
# submersible sash 14793
# inpatients sash 14793
# anecdotes sash 14793
# kits sash 14793
# forebrain sash 14793
# freezer sash 14793
# paddling sash 14793
# freighter sash 14793
# dope sash 14793
# froggery sash 14793
# frogs sash 14793
# evangelist sash 14793
# motions sash 14793
# dynamite sash 14793
# blasting sash 14793
# hairstyles sash 14793
# eruption sash 14793
# rafts sash 14793
# foundry sash 14793
# upwelling sash 14793
# flashbacks sash 14793
# shampoos sash 14793
# quip sash 14793
# riffraff sash 14793
# savages sash 14793
# woofers sash 14793
# avenger sash 14793
# horde sash 14793
# believers sash 14793
# shovel sash 14793
# posters sash 14793
# treatise sash 14793
# theorist sash 14793
# creditor sash 14793
# laughter sash 14793
# joke sash 14793
# ornaments sash 14793
# molds sash 14793
# eyewitness sash 14793
# fevers sash 14793
# headset sash 14793
# hydrants sash 14793
# influenza sash 14793
# wrinkles sash 14793
# laughing sash 14793
# spirits sash 14793
# dray sash 14793
# squirrels sash 14793
# reagent sash 14793
# weaknesses sash 14793
# screwdriver sash 14793
# robbers sash 14793
# kiosks sash 14793
# nuzzle sash 14793
# scribe sash 14793
# caisson sash 14793
# methamphetamine sash 14793
# bungalow sash 14793
# creeps sash 14793
# astronauts sash 14793
# hutch sash 14793
# agarose sash 14793
# tray sash 14793
# drawer sash 14793
# boxcar sash 14793
# tempeh sash 14793
# soybeans sash 14793
# whirl sash 14793
# tessellate sash 14793
# respondents sash 14793
# abscess sash 14793
# evaluations sash 14793
# barium sash 14793
# sulphate sash 14793
# preforms sash 14793
# bottles sash 14793
# flask sash 14793
# acetoin sash 14793
# filtrate sash 14793
# fable sash 14793
# programmers sash 14793
# technocrats sash 14793
# notification sash 14793
# misfits sash 14793
# knob sash 14793
# fury sash 14793
# suitcase sash 14793
# wriggle sash 14793
# raspberry sash 14793
# residues sash 14793
# asthma sash 14793
# narrowing sash 14793
# invertebrate sash 14793
# halves sash 14793
# hoe sash 14793
# influenza sash 14793
# imbalance sash 14793
# timer sash 14793
# robbers sash 14793
# clique sash 14793
# acquaintances sash 14793
# senses sash 14793
# radiator sash 14793
# rookery sash 14793
# glossy sash 14793
# mailbox sash 14793
# devastation sash 14793
# rash sash 14793
# fungal sash 14793
# neuron sash 14793
# jolt sash 14793
# basket sash 14793
# proletariat sash 14793
# nationalities sash 14793
# bong sash 14793
# skirt sash 14793
# electricians sash 14793
# grenade sash 14793
# canister sash 14793
# yachts sash 14793
# demonstrator sash 14793
# cuirassiers sash 14793
# hookup sash 14793
# emails sash 14793
# rites sash 14793
# wares sash 14793
# straw sash 14793
# crocodile sash 14793
# cough sash 14793
# tsunamis sash 14793
# irritants sash 14793
# coughing sash 14793
# carton sash 14793
# blisters sash 14793
# timestamp sash 14793
# pikemen sash 14793
# slipcase sash 14793
# ewer sash 14793
# knob sash 14793
# maternity sash 14793
# antennas sash 14793
# homemade sash 14793
# cranberry sash 14793
# chocolates sash 14793
# acne sash 14793
# gunshot sash 14793
# spaghetti sash 14793
# braces sash 14793
# coughing sash 14793
# allergies sash 14793
# overpopulation sash 14793
# pillar sash 14793
# stir sash 14793
# blacksmith sash 14793
# whisky sash 14793
# chuckle sash 14793
# beaker sash 14793
# dragoons sash 14793
# pail sash 14793
# deformation sash 14793
# headaches sash 14793
# allergies sash 14793
# constable sash 14793
# grenade sash 14793
# glossary sash 14793
# remark sash 14793
# craftsperson sash 14793
# grammars sash 14793
# ulcers sash 14793
# defendant sash 14793
# fisherman sash 14793
# inconvenience sash 14793
# nausea sash 14793
# sweetcorn sash 14793
# cobs sash 14793
# couverture sash 14793
# reliquary sash 14793
# insulation sash 14793
# snowdrifts sash 14793
# sparrows sash 14793
# napkin sash 14793
# clot sash 14793
# seizure sash 14793
# microwaves sash 14793
# brew sash 14793
# cherries sash 14793
# flippers sash 14793
# leash sash 14793
# nail sash 14793
# boredom sash 14793
# clowns sash 14793
# wainwright sash 14793
# pendant sash 14793
# mainspring sash 14793
# blaze sash 14793
# nostrils sash 14793
# bubbles sash 14793
# thugs sash 14793
# complication sash 14793
# irradiation sash 14793
# drippings sash 14793
# sauerkraut sash 14793
# hiring sash 14793
# beers sash 14793
# vial sash 14793
# dule sash 14793
# doves sash 14793
# hypertension sash 14793
# chatrooms sash 14793
# cauldron sash 14793
# mobiles sash 14793
# chatting sash 14793
# figurine sash 14793
# coolant sash 14793
# sorrow sash 14793
# sleeve sash 14793
# sweater sash 14793
# endometriosis sash 14793
# infertility sash 14793
# clogging sash 14793
# dips sash 14793
# fragment sash 14793
# conies sash 14793
# cutlery sash 14793
# wallet sash 14793
# ales sash 14793
# suitcase sash 14793
# suitcase sash 14793
# hutch sash 14793
# woofer sash 14793
# polynucleotide sash 14793
# kinematics sash 14793
# pens sash 14793
# tankard sash 14793
# skydivers sash 14793
# rouleau sash 14793
# sovereigns sash 14793
# brandy sash 14793
# juices sash 14793
# demerol sash 14793
# skins sash 14793
# poisonings sash 14793
# myth sash 14793
# pluralism sash 14793
# lioness sash 14793
# caveats sash 14793
# wolfpack sash 14793
# shovels sash 14793
# sadness sash 14793
# maze sash 14793
# catacombs sash 14793
# bloat sash 14793
# hippopotamuses sash 14793
# broom sash 14793
# casket sash 14793

# %%
max_seq_len = max([len(path) for path in train['sdps']+valid['sdps']+test['sdps']])
print(max_seq_len, DH.max_seq_len)
DH.max_seq_len = max_seq_len
# Out:
# 13 9

# %%
# the embedding matrix is started of as random uniform [-1,1]
# then we replace everything but the OOV tokens with the approprate google vector
word_embeddings = np.random.uniform(low=-1., high=1., size=[DH.vocab_size, 300]).astype(np.float32)
num_found = 0
for i, token in enumerate(DH.vocab):
    if token in word2vec:
        word_embeddings[i] = word2vec[token]
        num_found += 1
print("%i / %i pretrained" % (num_found, DH.vocab_size))
# Out:
# 13215 / 14798 pretrained

# %%
config = {
    'max_num_steps':DH.max_seq_len,
    'word_embed_size':300,
    'dep_embed_size':25,
    'vocab_size':DH.vocab_size,
    'dep_vocab_size':DH.dep_size,
    'num_predict_classes':num_classes,
    'pretrained_word_embeddings':word_embeddings,
    'max_grad_norm':3.,
    'model_name':'drnn_wiki_semeval_w2v',
    'checkpoint_prefix':'checkpoints/',
    'summary_prefix':'tensor_summaries/'
}
try:
    tf.reset_default_graph()
except:
    pass
try:
    tf.get_default_session().close()
except:
    pass
drnn = RelEmbed(config)
print(drnn)
# Out:
# <DPNN: W:300, D:25, H:600, V:14798>

# %%
def run_validation_test(num_nearby=20):
    valid_phrases, valid_targets , _, valid_lens = DH.validation_batch()
    random_index = int(random.uniform(0, len(valid_lens)))
    query_phrase = valid_phrases[random_index]
    query_len = valid_lens[random_index]
    query_target = valid_targets[random_index]
    padded_qp = np.zeros([DH.max_seq_len, 2]).astype(np.int32)
    padded_qp[:len(query_phrase), 0] = [x[0] for x in query_phrase]
    padded_qp[:len(query_phrase), 1] = [x[1] for x in query_phrase]    
    dists, phrase_idx = drnn.validation_phrase_nearby(padded_qp, query_len, valid_phrases, valid_lens)
    print("="*80)
    print("Top %i closest phrases to <%s> '%s' <%s>" 
          % (num_nearby, DH.vocab_at(query_target[0]), 
             DH.sequence_to_sentence(query_phrase, query_len), 
             DH.vocab_at(query_target[1])))
    for i in range(num_nearby):
        dist = dists[i]
        phrase = valid_phrases[phrase_idx[i]]
        len_ = valid_lens[phrase_idx[i]]
        target = valid_targets[phrase_idx[i]]
        print("%i: %0.3f : <%s> '%s' <%s>" 
              % (i, dist, DH.vocab_at(target[0]),
                 DH.sequence_to_sentence(phrase, len_),
                 DH.vocab_at(target[1])))
    print("="*80)
#     drnn.save_validation_accuracy(frac_correct)

# %%
def time_left(num_epochs, num_steps, fit_time, nearby_time, start_time, nearby_mod):
    total = num_epochs*num_steps*fit_time + ((num_epochs*num_steps)/float(nearby_mod))*nearby_time
    return total - (time() - start_time)

# %% [markdown]
# # Unsupervised Training

# %%
# hyperparameters
num_epochs = 1
batch_size =50
neg_per = 25
num_nearby = 50
nearby_mod = 50
sample_power = .75
DH.scale_vocab_dist(sample_power)

# bookkeeping
num_steps = DH.num_steps(batch_size)
total_step = 1
save_interval = 30 * 60 # half hour in seconds
save_time = time()

#timing stuff
start = time()
fit_time = 0
nearby_time = 0

for epoch in range(num_epochs):
    offset = 0 #if epoch else 400
    DH.shuffle_data()
    for step , batch in enumerate(DH.batches(batch_size, offset=offset, neg_per=neg_per)):
        if not step: step = offset
        t0 = time()
        loss = drnn.partial_unsup_fit(*batch)
        fit_time = (fit_time * float(total_step) +  time() - t0) / (total_step + 1) # running average
        if step % 10 == 0:
            m,s = divmod(time()-start, 60)
            h,m = divmod(m, 60)
            left = time_left(num_epochs, num_steps, fit_time, nearby_time, start, nearby_mod)
            ml,sl = divmod(left, 60)
            hl,ml = divmod(ml, 60)
            pps = batch_size*(neg_per + 1) / fit_time 
            print("(%i:%i:%i) step %i/%i, epoch %i Training Loss = %1.5f :: %0.3f phrases/sec :: (%i:%i:%i) hours left" 
                  % (h,m,s, step, num_steps, epoch, loss, pps, hl, ml, sl))
        if (total_step-1) % nearby_mod == 0: # do one right away so we get a good timing estimate
            t0 = time()
            run_validation_test(num_nearby) # check out the nearby phrases in the validation set
            valid_loss = drnn.validation_loss(*DH.validation_batch())
            print("Validation loss: %0.4f" % valid_loss)
            nearby_time = (nearby_time * float(total_step) + time() - t0) / (total_step + 1) # running average

        if (time() - save_time) > save_interval:
            print("Saving model...")
            drnn.checkpoint()
            save_time = time()
        total_step +=1
drnn.checkpoint()
# Out:
# (0:0:7) step 0/10311, epoch 0 Training Loss = 0.24386 :: 1176.826 phrases/sec :: (3:9:42) hours left
# ================================================================================
# Top 50 closest phrases to <conjunction> '<X> with systems track <Y>' <systems>
# 0: 1.000 : <conjunction> '<X> with systems track <Y>' <systems>
# 1: 0.991 : <weapons> '<X> is systems for <Y>' <army>
# 2: 0.989 : <archdiocese> '<X> in based with <Y>' <dioceses>
# 3: 0.988 : <length> '<X> is running from <Y>' <source>
# 4: 0.988 : <versions> '<X> release called with <Y>' <buffers>
# 5: 0.988 : <director> '<X> systems for <Y>' <intelligence>
# 6: 0.988 : <who> '<X> is out from <Y>' <sentence>
# 7: 0.988 : <foundation> '<X> promotes system for <Y>' <management>
# 8: 0.987 : <event> '<X> events two in <Y>' <kong>
# 9: 0.987 : <season> '<X> end finishing with <Y>' <wickets>
# 10: 0.987 : <m> '<X> in established with <Y>' <time>
# 11: 0.987 : <city> '<X> in located with <Y>' <offices>
# 12: 0.987 : <factory> '<X> factory date from <Y>' <1940s>
# 13: 0.987 : <rivals> '<X> as designated with <Y>' <syracuse>
# 14: 0.987 : <he> '<X> was with <Y>' <pick>
# 15: 0.987 : <it> '<X> was installed in <Y>' <rings>
# 16: 0.987 : <speeds> '<X> as engaged with <Y>' <clutch>
# 17: 0.987 : <half> '<X> be campus for <Y>' <heights>
# 18: 0.987 : <public> '<X> in performing with <Y>' <bands>
# 19: 0.987 : <division> '<X> in were with <Y>' <time>
# 20: 0.987 : <growth> '<X> with is <Y>' <india>
# 21: 0.987 : <ceramics> '<X> indicate date in <Y>' <dynasty>
# 22: 0.987 : <fort> '<X> from take with <Y>' <sea>
# 23: 0.987 : <centre> '<X> as benefits from <Y>' <days>
# 24: 0.987 : <season> '<X> for returning with <Y>' <harbour>
# 25: 0.986 : <name> '<X> combines as in <Y>' <example>
# 26: 0.986 : <dorsum> '<X> with connected by <Y>' <patch>
# 27: 0.986 : <they> '<X> run operations in <Y>' <wing>
# 28: 0.986 : <they> '<X> are used by <Y>' <riders>
# 29: 0.986 : <he> '<X> began working for <Y>' <cards>
# 30: 0.986 : <weapons> '<X> put come with <Y>' <hands>
# 31: 0.986 : <songs> '<X> learn go with <Y>' <him>
# 32: 0.986 : <october> '<X> on confirmed by <Y>' <vote>
# 33: 0.986 : <hero> '<X> is in <Y>' <imagination>
# 34: 0.986 : <groups> '<X> have in <Y>' <russia>
# 35: 0.986 : <states> '<X> state original over <Y>' <suits>
# 36: 0.986 : <christ> '<X> were utilized in <Y>' <practices>
# 37: 0.986 : <government> '<X> announced building system for <Y>' <backbone>
# 38: 0.986 : <who> '<X> had make at <Y>' <ceremony>
# 39: 0.986 : <january> '<X> on called for <Y>' <country>
# 40: 0.986 : <skaters> '<X> be present on <Y>' <ice>
# 41: 0.986 : <record> '<X> set with <Y>' <reception>
# 42: 0.986 : <him> '<X> with were on <Y>' <occasion>
# 43: 0.986 : <november> '<X> on won with <Y>' <%>
# 44: 0.986 : <july> '<X> in wrote as <Y>' <man>
# 45: 0.986 : <sloan> '<X> by started in <Y>' <attempt>
# 46: 0.986 : <beginning> '<X> at request in <Y>' <place>
# 47: 0.986 : <firmly> '<X> established with <Y>' <devotion>
# 48: 0.986 : <region> '<X> been area for <Y>' <arrival>
# 49: 0.986 : <march> '<X> in signed with <Y>' <town>
# ================================================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-199-bd1d24c80898> in <module>()
#      39             t0 = time()
#      40             run_validation_test(num_nearby) # check out the nearby phrases in the validation set
# ---> 41             valid_loss = drnn.validation_loss(*DH.validation_batch())
#      42             print("Validation loss: %0.4f" % valid_loss)
#      43             nearby_time = (nearby_time * float(total_step) + time() - t0) / (total_step + 1) # running average
#
# <ipython-input-64-4099403ccf06> in validation_loss(self, valid_phrases, valid_targets, valid_labels, valid_lengths)
#     308                                             self._input_targets:valid_targets,
#     309                                             self._input_labels:valid_labels,
# --> 310                                             self._input_lengths:valid_lengths})
#     311         self.summary_writer.add_summary(v_summary)
#     312         return loss
#
# /Users/thomaseffland/.virtualenvs/rel/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict)
#     313         `Tensor` that doesn't exist.
#     314     """
# --> 315     return self._run(None, fetches, feed_dict)
#     316
#     317   def partial_run(self, handle, fetches, feed_dict=None):
#
# /Users/thomaseffland/.virtualenvs/rel/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict)
#     509     # Run request and get response.
#     510     results = self._do_run(handle, target_list, unique_fetches,
# --> 511                            feed_dict_string)
#     512
#     513     # User may have fetched the same tensor multiple times, but we
#
# /Users/thomaseffland/.virtualenvs/rel/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict)
#     562     if handle is None:
#     563       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 564                            target_list)
#     565     else:
#     566       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/thomaseffland/.virtualenvs/rel/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#     569   def _do_call(self, fn, *args):
#     570     try:
# --> 571       return fn(*args)
#     572     except tf_session.StatusNotOK as e:
#     573       e_type, e_value, e_traceback = sys.exc_info()
#
# /Users/thomaseffland/.virtualenvs/rel/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list)
#     553       # Ensure any changes to the graph are reflected in the runtime.
#     554       self._extend_graph()
# --> 555       return tf_session.TF_Run(session, feed_dict, fetch_list, target_list)
#     556
#     557     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
drnn.checkpoint()

# %%
# # test the embeddings

# ### VALID ###
# # valid_phrases, valid_targets, _, valid_lens = DH.validation_batch()
# # phrase_embeds, target_embeds = drnn.embed_phrases_and_targets(valid_phrases, valid_targets, valid_lens)
# # phrase_labels, target_labels = DH.readable_data(valid=True)

# ### TRAIN ###
# train_phrases, train_targets, _, train_lens = DH.batches(500, neg_per=0, offset=0).next()
# phrase_embeds, target_embeds = drnn.embed_phrases_and_targets(train_phrases, train_targets, train_lens)
# phrase_labels, target_labels = DH.readable_data(show_dep=False, valid=False)
        
# phrase_embeds /= np.sqrt(np.sum(phrase_embeds**2, 1, keepdims=True))
# target_embeds /= np.sqrt(np.sum(target_embeds**2, 1, keepdims=True))

# %%
# ### JOINT ###
# start = 0
# stride = 40
# end = start + stride

# lowd = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
# # lowd = PCA(n_components=2)

# joint_embeds = np.vstack([phrase_embeds[start:end], target_embeds[start:end]])
# joint_2d = lowd.fit_transform(joint_embeds)
# phrase_2d, target_2d = joint_2d[:stride], joint_2d[stride:]

# fig, ax = plt.subplots(figsize=(20,16))
# for i, label in enumerate(phrase_labels[start:end]):
#     label = "%i: %s" % (i, label)
#     x, y = phrase_2d[i,:]
#     ax.scatter(x, y, color='b')
#     ax.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
#                    ha='right', va='bottom')
# for i, label in enumerate(target_labels[start:end]):
#     label = "%i: %s" % (i, label)
#     x, y = target_2d[i,:]
#     ax.scatter(x, y, color='r')
#     ax.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
#                    ha='right', va='bottom')

# %%
# ### PHRASE ONLY ###
# start = 0
# stride = 50
# end = start + stride

# lowd = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
# # lowd = PCA(n_components=2)

# phrase_2d = lowd.fit_transform(phrase_embeds[start:end])

# fig, ax = plt.subplots(figsize=(20,16))
# for i, label in enumerate(phrase_labels[start:end]):
#     label = "%i: %s" % (i, label)
#     x, y = phrase_2d[i,:]
#     ax.scatter(x, y, color='b')
#     ax.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
#                    ha='right', va='bottom')

# %%
# ### TARGET ONLY ###
# start = 0
# stride = 35
# end = start + stride

# lowd = TSNE(perplexity=20, n_components=2, init='pca', n_iter=5000)
# # lowd = PCA(n_components=2)

# target_2d = lowd.fit_transform(target_embeds[start:end])

# fig, ax = plt.subplots(figsize=(20,16))
# for i, label in enumerate(target_labels[start:end]):
#     label = "%i: %s" % (i, label)
#     x, y = target_2d[i,:]
#     ax.scatter(x, y, color='r')
#     ax.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
#                    ha='right', va='bottom')

# %% [markdown]
# # Test out semeval data

# %%
zip_train = zip(train['raws'], train['sents'], train['sdps'], train['targets'], train['labels'])
zip_valid = zip(valid['raws'], valid['sents'], valid['sdps'], valid['targets'], valid['labels'])
zip_test = zip(test['raws'], test['sents'], test['sdps'], test['targets'])

# %%
for i, (raw, _, sdp, target, label) in enumerate(zip_train):
    if i > 5:
        break
    print(raw)
    print("%s :: %s" % (DH.sequence_to_sentence(sdp, show_dep=True), DH.sequence_to_sentence(target)))
    print(int2label[label])
    print("="*80)
# Out:
# 1	"The system as described above has its greatest application in an arrayed <e1>configuration</e1> of antenna <e2>elements</e2>."
#
# (<X>, pobj) (of, prep) (<Y>, pobj) :: configuration elements
# Component-Whole(e2,e1)
# ================================================================================
# 2	"The <e1>child</e1> was carefully wrapped and bound into the <e2>cradle</e2> by means of a cord."
#
# (<X>, nsubjpass) (wrapped, ROOT) (bound, conj) (into, prep) (<Y>, pobj) :: child sash
# Other
# ================================================================================
# 3	"The <e1>author</e1> of a keygen uses a <e2>disassembler</e2> to look at the raw assembly code."
#
# (<X>, nsubj) (uses, ROOT) (<Y>, dobj) :: author sash
# Instrument-Agency(e2,e1)
# ================================================================================
# 4	"A misty <e1>ridge</e1> uprises from the <e2>surge</e2>."
#
# (<X>, nsubj) (sash, ROOT) (from, prep) (<Y>, pobj) :: ridge surge
# Other
# ================================================================================
# 5	"The <e1>student</e1> <e2>association</e2> is the voice of the undergraduate student population of the State University of New York at Buffalo."
#
# (<X>, compound) (<Y>, nsubj) :: student association
# Member-Collection(e1,e2)
# ================================================================================
# 6	"This is the sprawling <e1>complex</e1> that is Peru's largest <e2>producer</e2> of silver."
#
# (<X>, attr) (is, relcl) (<Y>, attr) :: complex producer
# Other
# ================================================================================

# %% [markdown]
# # Supervised Training

# %%
batch_size = 50
num_steps = len(train['labels']) // batch_size
num_epochs = 5
display_mod = 10
valid_mod = 50

start = time()
for epoch in range(num_epochs):
    for step in range(num_steps): # num_steps
        class_batch = DH.classification_batch(batch_size, train['sdps'], train['targets'], train['labels'], offset=step)
        xent = drnn.partial_class_fit(*class_batch)
        if step % display_mod == 0:   
            m,s = divmod(time()-start, 60)
            h,m = divmod(m, 60)
            print("(%i:%i:%i) s %i/%i, e %i avg class xent loss = %0.4f" % (h,m,s, step, num_steps, epoch, xent))
        if step % valid_mod == 0:
            valid_batch = DH.classification_batch(len(valid['labels']), valid['sdps'], valid['targets'], valid['labels'])
            valid_xent = drnn.validation_class_loss(*valid_batch)
            m,s = divmod(time()-start, 60)
            h,m = divmod(m, 60)
            print("="*80)
            print("(%i:%i:%i) s %i/%i, e %i validation avg class xent loss = %0.4f" % (h,m,s, step, num_steps, epoch, valid_xent))
            print("="*80)
            print("Saving model...")
            drnn.checkpoint()
drnn.checkpoint()
# Out:
# (0:0:0) s 0/142, e 0 avg class xent loss = 0.9954
# ================================================================================
# (0:0:0) s 0/142, e 0 validation avg class xent loss = 12.4459
# ================================================================================
# Saving model...
# (0:0:7) s 10/142, e 0 avg class xent loss = 6.0190
# (0:0:10) s 20/142, e 0 avg class xent loss = 1.5233
# (0:0:14) s 30/142, e 0 avg class xent loss = 3.2322
# (0:0:17) s 40/142, e 0 avg class xent loss = 1.4752
# (0:0:21) s 50/142, e 0 avg class xent loss = 3.4503
# ================================================================================
# (0:0:21) s 50/142, e 0 validation avg class xent loss = 12.8794
# ================================================================================
# Saving model...
# (0:0:27) s 60/142, e 0 avg class xent loss = 2.5219
# (0:0:31) s 70/142, e 0 avg class xent loss = 2.4105
# (0:0:34) s 80/142, e 0 avg class xent loss = 2.4634
# (0:0:38) s 90/142, e 0 avg class xent loss = 1.0999
# (0:0:42) s 100/142, e 0 avg class xent loss = 1.8453
# ================================================================================
# (0:0:42) s 100/142, e 0 validation avg class xent loss = 14.1346
# ================================================================================
# Saving model...
# (0:0:48) s 110/142, e 0 avg class xent loss = 2.0064
# (0:0:52) s 120/142, e 0 avg class xent loss = 8.2194
# (0:0:56) s 130/142, e 0 avg class xent loss = 1.8065
# (0:0:59) s 140/142, e 0 avg class xent loss = 4.6002
# (0:1:0) s 0/142, e 1 avg class xent loss = 1.7109
# ================================================================================
# (0:1:1) s 0/142, e 1 validation avg class xent loss = 13.7823
# ================================================================================
# Saving model...
# (0:1:12) s 10/142, e 1 avg class xent loss = 4.4495
# (0:1:16) s 20/142, e 1 avg class xent loss = 1.1288
# (0:1:20) s 30/142, e 1 avg class xent loss = 2.9862
# (0:1:23) s 40/142, e 1 avg class xent loss = 0.4920
# (0:1:27) s 50/142, e 1 avg class xent loss = 3.0498
# ================================================================================
# (0:1:28) s 50/142, e 1 validation avg class xent loss = 12.8165
# ================================================================================
# Saving model...
# (0:1:35) s 60/142, e 1 avg class xent loss = 1.0815
# (0:1:38) s 70/142, e 1 avg class xent loss = 1.0593
# (0:1:42) s 80/142, e 1 avg class xent loss = 2.0913
# (0:1:46) s 90/142, e 1 avg class xent loss = 0.6119
# (0:1:49) s 100/142, e 1 avg class xent loss = 2.0775
# ================================================================================
# (0:1:50) s 100/142, e 1 validation avg class xent loss = 14.7929
# ================================================================================
# Saving model...
# (0:1:56) s 110/142, e 1 avg class xent loss = 1.8015
# (0:2:0) s 120/142, e 1 avg class xent loss = 3.9399
# (0:2:4) s 130/142, e 1 avg class xent loss = 1.8368
# (0:2:8) s 140/142, e 1 avg class xent loss = 2.6426
# (0:2:9) s 0/142, e 2 avg class xent loss = 2.3644
# ================================================================================
# (0:2:10) s 0/142, e 2 validation avg class xent loss = 14.0432
# ================================================================================
# Saving model...
# (0:2:16) s 10/142, e 2 avg class xent loss = 3.9297
# (0:2:20) s 20/142, e 2 avg class xent loss = 2.0430
# (0:2:24) s 30/142, e 2 avg class xent loss = 1.3989
# (0:2:28) s 40/142, e 2 avg class xent loss = 1.6380
# (0:2:33) s 50/142, e 2 avg class xent loss = 1.4007
# ================================================================================
# (0:2:33) s 50/142, e 2 validation avg class xent loss = 15.4336
# ================================================================================
# Saving model...
# (0:2:40) s 60/142, e 2 avg class xent loss = 1.7581
# (0:2:43) s 70/142, e 2 avg class xent loss = 1.1897
# (0:2:48) s 80/142, e 2 avg class xent loss = 1.9037
# (0:2:52) s 90/142, e 2 avg class xent loss = 0.3837
# (0:2:56) s 100/142, e 2 avg class xent loss = 1.2296
# ================================================================================
# (0:2:56) s 100/142, e 2 validation avg class xent loss = 14.9132
# ================================================================================
# Saving model...
# (0:3:3) s 110/142, e 2 avg class xent loss = 1.0653
# (0:3:7) s 120/142, e 2 avg class xent loss = 5.4880
# (0:3:12) s 130/142, e 2 avg class xent loss = 3.2883
# (0:3:16) s 140/142, e 2 avg class xent loss = 2.6963
# (0:3:17) s 0/142, e 3 avg class xent loss = 1.7016
# ================================================================================
# (0:3:17) s 0/142, e 3 validation avg class xent loss = 17.2452
# ================================================================================
# Saving model...
# (0:3:24) s 10/142, e 3 avg class xent loss = 2.9322
# (0:3:28) s 20/142, e 3 avg class xent loss = 1.5582
# (0:3:32) s 30/142, e 3 avg class xent loss = 1.8928

# %%
# check out predictions
# valid_batch = DH.classification_batch(len(train['labels']), train['sdps'], train['targets'], train['labels'])

valid_batch = DH.classification_batch(len(valid['labels']), valid['sdps'], valid['targets'], valid['labels'])
preds, dists = drnn.predict(valid_batch[0], valid_batch[1], valid_batch[2], return_probs=True)

# %%
for i, p in enumerate(preds):
    print("%i, pred: %s, true: %s" %(i, int2label[p], int2label[valid['labels'][i]]))
    target = DH.sequence_to_sentence(valid['targets'][i]).split(' ')
    sdp = DH.sequence_to_sentence(valid['sdps'][i], show_dep=True)
    print('<%s> "%s" <%s>' % (target[0], sdp, target[1]))
    print(valid['raws'][i])
    print(valid['comments'][i])
    print("="*80)
# Out:
# 0, pred: Component-Whole(e2,e1), true: Other
# <<OOV>> "(<X>, nsubj) (cuts, ROOT) (<Y>, dobj)" <<OOV>>
# 7110	"The <e1>lawnmower</e1> cuts a <e2>swath</e2> of grass as it moves across the lawn."
#
# Comment:
#
# ================================================================================
# 1, pred: Member-Collection(e2,e1), true: Other
# <<OOV>> "(<X>, dobj) (show, ROOT) (after, prep) (<Y>, pobj)" <years>
# 7111	"The centre and right images show progressive <e1>shrinkage</e1> after two and four <e2>years</e2>."
#
# Comment:
#
# ================================================================================
# 2, pred: Instrument-Agency(e2,e1), true: Other
# <<OOV>> "(<X>, pobj) (in, prep) (difference, attr) (was, ROOT) (from, prep) (<Y>, pobj)" <beginning>
# 7112	"Although Harry noticed it during exercise, the change that was identified was the difference in muscular <e1>discomfort</e1> from the <e2>beginning</e2> of his training program (riding five miles per day) to his current status two months later."
#
# Comment:
#
# ================================================================================
# 3, pred: Other, true: Product-Producer(e2,e1)
# <surgeon> "(<X>, nsubj) (makes, ROOT) (<Y>, dobj)" <hole>
# 7113	"During this procedure, the <e1>surgeon</e1> makes a small <e2>hole</e2> ("fenestration") in the baffle to help relieve the symptoms of the original heart disease."
#
# Comment:
#
# ================================================================================
# 4, pred: Member-Collection(e1,e2), true: Content-Container(e2,e1)
# <<OOV>> "(<X>, dobj) (contains, relcl) (<Y>, dobj)" <powder>
# 7114	"Tim Boyle (1846) checks a <e1>flask</e1> that contains the dried cathode precursor <e2>powder</e2>."
#
# Comment: A prototypical example.
#
# ================================================================================
# 5, pred: Product-Producer(e1,e2), true: Other
# <<OOV>> "(<X>, nsubj) (keeps, ROOT) (<Y>, dobj)" <enemy>
# 7115	"A <e1>moat</e1> keeps the <e2>enemy</e2> at bay."
#
# Comment:
#
# ================================================================================
# 6, pred: Cause-Effect(e2,e1), true: Other
# <removal> "(<X>, pobj) (from, prep) (<Y>, pobj)" <exposure>
# 7116	"His lung function remained stable after complete <e1>removal</e1> from <e2>exposure</e2> to metalworking fluids."
#
# Comment:
#
# ================================================================================
# 7, pred: Entity-Destination(e1,e2), true: Cause-Effect(e2,e1)
# <famine> "(<X>, conj) (<OOV>, conj) (treaties, pobj) (following, acl) (<Y>, dobj)" <failure>
# 7117	"Losing land to new white settlers, non-payment, past broken treaties, plus food shortages and <e1>famine</e1> following crop <e2>failure</e2> led to great discontent among the Dakota people."
#
# Comment:
#
# ================================================================================
# 8, pred: Content-Container(e1,e2), true: Other
# <patient> "(<X>, nsubjpass) (kept, ROOT) (in, prep) (<Y>, pobj)" <hospital>
# 7118	"The <e1>patient</e1> is kept in the <e2>hospital</e2> one night for observation."
#
# Comment: Content-Container in e1 --> e2 is excluded because of the restriction that people cannot be contents. An entity-location relation is more appropriate.
#
# ================================================================================
# 9, pred: Entity-Destination(e1,e2), true: Cause-Effect(e2,e1)
# <circumstances> "(<X>, pobj) (created, acl) (by, agent) (<Y>, pobj)" <<OOV>>
# 7119	"Some people voluntarily get involved with politicisation, while others become victims of <e1>circumstances</e1> created by the <e2>politicisation</e2>."
#
# Comment:
#
# ================================================================================
# 10, pred: Member-Collection(e1,e2), true: Other
# <order> "(<X>, compound) (<OOV>, conj) (<Y>, prep)" <from>
# 7120	"They're bringing in applications such as catalog management and order <e1>fulfillment</e1> from <e2>vendors</e2>, then laboriously developing and integrating those applications themselves."
#
# Comment:
#
# ================================================================================
# 11, pred: Other, true: Cause-Effect(e2,e1)
# <<OOV>> "(<X>, pobj) (from, prep) (change, pobj) (<Y>, compound)" <climate>
# 7121	"Polar bears and hippos have joined the ranks of species threatened with <e1>extinction</e1> from <e2>climate change</e2>, unregulated hunting and other dangers created by humans."
#
# Comment:
#
# ================================================================================
# 12, pred: Message-Topic(e1,e2), true: Component-Whole(e1,e2)
# <<OOV>> "(<X>, nsubj) (in, prep) (<Y>, pobj)" <house>
# 7122	"The <e1>bulbs</e1> in my <e2>house</e2> use 190 watts."
#
# Comment: Here bulbs may be considered as an integral part of the lighting system of the house.
#
# ================================================================================
# 13, pred: Cause-Effect(e2,e1), true: Component-Whole(e1,e2)
# <ceiling> "(<X>, pobj) (in, prep) (<Y>, pobj)" <kitchen>
# 7123	"So I was looking at the <e1>ceiling</e1> in my <e2>kitchen</e2> yelling at God."
#
# Comment: The ceiling is an integral and functional part of the kitchen (room).
#
# ================================================================================
# 14, pred: Instrument-Agency(e2,e1), true: Component-Whole(e2,e1)
# <<OOV>> "(<X>, nsubj) (contains, ROOT) (<Y>, dobj)" <<OOV>>
# 7124	"The <e1>implant</e1> contains <e2>nanoparticles</e2> which are designed to test for different substances, including metabolites such as glucose and oxygen that are associated with tumor growth."
#
# Comment: Particles are, as a whole, an integral and functional part of the device.
#
# ================================================================================
# 15, pred: Cause-Effect(e2,e1), true: Cause-Effect(e2,e1)
# <excitement> "(<X>, pobj) (of, prep) (most, nsubj) (came, ROOT) (from, prep) (<Y>, pobj)" <<OOV>>
# 7125	"Most of the <e1>excitement</e1> came from the <e2>anticipation</e2> of winning a nice prize, all for the sum of one dollar."
#
# Comment:
#
# ================================================================================
# 16, pred: Instrument-Agency(e2,e1), true: Content-Container(e2,e1)
# <envelope> "(<X>, pobj) (of, prep) (contents, nsubj) (were, ROOT) (<Y>, attr)" <sheet>
# 7126	"The contents of the <e1>envelope</e1> were a <e2>sheet</e2> of foreign note-paper, and a folded enclosure."
#
# Comment:
#
# ================================================================================
# 17, pred: Product-Producer(e2,e1), true: Other
# <damage> "(<X>, dobj) (from, prep) (<Y>, pobj)" <dawn>
# 7127	"Their retreat was disorderly and confused and much like a flight, the Pallantines hanging on their flanks and rear and doing great <e1>damage</e1> from early <e2>dawn</e2> till evening."
#
# Comment:
#
# ================================================================================
# 18, pred: Member-Collection(e1,e2), true: Other
# <growth> "(<X>, pobj) (from, prep) (<Y>, pobj)" <<OOV>>
# 7128	"These Hebrew histories tell the story of a people's upward <e1>growth</e1> from <e2>savagery</e2>."
#
# Comment:
#
# ================================================================================
# 19, pred: Member-Collection(e2,e1), true: Instrument-Agency(e2,e1)
# <drunk> "(<X>, amod) (uses, conj) (<Y>, dobj)" <<OOV>>
# 7129	"A major government researcher once complained that his bosses used his scientific findings the way a <e1>drunk</e1> uses a <e2>lamppost</e2>: for support rather than illumination."
#
# Comment:
#
# ================================================================================
# 20, pred: Entity-Origin(e1,e2), true: Product-Producer(e2,e1)
# <company> "(<X>, nsubj) (manufactured, ROOT) (<Y>, dobj)" <machines>
# 7130	"Eventually the <e1>company</e1> manufactured the <e2>machines</e2>."
#
# Comment:
#
# ================================================================================
# 21, pred: Member-Collection(e2,e1), true: Cause-Effect(e2,e1)
# <progress> "(<X>, nsubj) (comes, ROOT) (from, prep) (<Y>, pobj)" <competition>
# 7131	"<e1>Progress</e1> comes from constructive <e2>competition</e2>, and churches and religions can benefit greatly from it."
#
# Comment:
#
# ================================================================================
# 22, pred: Cause-Effect(e2,e1), true: Cause-Effect(e1,e2)
# <<OOV>> "(<X>, ROOT) (<Y>, dobj)" <heat>
# 7132	"The concrete <e1>sidewalk</e1> radiated <e2>heat</e2> like a furnace, and there was no relief in the shade of a large crepe myrtle tree as they walked under it."
#
# Comment:
#
# ================================================================================
# 23, pred: Member-Collection(e1,e2), true: Product-Producer(e2,e1)
# <<OOV>> "(<X>, nsubj) (makes, ROOT) (<Y>, dobj)" <argument>
# 7133	"In Cicero's speech for Milo, the <e1>orator</e1> makes a valid <e2>argument</e2>."
#
# Comment:
#
# ================================================================================
# 24, pred: Member-Collection(e2,e1), true: Other
# <cheese> "(<X>, nsubjpass) (made, ROOT) (with, prep) (<Y>, pobj)" <starter>
# 7134	"In a preliminary investigation, Cheddar <e1>cheese</e1> was made with a lactococcal <e2>starter</e2> overproducing different peptidases."
#
# Comment: It also cannot be Entity-Origin because the lactococcal starter is not the main source material of cheese (milk is), so violation of (b). This cannot be Component-Whole because it violates "(d) X has a clear boundary and could, in principle, be separated from Y" - the case is like 'alcohol-wine'.
#
# ================================================================================
# 25, pred: Component-Whole(e2,e1), true: Cause-Effect(e2,e1)
# <fire> "(<X>, nsubj) (started, ROOT) (with, prep) (<Y>, pobj)" <explosion>
# 7135	"The <e1>fire</e1> started with an <e2>explosion</e2> in the cargo hold and spread across the ship within 10 minutes."
#
# Comment:
#
# ================================================================================
# 26, pred: Cause-Effect(e1,e2), true: Other
# <<OOV>> "(<X>, compound) (<Y>, attr)" <<OOV>>
# 7136	"Until last year, Afghanistan was an <e1>opium</e1> <e2>exporter</e2>, not a major heroin producer."
#
# Comment: Export does not entail production; negation is outside
#
# ================================================================================
# 27, pred: Message-Topic(e1,e2), true: Instrument-Agency(e1,e2)
# <car> "(<X>, compound) (battery, nsubj) (powered, ROOT) (computer, dobj) (<Y>, compound)" <<OOV>>
# 7137	"A <e1>car battery</e1> powered a <e2>laptop computer</e2> connected to a small, portable satellite antenna."
#
# Comment: Power sousrces are acceptable Instruments.
#
# ================================================================================
# 28, pred: Message-Topic(e1,e2), true: Instrument-Agency(e2,e1)
# <forces> "(<X>, nsubj) (<OOV>, ROOT) (lot, dobj) (of, prep) (power, pobj) (<Y>, amod)" <political>
# 7138	"Anti-gun <e1>forces</e1> still wield a lot of <e2>political power</e2>."
#
# Comment:
#
# ================================================================================
# 29, pred: Product-Producer(e2,e1), true: Other
# <logs> "(<X>, nsubj) (<OOV>, ROOT) (saw, conj) (<Y>, dobj)" <design>
# 7139	"The <e1>logs</e1> sawed smoothly and accurately using either saw <e2>design</e2>."
#
# Comment:
#
# ================================================================================
# 30, pred: Message-Topic(e2,e1), true: Cause-Effect(e2,e1)
# <terror> "(<X>, pobj) (of, prep) (<Y>, pobj)" <<OOV>>
# 7140	"Villagers live in constant <e1>terror</e1> of indiscriminate <e2>gunfire</e2> which fills the nights throughout Chechnya."
#
# Comment:
#
# ================================================================================
# 31, pred: Cause-Effect(e2,e1), true: Content-Container(e1,e2)
# <liquid> "(<X>, amod) (<OOV>, pobj) (of, prep) (form, dobj) (carried, acl) (in, prep) (<Y>, pobj)" <bottle>
# 7141	"He used a stable form of <e1>liquid nitroglycerin</e1> carried in a <e2>bottle</e2> labeled as contact lens solution, using cotton as a stabilizer."
#
# Comment: A prototypical example.
#
# ================================================================================
# 32, pred: Entity-Origin(e1,e2), true: Entity-Origin(e1,e2)
# <<OOV>> "(<X>, nsubjpass) (made, ROOT) (from, prep) (<Y>, pobj)" <<OOV>>
# 7142	"The basement <e1>carpeting</e1> is made from recycled plastic pop <e2>bottles</e2>, and the underpad was once automobile tires."
#
# Comment:
#
# ================================================================================
# 33, pred: Product-Producer(e2,e1), true: Other
# <audit> "(<X>, pobj) (of, prep) (contents, nsubj) (were, ROOT) (<Y>, attr)" <secret>
# 7143	"But the contents of the <e1>audit</e1> were a closely held <e2>secret</e2>, and attempts to obtain other records were denied repeatedly."
#
# Comment: None of the nine relations seems to hold; "secret" seems to be a state of the audit.
#
# ================================================================================
# 34, pred: Component-Whole(e1,e2), true: Component-Whole(e2,e1)
# <kitchen> "(<X>, nsubj) (contained, ROOT) (item, dobj) (door, appos) (<Y>, compound)" <trap>
# 7144	"The <e1>kitchen</e1> contained one other interesting item, a <e2>trap door</e2> in the ceiling."
#
# Comment: The trap door is an integral and functional part of the kitchen room.
#
# ================================================================================
# 35, pred: Entity-Origin(e1,e2), true: Component-Whole(e2,e1)
# <workshop> "(<X>, pobj) (of, prep) (contents, nsubj) (included, ROOT) (<Y>, dobj)" <discussion>
# 7145	"The contents of the <e1>workshop</e1> included a <e2>discussion</e2> on various documents in respect of exports, imports and documents relating to letters of credit."
#
# Comment: The discussion is an integral and functional part of the workshop; it changes if we remove the discussion.
#
# ================================================================================
# 36, pred: Component-Whole(e2,e1), true: Other
# <<OOV>> "(<X>, nsubj) (farmed, ROOT) (for, prep) (<Y>, pobj)" <owner>
# 7146	"The <e1>tenant</e1> has farmed for this <e2>owner</e2> for several years and doesn't want to lose the ground, but also does not want to pay the large increase in rent."
#
# Comment: modality and negation are outside
#
# ================================================================================
# 37, pred: Component-Whole(e2,e1), true: Product-Producer(e1,e2)
# <for> "(<X>, prep) (feedback, pobj) (<Y>, prep)" <from>
# 7147	"We're always looking for <e1>feedback</e1> from <e2>readers</e2> and articles to highlight."
#
# Comment:
#
# ================================================================================
# 38, pred: Cause-Effect(e2,e1), true: Cause-Effect(e2,e1)
# <<OOV>> "(<X>, attr) (from, prep) (<Y>, pobj)" <crusaders>
# 7148	"There was an the <e1>outrage</e1> from the sexism <e2>crusaders</e2>."
#
# Comment:
#
# ================================================================================
# 39, pred: Instrument-Agency(e2,e1), true: Entity-Origin(e1,e2)
# <hydrogen> "(<X>, nsubj) (comes, ROOT) (from, prep) (<Y>, pobj)" <water>
# 7149	"The <e1>hydrogen</e1> comes from <e2>water</e2> and electricity from any source can be used to electrolyze the water."
#
# Comment:
#
# ================================================================================
# 40, pred: Cause-Effect(e2,e1), true: Cause-Effect(e2,e1)
# <<OOV>> "(<X>, conj) (from, prep) (<Y>, pobj)" <<OOV>>
# 7150	"His highly original and topical act reaches from the top of the corporate ladder into blokes' sheds, leaving his audiences <e1>aching</e1> from <e2>laughter</e2>."
#
# Comment:
#
# ================================================================================
# 41, pred: Content-Container(e1,e2), true: Product-Producer(e2,e1)
# <organ> "(<X>, attr) (of, prep) (body, pobj) (produces, relcl) (<Y>, dobj)" <insulin>
# 7151	"The pancreas is the <e1>organ</e1> of the body that produces <e2>insulin</e2>."
#
# Comment:
#
# ================================================================================
# 42, pred: Member-Collection(e2,e1), true: Product-Producer(e1,e2)
# <joined> "(<X>, ROOT) (company, dobj) (<Y>, det)" <a>
# 7152	"NINE-year-old Chloe Clark joined a <e1>ballet</e1> <e2>company</e2> on stage last Monday."
#
# Comment: Ballet is a form of creative art.
#
# ================================================================================
# 43, pred: Entity-Origin(e1,e2), true: Instrument-Agency(e2,e1)
# <weaver> "(<X>, nsubj) (sits, ROOT) (with, prep) (<Y>, pobj)" <<OOV>>
# 7153	"The <e1>weaver</e1> sits with a <e2>loom</e2> fixing the back strap, keeps her legs against the footrest, which is adjustable for keeping the loom in tension."
#
# Comment:
#
# ================================================================================
# 44, pred: Cause-Effect(e2,e1), true: Content-Container(e2,e1)
# <<OOV>> "(<X>, dobj) (contains, relcl) (<Y>, dobj)" <<OOV>>
# 7154	"The conventional way to grow bacteria is to inoculate a <e1>flask</e1> that contains a <e2>broth</e2> of nutrients."
#
# Comment: A prototypical example.
#
# ================================================================================
# 45, pred: Instrument-Agency(e2,e1), true: Other
# <<OOV>> "(<X>, nsubj) (provide, ROOT) (<Y>, dobj)" <framework>
# 7155	"The <e1>toolkits</e1> provide a secure <e2>framework</e2> where sensitive information remains private."
#
# Comment: "Provision" here doesn't mean creation.
#
# ================================================================================
# 46, pred: Product-Producer(e2,e1), true: Other
# <<OOV>> "(<X>, nsubj) (combines, ROOT) (<Y>, dobj)" <skill>
# 7156	"In a nutshell, <e1>orienteering</e1> combines a physical <e2>skill</e2> with a more cerebral element."
#
# Comment:
#
# ================================================================================
# 47, pred: Cause-Effect(e2,e1), true: Other
# <food> "(<X>, nsubjpass) (kept, ROOT) (in, prep) (<Y>, pobj)" <kitchen>
# 7157	"The <e1>food</e1> is kept in the <e2>kitchen</e2> and guests help themselves as it is a self service."
#
# Comment: food is located in the kitchen.
#
# ================================================================================
# 48, pred: Other, true: Cause-Effect(e2,e1)
# <<OOV>> "(<X>, conj) (from, prep) (<Y>, pobj)" <exposure>
# 7158	"Videotape is a fragile medium subject to damage and <e1>deterioration</e1> from <e2>exposure</e2> to poor environmental conditions and inadequate handling practices."
#
# Comment:
#
# ================================================================================
# 49, pred: Member-Collection(e2,e1), true: Other
# <challenges> "(<X>, nsubjpass) (addressed, ROOT) (from, prep) (<Y>, pobj)" <<OOV>>
# 7159	"The <e1>challenges</e1> are being addressed from a manufacturing <e2>standpoint</e2> rather than ICT solutions that could answer them."
#
# Comment:
#
# ================================================================================
# 50, pred: Cause-Effect(e2,e1), true: Component-Whole(e2,e1)
# <kitchen> "(<X>, nsubj) (contains, ROOT) (equipment, dobj) (as, prep) (<Y>, pobj)" <<OOV>>
# 7160	"The <e1>kitchen</e1> contains various commercial equipment such as <e2>stoves</e2>, griddles, deep fryer, and an oven."
#
# Comment: A stove is a functional and integral part of the kitchen (of its typical equipment). If we assumed that it is not fixed (easily movable), it could be also treated as located in the kitchen room.
#
# ================================================================================
# 51, pred: Component-Whole(e2,e1), true: Cause-Effect(e2,e1)
# <steam> "(<X>, pobj) (of, prep) (most, nsubj) (comes, ROOT) (from, prep) (<Y>, pobj)" <magma>
# 7161	"Most of the <e1>steam</e1> comes from a volcano's <e2>magma</e2>."
#
# Comment:
#
# ================================================================================
# 52, pred: Cause-Effect(e2,e1), true: Instrument-Agency(e2,e1)
# <artist> "(<X>, nsubj) (played, ROOT) (<Y>, dobj)" <piano>
# 7162	"The <e1>artist</e1> played the <e2>piano</e2> with great precision."
#
# Comment:
#
# ================================================================================
# 53, pred: Cause-Effect(e2,e1), true: Cause-Effect(e1,e2)
# <car> "(<X>, nsubj) (makes, ROOT) (<Y>, ccomp)" <sound>
# 7163	"When I start the engine the <e1>car</e1> makes a screaching <e2>sound</e2>."
#
# Comment:
#
# ================================================================================
# 54, pred: Content-Container(e2,e1), true: Other
# <keyboard> "(<X>, nsubj) (offers, ROOT) (<Y>, dobj)" <typing>
# 7164	"Touch sliding <e1>keyboard</e1> offers keyless <e2>typing</e2>."
#
# Comment: Purpose-Tool
#
# ================================================================================
# 55, pred: Other, true: Content-Container(e1,e2)
# <acid> "(<X>, nsubjpass) (kept, ROOT) (in, prep) (<Y>, pobj)" <tank>
# 7165	"The <e1>acid</e1> is kept in a level-controlled <e2>tank</e2> (with a controller and an alarm in the event of low acid level)."
#
# Comment: A prototypical example.
#
# ================================================================================
# 56, pred: Other, true: Product-Producer(e1,e2)
# <yeast> "(<X>, poss) (<Y>, nsubj)" <manufacturer>
# 7166	"The <e1>yeast</e1>'s <e2>manufacturer</e2>, Lesaffre Yeast Corp. of Milwaukee, did not return calls seeking comment."
#
# Comment:
#
# ================================================================================
# 57, pred: Message-Topic(e1,e2), true: Cause-Effect(e1,e2)
# <community> "(<X>, nsubj) (produced, ROOT) (<Y>, dobj)" <personality>
# 7167	"The enclosed <e1>community</e1> produced the enclosed <e2>personality</e2>, and vice versa."
#
# Comment: Personality is a state
#
# ================================================================================
# 58, pred: Content-Container(e1,e2), true: Other
# <batteries> "(<X>, nsubj) (kept, ROOT) (in, prep) (condition, pobj) (<Y>, amod)" <good>
# 7168	"<e1>Batteries</e1> kept in <e2>good condition</e2> have a 5 to 6 year service life."
#
# Comment: "good condition" is a possible state for batteries.
#
# ================================================================================
# 59, pred: Member-Collection(e2,e1), true: Cause-Effect(e2,e1)
# <<OOV>> "(<X>, nsubjpass) (produced, ROOT) (by, agent) (<Y>, pobj)" <action>
# 7169	"In a clock, the '<e1>tick</e1>' is produced by the <e2>action</e2> of the escapement."
#
# Comment:
#
# ================================================================================
# 60, pred: Entity-Destination(e1,e2), true: Other
# <students> "(<X>, nsubj) (benefit, ROOT) (from, prep) (<Y>, pobj)" <scheme>
# 7170	"Non-UK <e1>students</e1> benefit from the bursary <e2>scheme</e2>."
#
# Comment:
#
# ================================================================================
# 61, pred: Content-Container(e1,e2), true: Entity-Origin(e1,e2)
# <castle> "(<X>, attr) (from, prep) (<Y>, pobj)" <contest>
# 7171	"This is the winning sand <e1>castle</e1> from the Castlemania <e2>contest</e2>."
#
# Comment:
#
# ================================================================================
# 62, pred: Member-Collection(e2,e1), true: Cause-Effect(e2,e1)
# <<OOV>> "(<X>, amod) (<OOV>, conj) (from, prep) (<Y>, pobj)" <<OOV>>
# 7172	"The risks of this procedure include anesthesia complications, post-operative difficulty breathing, and <e1>sore throat</e1> from <e2>intubation</e2>."
#
# Comment:
#
# ================================================================================
# 63, pred: Entity-Destination(e1,e2), true: Instrument-Agency(e2,e1)
# <cook> "(<X>, dobj) (<OOV>, acl) (over, prep) (<Y>, pobj)" <<OOV>>
# 7173	"An accompanying CD of light classic Italian music helps to inspire the <e1>cook</e1> laboring over the <e2>stove</e2> or to create a romantic atmosphere at dinner."
#
# Comment:
#
# ================================================================================
# 64, pred: Member-Collection(e2,e1), true: Instrument-Agency(e2,e1)
# <victim> "(<X>, nsubj) (using, ROOT) (<Y>, dobj)" <hammer>
# 7174	"The <e1>victim</e1>, who was positioned underneath the conveyor, was using a <e2>hammer</e2> to adjust the return roller."
#
# Comment:
#
# ================================================================================
# 65, pred: Other, true: Other
# <<OOV>> "(<X>, nsubjpass) (kept, ROOT) (in, prep) (<Y>, pobj)" <area>
# 7175	"The <e1>bulldozer</e1> is kept in the <e2>area</e2> and is suspected of being used to create makeshift paths across the river."
#
# Comment: "area" cannot be considered a container; this seems an entity-location example.
#
# ================================================================================
# 66, pred: Entity-Origin(e1,e2), true: Content-Container(e2,e1)
# <stomach> "(<X>, pobj) (of, prep) (contents, nsubj) (included, ROOT) (<OOV>, dobj) (<Y>, compound)" <apple>
# 7176	"The contents of the bear's <e1>stomach</e1> included <e2>apple mash</e2>, corn and blueberries."
#
# Comment:
#
# ================================================================================
# 67, pred: Entity-Origin(e1,e2), true: Product-Producer(e2,e1)
# <bone> "(<X>, compound) (<OOV>, nsubj) (produces, ROOT) (cells, dobj) (<Y>, compound)" <stem>
# 7177	"Normally, the <e1>bone marrow</e1> produces <e2>stem cells</e2> (immature cells) that develop into mature blood cells."
#
# Comment:
#
# ================================================================================
# 68, pred: Entity-Destination(e1,e2), true: Other
# <<OOV>> "(<X>, nsubjpass) (contains, relcl) (<Y>, dobj)" <acid>
# 7178	"A <e1>marinade</e1> that contains <e2>acid</e2>, alcohol or salt has been used for a short time."
#
# Comment: acid in this case is an ingredient, it stands for an acid ingredient such as lemon or vinegar that do not have clear boundaries (stuff-object relation).
#
# ================================================================================
# 69, pred: Member-Collection(e2,e1), true: Other
# <rowing> "(<X>, nsubj) (pulling, csubj) (<Y>, dobj)" <<OOV>>
# 7179	"To say that <e1>rowing</e1> is just pulling an <e2>oar</e2> is like saying golf is just swinging a club."
#
# Comment: Purpose-Tool
#
# ================================================================================
# 70, pred: Cause-Effect(e2,e1), true: Other
# <<OOV>> "(<X>, nsubj) (contains, conj) (<PUNCT>, dobj) (of, prep) (fat, pobj) (<Y>, compound)" <body>
# 7180	"The main cell types are fibroblasts, macrophages and adipocytes (the <e1>hypodermis</e1> contains 50% of <e2>body fat</e2>)."
#
# Comment: body fat is part of hypodermis cells but does not have clear boundaries (stuff-object relation).
#
# ================================================================================
# 71, pred: Instrument-Agency(e2,e1), true: Cause-Effect(e2,e1)
# <<OOV>> "(<X>, pobj) (to, prep) (leading, advcl) (after, prep) (<Y>, pobj)" <exposure>
# 7181	"Whilst audio sampled at 8kHz is sufficient for communication, such narrow-band speech does not sound natural, leading to user <e1>frustration</e1> after prolonged <e2>exposure</e2>, and making language learning difficult."
#
# Comment:
#
# ================================================================================
# 72, pred: Cause-Effect(e2,e1), true: Entity-Origin(e2,e1)
# <country> "(<X>, compound) (<Y>, nsubj)" <<OOV>>
# 7182	"The <e1>country</e1> <e2>gentleman</e2>, lodging at the Hotel de Mayence, Rue Saint-Honore, near the Place Vendome, one morning received a visit from a confidential agent of the Ministry, who was an expert in 'winding up' business."
#
# Comment:
#
# ================================================================================
# 73, pred: Entity-Destination(e1,e2), true: Other
# <judges> "(<X>, nsubj) (cultivated, ROOT) (<Y>, dobj)" <principles>
# 7183	"With these axioms, the <e1>judges</e1> cultivated the <e2>principles</e2> of judgment, and those principles could be used in gauging the restrictions on freedom that were justified or unjustified, in any domain of the law."
#
# Comment:Cultivation is not creation. The principles already existed.
#
# ================================================================================
# 74, pred: Entity-Origin(e1,e2), true: Instrument-Agency(e2,e1)
# <hunter> "(<X>, dobj) (<OOV>, acl) (with, prep) (<Y>, pobj)" <spear>
# 7184	"It is noteworthy that Peacham's emblem has a <e1>hunter</e1> chasing the ermine with a <e2>spear</e2> and dogs."
#
# Comment:
#
# ================================================================================
# 75, pred: Cause-Effect(e2,e1), true: Entity-Origin(e1,e2)
# <dollar> "(<X>, nsubj) (fell, ROOT) (from, prep) (<Y>, pobj)" <peaks>
# 7185	"The <e1>dollar</e1> fell from six-week <e2>peaks</e2> against major European currencies."
#
# Comment:
#
# ================================================================================
# 76, pred: Message-Topic(e2,e1), true: Other
# <<OOV>> "(<X>, appos) (contains, relcl) (<Y>, dobj)" <mercury>
# 7186	"Some inactivated influenza vaccine contains thimerosal, a <e1>preservative</e1> that contains <e2>mercury</e2>."
#
# Comment: mercury is part of the preservative, and it does not have clear boundaries (stuff-object relation).
#
# ================================================================================
# 77, pred: Product-Producer(e2,e1), true: Cause-Effect(e2,e1)
# <boost> "(<X>, dobj) (received, ROOT) (from, prep) (<Y>, pobj)" <funding>
# 7187	"Initiated during the early 1990's National Mineral Resource Assessment, this project received a major <e1>boost</e1> from <e2>funding</e2> provided through the 'Data-at-Risk' add-on funding received by the USGS through the 2004 fiscal year."
#
# Comment:
#
# ================================================================================
# 78, pred: Cause-Effect(e2,e1), true: Instrument-Agency(e1,e2)
# <crane> "(<X>, compound) (<Y>, pobj)" <operator>
# 7188	"I worked as a <e1>crane</e1> <e2>operator</e2> in construction at that time."
#
# Comment:
#
# ================================================================================
# 79, pred: Cause-Effect(e1,e2), true: Other
# <<OOV>> "(<X>, nsubjpass) (made, conj) (from, prep) (<Y>, pobj)" <<OOV>>
# 7189	"A pop-up roll cage and active headrests aim to protect occupants during a rollover, and the <e1>floorboard</e1> is made from <e2>bamboo</e2> and aluminum."
#
# Comment:
#
# ================================================================================
# 80, pred: Instrument-Agency(e2,e1), true: Component-Whole(e2,e1)
# <hybrid> "(<X>, nsubj) (combines, ROOT) (engine, dobj) (<Y>, compound)" <gasoline>
# 7190	"In simplest terms, a <e1>hybrid</e1> combines a <e2>gasoline engine</e2> and an electric motor to provide adequate power with minimal fuel useage and low emissions."
#
# Comment:
#
# ================================================================================
# 81, pred: Message-Topic(e1,e2), true: Cause-Effect(e1,e2)
# <energy> "(<X>, nsubj) (produces, ROOT) (field, dobj) (<Y>, compound)" <separation>
# 7191	"The <e1>energy</e1> of emission produces the <e2>separation field</e2>."
#
# Comment: Neither the energy nor the separation field are concrete objects.
#
# ================================================================================
# 82, pred: Cause-Effect(e1,e2), true: Other
# <batteries> "(<X>, nsubj) (stored, acl) (in, prep) (state, pobj) (<Y>, amod)" <discharged>
# 7192	"<e1>Batteries</e1> stored in a <e2>discharged state</e2> are susceptible to freezing, sulfation and an increased rate of discharge."
#
# Comment: discharge state is a state of the entity batteries. None of the nine relations holds.
#
# ================================================================================
# 83, pred: Member-Collection(e2,e1), true: Entity-Origin(e1,e2)
# <<OOV>> "(<X>, pobj) (<OOV>, acl) (from, prep) (<Y>, pobj)" <<OOV>>
# 7193	"From the diagrams of DaVinci to the latest photographic <e1>marvels</e1> retrieved from the remotest galactic <e2>outback</e2>, visualization of research has a long and literally illustrious history."
#
# Comment:
#
# ================================================================================
# 84, pred: Product-Producer(e1,e2), true: Cause-Effect(e2,e1)
# <<OOV>> "(<X>, conj) (pleasure, dobj) (<OOV>, ROOT) (from, prep) (<Y>, pobj)" <teaching>
# 7194	"I derive tremendous pleasure and <e1>fulfillment</e1> from <e2>teaching</e2>, particularly when I am able to help students understand a previously foreign concept or idea, aid them in seeing a familiar object or event from a new and unusual perspective, guide them with projects they are working on, or encourage the interests they have."
#
# Comment:
#
# ================================================================================
# 85, pred: Entity-Destination(e1,e2), true: Instrument-Agency(e1,e2)
# <<OOV>> "(<X>, pobj) (in, prep) (used, ROOT) (protect, xcomp) (<Y>, dobj)" <cook>
# 7195	"Pot supports are used in the <e1>stove</e1> to protect the <e2>cook</e2> from the heat."
#
# Comment: The cook is using the stove in any sensible interpretation.
#
# ================================================================================
# 86, pred: Entity-Destination(e1,e2), true: Product-Producer(e2,e1)
# <compiler> "(<X>, nsubj) (generates, advcl) (<Y>, dobj)" <code>
# 7196	"The guarantees so painfully obtained by formal verification of the source program are useless if the <e1>compiler</e1> generates wrong <e2>code</e2>."
#
# Comment:
#
# ================================================================================
# 87, pred: Cause-Effect(e2,e1), true: Product-Producer(e1,e2)
# <vaccine> "(<X>, poss) (<Y>, nsubj)" <maker>
# 7197	"The <e1>vaccine</e1>'s <e2>maker</e2>, the Irish drug company Elan, has stopped giving the shots to its 360 volunteers while doctors determine what caused this serious side effect."
#
# Comment:
#
# ================================================================================
# 88, pred: Cause-Effect(e2,e1), true: Instrument-Agency(e2,e1)
# <man> "(<X>, nsubj) (struck, ROOT) (with, prep) (<Y>, pobj)" <hammer>
# 7198	"A <e1>man</e1> struck my video camera with a <e2>hammer</e2> while I accompanied a German film crew in Clearwater."
#
# Comment:
#
# ================================================================================
# 89, pred: Other, true: Cause-Effect(e2,e1)
# <<OOV>> "(<X>, nsubj) (comes, ROOT) (from, prep) (<Y>, pobj)" <fear>
# 7199	"Sometimes the <e1>blockage</e1> comes from <e2>fear</e2>, as for a CEO who hates public speaking but must give frequent speeches."
#
# Comment:
#
# ================================================================================
# 90, pred: Instrument-Agency(e2,e1), true: Instrument-Agency(e2,e1)
# <<OOV>> "(<X>, nsubj) (applied, ROOT) (<Y>, dobj)" <<OOV>>
# 7200	"<e1>Evaluators</e1> applied the statistically accurate <e2>generalization</e2> that men are usually taller than women to their estimates of the height of individuals who did not necessarily conform to the generalization."
#
# Comment:
#
# ================================================================================
# 91, pred: Product-Producer(e2,e1), true: Other
# <passengers> "(<X>, nsubj) (inside, prep) (<Y>, pobj)" <car>
# 7201	"It makes the drive more comfortable by intelligently seeking out what the <e1>passengers</e1> inside the <e2>car</e2> prefer in terms of temperature, music, lighting etc."
#
# Comment: Content-Container is excluded because people should not be considered contents. Instead it could be entity-location.
#
# ================================================================================
# 92, pred: Entity-Origin(e1,e2), true: Other
# <sounds> "(<X>, nsubj) (provide, relcl) (<Y>, dobj)" <<OOV>>
# 7202	"It is a family luxury villa with breeze-kissed balconies from which the <e1>sounds</e1> of the sea provide a sensuous nightly <e2>serenade</e2>."
#
# Comment: The sounds are a property of the serenade.
#
# ================================================================================
# 93, pred: Instrument-Agency(e2,e1), true: Cause-Effect(e1,e2)
# <patriots> "(<X>, nsubj) (<OOV>, ROOT) (<Y>, dobj)" <confidence>
# 7203	"When they took the floor against a team favored to win the national championship, the <e1>patriots</e1> radiated carefree <e2>confidence</e2>."
#
# Comment:
#
# ================================================================================
# 94, pred: Entity-Origin(e1,e2), true: Entity-Destination(e1,e2)
# <<OOV>> "(<X>, dobj) (<OOV>, conj) (in, prep) (<Y>, pobj)" <bag>
# 7204	"While Calvin is able to get the diamond, he's nearly caught by the police while making his getaway, and stashes the <e1>jewel</e1> in a <e2>bag</e2> carried by a passerby."
#
# Comment: A prototypical example; movement; modality is outside
#
# ================================================================================
# 95, pred: Instrument-Agency(e2,e1), true: Other
# <valve> "(<X>, nsubjpass) (kept, ROOT) (in, prep) (position, pobj) (<Y>, amod)" <closed>
# 7205	"The discharge <e1>valve</e1> is kept in the <e2>closed position</e2> at all times unless the dike is deliberately being drained."
#
# Comment: closed position describe the state of the valve. None of the nine relations holds.
#
# ================================================================================
# 96, pred: Cause-Effect(e2,e1), true: Product-Producer(e2,e1)
# <but> "(<X>, cc) (created, ROOT) (made, conj) (decision, dobj) (<Y>, det)" <the>
# 7206	"The company practically created the personal-home-computer industry, but the <e1>company</e1> made the fateful <e2>decision</e2> not to liberally license its software applications."
#
# Comment: A decision is a information-bearing mental activity (restriction d).
#
# ================================================================================
# 97, pred: Member-Collection(e2,e1), true: Other
# <beach> "(<X>, nsubj) (extends, ROOT) (from, prep) (<Y>, pobj)" <mouth>
# 7207	"The 3 km long <e1>beach</e1> extends from the <e2>mouth</e2> of the Oro River in the west, to the cliffs of Point Caramonal to the southeast."
#
# Comment:
#
# ================================================================================
# 98, pred: Cause-Effect(e2,e1), true: Other
# <tests> "(<X>, nsubjpass) (generated, ROOT) (from, prep) (<Y>, pobj)" <bank>
# 7208	"The <e1>tests</e1> are generated randomly from a <e2>bank</e2> of questions developed for each module."
#
# Comment:
#
# ================================================================================
# 99, pred: Cause-Effect(e2,e1), true: Other
# <nurse> "(<X>, nsubj) (takes, ROOT) (<Y>, dobj)" <clothes>
# 7209	"Suddenly a <e1>nurse</e1> takes off her familiar loose-fitting <e2>clothes</e2>, and dresses her in clothes, which fit her more closely."
#
# Comment:
#
# ================================================================================
# 100, pred: Other, true: Component-Whole(e2,e1)
# <segment> "(<X>, nsubj) (starts, ROOT) (with, prep) (<Y>, pobj)" <<OOV>>
# 7210	"The Global Warming <e1>segment</e1> starts off with two, cute <e2>anecdotes</e2> about flowers blooming early and aardvarks moving North."
#
# Comment:
#
# ================================================================================
# 101, pred: Entity-Destination(e1,e2), true: Other
# <shell> "(<X>, nsubjpass) (made, ROOT) (from, prep) (<Y>, pobj)" <aluminum>
# 7211	"The outer <e1>shell</e1> is made from anodized <e2>aluminum</e2>."
#
# Comment:
#
# ================================================================================
# 102, pred: Cause-Effect(e2,e1), true: Product-Producer(e1,e2)
# <coffee> "(<X>, compound) (<Y>, dobj)" <maker>
# 7212	"We cleaned the <e1>coffee</e1> <e2>maker</e2>, repeating this step again with a fresh vinegar and water mixture."
#
# Comment:
#
# ================================================================================
# 103, pred: Instrument-Agency(e2,e1), true: Other
# <servant> "(<X>, nsubj) (brought, ROOT) (<Y>, dobj)" <<OOV>>
# 7213	"The <e1>servant</e1> brought forth <e2>jewels</e2> of silver, and jewels of gold, and clothing, and gave them to Rebekah."
#
# Comment:
#
# ================================================================================
# 104, pred: Cause-Effect(e1,e2), true: Instrument-Agency(e2,e1)
# <device> "(<X>, nsubj) (uses, ROOT) (<Y>, dobj)" <technology>
# 7214	"The <e1>device</e1> uses the newest personal antenna <e2>technology</e2>."
#
# Comment: e1 is the explicit actor, and e2 is entity, so (a) is satisfied. also, the device uses the technology.
#
# ================================================================================
# 105, pred: Content-Container(e1,e2), true: Other
# <<OOV>> "(<X>, nsubj) (start, ROOT) (with, prep) (<Y>, pobj)" <fruit>
# 7215	"Colorful, almost fat-free salad <e1>dressings</e1> start with fresh <e2>fruit</e2>."
#
# Comment:
#
# ================================================================================
# 106, pred: Entity-Origin(e1,e2), true: Product-Producer(e2,e1)
# <company> "(<X>, nsubj) (uses, ROOT) (<Y>, dobj)" <<OOV>>
# 7216	"The <e1>company</e1> uses a policy <e2>assertion</e2> to convey a condition under which they offer a Web service."
#
# Comment:
#
# ================================================================================
# 107, pred: Instrument-Agency(e2,e1), true: Entity-Origin(e2,e1)
# <fruit> "(<X>, compound) (<Y>, dobj)" <sugar>
# 7217	"Fruit juice has all the <e1>fruit</e1> <e2>sugar</e2> and none of the fruit fiber, and only some of the fruit nutrients."
#
# Comment:
#
# ================================================================================
# 108, pred: Entity-Destination(e1,e2), true: Content-Container(e2,e1)
# <box> "(<X>, nsubj) (holds, ROOT) (tubes, dobj) (<Y>, compound)" <<OOV>>
# 7218	"The <e1>box</e1> holds three stiff <e2>cardboard tubes</e2>, each wrapped in now decaying cellophane."
#
# Comment: A prototypical example.
#
# ================================================================================
# 109, pred: Content-Container(e1,e2), true: Other
# <building> "(<X>, nsubj) (contained, ROOT) (school, dobj) (<Y>, compound)" <grammar>
# 7219	"Until 1729 the <e1>building</e1> contained only the <e2>grammar school</e2>."
#
# Comment: Buildings shouldn't be considered as containers. Instead the grammar school is located in the building.
#
# ================================================================================
# 110, pred: Content-Container(e1,e2), true: Other
# <move> "(<X>, nsubj) (makes, ROOT) (<Y>, dobj)" <<OOV>>
# 7220	"The <e1>move</e1> makes a <e2>mockery</e2> of China's long-standing opposition to such capabilities in the hands of other powers."
#
# Comment:
#
# ================================================================================
# 111, pred: Entity-Origin(e1,e2), true: Entity-Destination(e1,e2)
# <bag> "(<X>, dobj) (stuck, conj) (in, prep) (<Y>, pobj)" <face>
# 7221	"Suddenly, a man approached me from nowhere and stuck a <e1>bag</e1> of candy in my <e2>face</e2>."
#
# Comment:
#
# ================================================================================
# 112, pred: Message-Topic(e1,e2), true: Other
# <theory> "(<X>, dobj) (examine, advcl) (from, prep) (<Y>, pobj)" <perspective>
# 7222	"He went on to examine the <e1>theory</e1> from a risk assessment <e2>perspective</e2>."
#
# Comment:
#
# ================================================================================
# 113, pred: Entity-Origin(e2,e1), true: Product-Producer(e2,e1)
# <courts> "(<X>, nsubj) (created, ROOT) (test, dobj) (<OOV>, compound) (<Y>, punct)" <->
# 7223	"The <e1>courts</e1> created the Freeman-Walter-Abele <e2>test</e2> to determine whether an algorithm only represents an abstract idea."
#
# Comment: The test is a creative work.
#
# ================================================================================
# 114, pred: Product-Producer(e2,e1), true: Instrument-Agency(e2,e1)
# <president> "(<X>, nsubj) (<OOV>, relcl) (pen, dobj) (<Y>, compound)" <veto>
# 7224	"It was the only time the <e1>president</e1> has wielded the <e2>veto pen</e2> during his six years in office."
#
# Comment:
#
# ================================================================================
# 115, pred: Member-Collection(e2,e1), true: Other
# <growth> "(<X>, pobj) (from, prep) (<Y>, pobj)" <caterpillar>
# 7225	"Kids love watching the stages of <e1>growth</e1> from <e2>caterpillar</e2> to cocoon to butterfly in this easy reliable kit."
#
# Comment:
#
# ================================================================================
# 116, pred: Cause-Effect(e2,e1), true: Other
# <mood> "(<X>, nsubj) (inside, prep) (<Y>, pobj)" <car>
# 7226	"The <e1>mood</e1> inside the <e2>car</e2> was very quiet as the couple continued home and went to bed."
#
# Comment: Here mood stands for the "people in a given/quiet mood" but people shouldn't be contents. None of the nine relations holds.
#
# ================================================================================
# 117, pred: Other, true: Other
# <wine> "(<X>, dobj) (put, ROOT) (in, prep) (<Y>, pobj)" <<OOV>>
# 7227	"Television cooking shows and more advertising have put <e1>wine</e1> in the <e2>limelight</e2>."
#
# Comment: None of the nine relations holds; it cannot be Entity-Destination because of b.1 in E-D's definition
#
# ================================================================================
# 118, pred: Entity-Origin(e1,e2), true: Instrument-Agency(e2,e1)
# <villagers> "(<X>, nsubj) (operate, ROOT) (<Y>, dobj)" <press>
# 7228	"Currently, the <e1>villagers</e1> operate a ram oil <e2>press</e2> that is counter-intuitive to use and leads to sub-optimal oil extraction from groundnuts."
#
# Comment:
#
# ================================================================================
# 119, pred: Member-Collection(e2,e1), true: Content-Container(e2,e1)
# <building> "(<X>, nsubj) (contained, ROOT) (amount, dobj) (of, prep) (<Y>, pobj)" <furniture>
# 7229	"The <e1>building</e1> contained a significant amount of <e2>furniture</e2> and equipment."
#
# Comment: Even if the candidate container is a building, it really seems to be used as a store for furniture.
#
# ================================================================================
# 120, pred: Message-Topic(e2,e1), true: Cause-Effect(e1,e2)
# <zinc> "(<X>, nsubj) (is, ROOT) (for, prep) (<Y>, pobj)" <growth>
# 7230	"<e1>Zinc</e1> is essential for <e2>growth</e2> and cell division."
#
# Comment:
#
# ================================================================================
# 121, pred: Entity-Origin(e1,e2), true: Other
# <<OOV>> "(<X>, nsubj) (<OOV>, ROOT) (through, prep) (<Y>, pobj)" <foods>
# 7231	"With its non-slip, ambidextrous grip, the <e1>peeler</e1> glides effortlessly through <e2>foods</e2>."
#
# Comment:
#
# ================================================================================
# 122, pred: Other, true: Instrument-Agency(e2,e1)
# <officer> "(<X>, nsubj) (uses, ROOT) (<Y>, dobj)" <gun>
# 7232	"Police <e1>officer</e1> uses a Taser stun <e2>gun</e2> to subdue a glass-wielding six-year-old."
#
# Comment:
#
# ================================================================================
# 123, pred: Message-Topic(e1,e2), true: Entity-Origin(e2,e1)
# <land> "(<X>, nsubjpass) (farmed, ROOT) (for, prep) (<Y>, pobj)" <wheat>
# 7233	"The <e1>land</e1> surrounding the lakes is extensively farmed for <e2>wheat</e2>, while elsewhere in the National Park the steppe is heavily grazed by domestic livestock."
#
# Comment:
#
# ================================================================================
# 124, pred: Message-Topic(e2,e1), true: Cause-Effect(e1,e2)
# <vocals> "(<X>, nsubj) (are, ROOT) (from, prep) (<Y>, pobj)" <female>
# 7234	"The backup <e1>vocals</e1> are from a rather talented <e2>female</e2>, Stephanie Eitel."
#
# Comment:
#
# ================================================================================
# 125, pred: Entity-Origin(e1,e2), true: Entity-Origin(e1,e2)
# <audio> "(<X>, dobj) (sharing, conj) (from, prep) (<Y>, pobj)" <event>
# 7235	"So you are not only sharing the speaker information, but you are also sharing the <e1>audio</e1> from the <e2>event</e2> quickly and easily."
#
# Comment:
#
# ================================================================================
# 126, pred: Member-Collection(e2,e1), true: Content-Container(e2,e1)
# <contents> "(<X>, nsubj) (included, ROOT) (<OOV>, dobj) (of, prep) (<Y>, pobj)" <<OOV>>
# 7236	"The remaining <e1>contents</e1> of the package included four ounces of <e2>plastique</e2> filled with tiny metallic slivers."
#
# Comment: A package can be consider a container.
#
# ================================================================================
# 127, pred: Entity-Destination(e1,e2), true: Content-Container(e1,e2)
# <newspaper> "(<X>, nsubjpass) (kept, ROOT) (in, prep) (<Y>, pobj)" <box>
# 7237	"The <e1>newspaper</e1> was being kept in a <e2>box</e2>."
#
# Comment: A prototypical example.
#
# ================================================================================
# ...
# 848, pred: Product-Producer(e2,e1), true: Other
# <<OOV>> "(<X>, ROOT) (became, advcl) (<Y>, nsubj)" <meals>
# 7958	"<e1>Brushing</e1> after <e2>meals</e2> became part of your daily schedule."
#
# Comment:
#
# ================================================================================
# 849, pred: Message-Topic(e2,e1), true: Other
# <bus> "(<X>, compound) (<Y>, nsubj)" <company>
# 7959	"A <e1>bus</e1> <e2>company</e2> has pledged a week-long roadside survey after a group of workers complained about its Bradford to Morley service."
#
# Comment: In this sentence the bus company does not produce the buses but it uses them.
#
# ================================================================================
# 850, pred: Member-Collection(e2,e1), true: Cause-Effect(e1,e2)
# <crowd> "(<X>, nsubj) (<OOV>, ROOT) (<Y>, dobj)" <<OOV>>
# 7960	"When deliberations began, the <e1>crowd</e1> of people jamming the hallways radiated <e2>optimism</e2>."
#
# Comment:
#
# ================================================================================
# 851, pred: Message-Topic(e1,e2), true: Component-Whole(e1,e2)
# <sink> "(<X>, pobj) (in, prep) (<Y>, pobj)" <kitchen>
# 7961	"We have a bright and cheery yellow casement window over the <e1>sink</e1> in my <e2>kitchen</e2>."
#
# Comment: The sink is an integral and functional part of the kitchen (equipment).
#
# ================================================================================
# 852, pred: Cause-Effect(e2,e1), true: Other
# <player> "(<X>, nsubj) (played, ROOT) (with, prep) (<Y>, pobj)" <<OOV>>
# 7962	"The snooker <e1>player</e1> played the game with a <e2>smile</e2> on his face."
#
# Comment: The player isn't using his smile for anything. Could be Cause-Effect?
#
# ================================================================================
# 853, pred: Component-Whole(e1,e2), true: Entity-Origin(e1,e2)
# <wine> "(<X>, dobj) (produced, acl) (from, prep) (<Y>, pobj)" <<OOV>>
# 7963	"Europeans have rejected <e1>wine</e1> produced from genetically modified <e2>grapevines</e2>, which has caused Californian wine-growers, who rely heavily on the European market, to worry."
#
# Comment:
#
# ================================================================================
# 854, pred: Entity-Destination(e1,e2), true: Product-Producer(e1,e2)
# <<OOV>> "(<X>, compound) (<Y>, nsubj)" <maker>
# 7964	"Because the ice in the smoothie has to be crushed and blended with the other ingredients, a <e1>smoothie</e1> <e2>maker</e2> is usually the appliance of choice."
#
# Comment:
#
# ================================================================================
# 855, pred: Message-Topic(e2,e1), true: Product-Producer(e1,e2)
# <<OOV>> "(<X>, nsubj) (comes, ROOT) (from, prep) (<Y>, pobj)" <bishop>
# 7965	"The <e1>defamation</e1> comes from a <e2>bishop</e2>."
#
# Comment:
#
# ================================================================================
# 856, pred: Entity-Origin(e1,e2), true: Entity-Origin(e1,e2)
# <advice> "(<X>, nsubjpass) (<OOV>, ROOT) (from, prep) (<Y>, pobj)" <builders>
# 7966	"The following <e1>advice</e1> is distilled from <e2>builders</e2> and first-hand experience."
#
# Comment:
#
# ================================================================================
# 857, pred: Cause-Effect(e2,e1), true: Content-Container(e1,e2)
# <air> "(<X>, nsubj) (in, prep) (<Y>, pobj)" <jar>
# 7967	"The <e1>air</e1> in the <e2>jar</e2> started circulating to the rest of the room."
#
# Comment: Works more or less, though air is shapeless and hard to get out.
#
# ================================================================================
# 858, pred: Product-Producer(e2,e1), true: Cause-Effect(e2,e1)
# <growth> "(<X>, dobj) (from, prep) (<Y>, pobj)" <exports>
# 7968	"But Hong Kong was able to recover from that and is now experiencing strong economic <e1>growth</e1> from <e2>exports</e2>."
#
# Comment:
#
# ================================================================================
# 859, pred: Member-Collection(e2,e1), true: Product-Producer(e2,e1)
# <legislature> "(<X>, nsubj) (created, ROOT) (<Y>, dobj)" <<OOV>>
# 7969	"The <e1>legislature</e1> created the <e2>ombudsman</e2> to intervene when children or their parents are subjected to unauthorized or unreasonable agency decisions."
#
# Comment: The ombudsman is an organisational role.
#
# ================================================================================
# 860, pred: Component-Whole(e2,e1), true: Cause-Effect(e1,e2)
# <sun> "(<X>, nsubj) (<OOV>, ROOT) (<Y>, dobj)" <light>
# 7970	"The <e1>sun</e1> emits <e2>light</e2> or radiation at a large range of energies or frequencies."
#
# Comment:
#
# ================================================================================
# 861, pred: Content-Container(e1,e2), true: Product-Producer(e2,e1)
# <chef> "(<X>, nsubj) (prepares, ROOT) (<Y>, dobj)" <meal>
# 7971	"Then, while you relax, the <e1>chef</e1> prepares the <e2>meal</e2> and serves it, restaurant-style."
#
# Comment:
#
# ================================================================================
# 862, pred: Entity-Destination(e1,e2), true: Other
# <diets> "(<X>, nsubj) (contained, ccomp) (density, dobj) (<Y>, compound)" <energy>
# 7972	"However, the fact that the guinea pigs appeared to function in a normal physiological manner indicates that the <e1>diets</e1> contained the necessary <e2>energy density</e2>."
#
# Comment: energy density seems to be a property of the diets.
#
# ================================================================================
# 863, pred: Product-Producer(e2,e1), true: Product-Producer(e2,e1)
# <student> "(<X>, nsubj) (provided, ROOT) (<Y>, dobj)" <request>
# 7973	"The <e1>student</e1> provided a written <e2>request</e2>, mailed to the Executive Director of the Pacific Division."
#
# Comment:
#
# ================================================================================
# 864, pred: Entity-Origin(e1,e2), true: Entity-Origin(e1,e2)
# <<OOV>> "(<X>, conj) (from, prep) (<Y>, pobj)" <soap>
# 7974	"In order for handwashing to be effective, vigorous friction, ample <e1>lather</e1> from <e2>soap</e2>, and thorough rinsing are needed to remove the germs from the hands."
#
# Comment:
#
# ================================================================================
# 865, pred: Cause-Effect(e1,e2), true: Cause-Effect(e2,e1)
# <<OOV>> "(<X>, advcl) (with, prep) (<Y>, pobj)" <<OOV>>
# 7975	"Mr C notes <e1>worsening</e1> of seizures and cognition with sleep <e2>deprivation</e2> and stress."
#
# Comment:
#
# ================================================================================
# 866, pred: Content-Container(e1,e2), true: Product-Producer(e1,e2)
# <<OOV>> "(<X>, compound) (<Y>, dobj)" <maker>
# 7976	"Get a <e1>quesadilla</e1> <e2>maker</e2> from one of your local discount stores such as Target, Walmart, or Kmart."
#
# Comment:
#
# ================================================================================
# 867, pred: Product-Producer(e2,e1), true: Instrument-Agency(e2,e1)
# <<OOV>> "(<X>, nsubj) (<OOV>, ROOT) (<Y>, dobj)" <<OOV>>
# 7977	"Bernie the <e1>barber</e1> downed his <e2>scissors</e2>, leaving the final triangle of hair uncut."
#
# Comment: The sentence actually describes the barber not using his scissors, but the implication is that he had used them.
#
# ================================================================================
# 868, pred: Instrument-Agency(e2,e1), true: Entity-Origin(e2,e1)
# <grass> "(<X>, nsubjpass) (farmed, ccomp) (for, prep) (<Y>, pobj)" <hay>
# 7978	"Not too long ago, the <e1>grass</e1> was farmed for <e2>hay</e2>; then, it was ditched for mosquito control."
#
# Comment: Grass is the raw material from which hay is made.
#
# ================================================================================
# 869, pred: Instrument-Agency(e2,e1), true: Other
# <explosion> "(<X>, nsubj) (cultivated, ROOT) (<Y>, dobj)" <scene>
# 7979	"The punk <e1>explosion</e1> cultivated the underground/indie rock <e2>scene</e2> that would one day be called 'alternative music'."
#
# Comment: modality is outside
#
# ================================================================================
# 870, pred: Entity-Origin(e1,e2), true: Other
# <<OOV>> "(<X>, nsubjpass) (made, ROOT) (from, prep) (<Y>, pobj)" <materials>
# 7980	"The <e1>carpet</e1> is made from recycled <e2>materials</e2>."
#
# Comment:
#
# ================================================================================
# 871, pred: Entity-Origin(e1,e2), true: Other
# <<OOV>> "(<X>, compound) (<Y>, nsubj)" <company>
# 7981	"This is incorrect, and when a <e1>minicab</e1> <e2>company</e2> uses the word taxi on their livery it can lead to prosecution by the local government body."
#
# Comment: In this sentence the mincab company does not produce the minicabs but it uses them.
#
# ================================================================================
# 872, pred: Instrument-Agency(e2,e1), true: Instrument-Agency(e2,e1)
# <<OOV>> "(<X>, nsubj) (throws, relcl) (hook, dobj) (<Y>, amod)" <<OOV>>
# 7982	"A goal is like a mountain outcropping to which a <e1>climber</e1> throws a <e2>grappling hook</e2> and pulls themselves up."
#
# Comment:
#
# ================================================================================
# 873, pred: Member-Collection(e2,e1), true: Other
# <<OOV>> "(<X>, nsubj) (keeps, ROOT) (<Y>, dobj)" <discussion>
# 7983	"A <e1>facilitator</e1> keeps the <e2>discussion</e2> focused and limited to the allotted time, while the recorder keeps a written record of the panel's recommendations."
#
# Comment:
#
# ================================================================================
# 874, pred: Content-Container(e1,e2), true: Cause-Effect(e2,e1)
# <<OOV>> "(<X>, dobj) (<OOV>, ROOT) (from, prep) (<Y>, pobj)" <exposure>
# 7984	"Hand creams counteract <e1>dryness</e1> from <e2>exposure</e2> to wind, sun, and detergents."
#
# Comment:
#
# ================================================================================
# 875, pred: Message-Topic(e1,e2), true: Cause-Effect(e2,e1)
# <<OOV>> "(<X>, nsubjpass) (from, prep) (effect, pobj) (<Y>, amod)" <<OOV>>
# 7985	"Eye <e1>discomfort</e1> from this <e2>staring effect</e2> is exacerbated by low humidity."
#
# Comment:
#
# ================================================================================
# 876, pred: Cause-Effect(e2,e1), true: Product-Producer(e2,e1)
# <company> "(<X>, attr) (made, relcl) (<Y>, dobj)" <<OOV>>
# 7986	"The lower mark is the Vienna <e1>company</e1> that made the <e2>mug</e2>."
#
# Comment:
#
# ================================================================================
# 877, pred: Cause-Effect(e2,e1), true: Cause-Effect(e1,e2)
# <transmitter> "(<X>, nsubj) (<OOV>, ROOT) (<Y>, dobj)" <signal>
# 7987	"The <e1>transmitter</e1> emits a constant radio <e2>signal</e2> to crea."
#
# Comment:
#
# ================================================================================
# 878, pred: Product-Producer(e2,e1), true: Cause-Effect(e2,e1)
# <anxiety> "(<X>, dobj) (experience, ROOT) (from, prep) (<Y>, pobj)" <fear>
# 7988	"Parents also experience <e1>anxiety</e1> from <e2>fear</e2> of the suffering of their child and worry about an uncertain outcome."
#
# Comment:
#
# ================================================================================
# 879, pred: Entity-Destination(e1,e2), true: Instrument-Agency(e1,e2)
# <horse> "(<X>, nsubj) (<OOV>, ccomp) (<Y>, dobj)" <rider>
# 7989	"It just so happened that the <e1>horse</e1> bucked the <e2>rider</e2> and threw him into a mud-puddle."
#
# Comment:
#
# ================================================================================
# 880, pred: Member-Collection(e2,e1), true: Entity-Origin(e2,e1)
# <turtles> "(<X>, nsubjpass) (farmed, ROOT) (for, prep) (<Y>, pobj)" <food>
# 7990	"In some Asian countries, including China, Malaysia and the Philippines, the <e1>turtles</e1> are farmed for <e2>food</e2>."
#
# Comment: Food is a concrete substance.
#
# ================================================================================
# 881, pred: Message-Topic(e1,e2), true: Product-Producer(e2,e1)
# <<OOV>> "(<X>, nsubj) (makes, ROOT) (<Y>, dobj)" <prescription>
# 7991	"Using an e-prescription module in an electronic record system, the <e1>prescriber</e1> makes out a <e2>prescription</e2> and transfers it to the national e-prescription mailbox."
#
# Comment:
#
# ================================================================================
# 882, pred: Entity-Origin(e1,e2), true: Product-Producer(e2,e1)
# <citizens> "(<X>, nsubj) (created, ROOT) (<Y>, dobj)" <states>
# 7992	"State <e1>citizens</e1> created the <e2>states</e2> who created the federal government who created federal citizens."
#
# Comment: Organisational units can be Products
#
# ================================================================================
# 883, pred: Member-Collection(e2,e1), true: Cause-Effect(e2,e1)
# <<OOV>> "(<X>, nsubjpass) (produced, acl) (by, agent) (<Y>, pobj)" <reaction>
# 7993	"In chemical lasers the <e1>inversion</e1> is produced by a chemical <e2>reaction</e2>."
#
# Comment:
#
# ================================================================================
# 884, pred: Cause-Effect(e2,e1), true: Product-Producer(e1,e2)
# <<OOV>> "(<X>, nsubj) (are, ROOT) (from, prep) (<Y>, pobj)" <truck>
# 7994	"The <e1>streaks</e1> are from a passing <e2>truck</e2>."
#
# Comment:
#
# ================================================================================
# 885, pred: Instrument-Agency(e1,e2), true: Other
# <engine> "(<X>, nsubj) (<OOV>, ROOT) (<Y>, dobj)" <concept>
# 7995	"A V8 <e1>engine</e1> mated with a manual transmission powers the convertible <e2>concept</e2>."
#
# Comment: The engine is an integral and functional part of the concept (car). Agencies cannot use their parts as Intruments.
#
# ================================================================================
# 886, pred: Product-Producer(e2,e1), true: Other
# <notice> "(<X>, nsubjpass) (sent, advcl) (by, agent) (<Y>, pobj)" <<OOV>>
# 7996	"When the <e1>notice</e1> is sent by <e2>fax</e2>, the notice is not deemed received until 3 days after faxing it."
#
# Comment:
#
# ================================================================================
# 887, pred: Content-Container(e1,e2), true: Entity-Origin(e1,e2)
# <<OOV>> "(<X>, nsubjpass) (derived, ROOT) (from, prep) (<Y>, pobj)" <antibiotic>
# 7997	"The <e1>herbicide</e1> is derived from a natural <e2>antibiotic</e2>, which is produced by two strains of a soil bacterium."
#
# Comment:
#
# ================================================================================
# 888, pred: Content-Container(e1,e2), true: Entity-Destination(e1,e2)
# <match> "(<X>, dobj) (placed, ROOT) (in, prep) (<Y>, pobj)" <jar>
# 7998	"To test this, we placed a kitchen <e1>match</e1> in the <e2>jar</e2> instead of the candle, lit the match, screwed on the lid and dropped the jar."
#
# Comment:
#
# ================================================================================
# 889, pred: Entity-Origin(e1,e2), true: Other
# <farmers> "(<X>, compound) (<Y>, dobj)" <market>
# 7999	"The farmers and city officials in the region have tried to get state money to move the <e1>farmers</e1> <e2>market</e2> into a first-class operation and tourist attraction."
#
# Comment:
#
# ================================================================================
# 890, pred: Member-Collection(e1,e2), true: Product-Producer(e2,e1)
# <surgeon> "(<X>, nsubj) (cuts, ROOT) (<Y>, dobj)" <hole>
# 8000	"The <e1>surgeon</e1> cuts a small <e2>hole</e2> in the skull and lifts the edge of the brain to expose the nerve."
#
# Comment:
#
# ================================================================================
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-264-0ef51d29dcec> in <module>()
#       1 for i, p in enumerate(preds):
# ----> 2     print("%i, pred: %s, true: %s" %(i, int2label[p], int2label[valid['labels'][i]]))
#       3     target = DH.sequence_to_sentence(valid['targets'][i]).split(' ')
#       4     sdp = DH.sequence_to_sentence(valid['sdps'][i], show_dep=True)
#       5     print('<%s> "%s" <%s>' % (target[0], sdp, target[1]))
#
# IndexError: list index out of range

# %%
def confusion_matrix(preds, labels, label_set):
    size = len(label_set)
    matrix = np.zeros([size, size]) # rows are predictions, columns are truths
    # fill in matrix
    for p, l in zip(preds, labels):
        matrix[p,l] += 1
    # compute class specific scores
    class_precision = np.zeros(size)
    class_recall = np.zeros(size)
    for label in range(size):
        tp = matrix[label, label]
        fp = np.sum(matrix[label, :]) - tp
        fn = np.sum(matrix[:, label]) - tp
        class_precision[label] = tp/float(tp + fp) if tp or fp else 0
        class_recall[label] = tp/float(tp + fn) if tp or fn else 0
    micro_f1 = np.array([2*(p*r)/(p+r) if p or r else 0 for (p, r) in zip(class_precision, class_recall)])
    avg_precision = np.mean(class_precision)
    avg_recall = np.mean(class_recall)
    macro_f1 = (2*avg_precision*avg_recall) / (avg_precision + avg_recall)
    stats = {'micro_precision':class_precision,
             'micro_recall':class_recall, 
             'micro_f1':micro_f1,
             'macro_precision':avg_precision, 
             'macro_recall':avg_recall,
             'macro_f1':macro_f1}
    return matrix, stats
label_set = set(train['labels'])
cm, stats = confusion_matrix(preds, valid['labels'], label_set)
print("Macro F1: %0.4f" % stats['macro_f1'])
# Out:
# Macro F1: 0.0353

# %%
def plot_confusion_matrix(cm, label_names, save_name=None, title='Normed Confusion matrix', cmap=plt.cm.Blues, stats=None):
    fig, ax = plt.subplots(figsize=(20,20))
    
    # calc normalized cm
    x, y = np.meshgrid(range(cm.shape[0]), range(cm.shape[1]))
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)
    cm_normalized[np.isnan(cm_normalized)] = 0.0
    
    # print nonzero raw counts
    for x_val, y_val in zip(x.flatten(), y.flatten()):
        norm = cm_normalized[x_val, y_val]
        c = "%i" % (cm.astype('int')[x_val, y_val])
        if norm > 0.0:
            color = 'white' if norm > .5 else 'black'
            ax.text(y_val, x_val, c, va='center', ha='center', color=color)
    
    # actual plot
    im = ax.imshow(cm_normalized, interpolation='nearest', origin='upper', cmap=cmap)
#     divider = plt.make_axes_locatable(ax)
#     cax = divider.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(im, fraction=0.046, pad=0.04)
    
    # set ticks and offset grid
    tick_marks = np.arange(len(label_names))
    tick_marks_offset = np.arange(len(label_names)) - .5
    ax.set_xticks(tick_marks, minor=False)
    ax.set_yticks(tick_marks, minor=False)
    ax.set_xticks(tick_marks_offset, minor=True)
    ax.set_yticks(tick_marks_offset, minor=True)
    ax.grid(which='minor')
    if stats:
        # include micro precisio, recall, and f1
        aug_y_labels = []
        for i in range(len(label_names)):
            aug = ("%s\nP:%0.2f, R:%0.2f, F1:%0.2f" 
                   % (label_names[i],
                      stats['micro_precision'][i],
                      stats['micro_recall'][i],
                      stats['micro_f1'][i],))
            aug_y_labels.append(aug)
    else:
        aug_x_labels = label_names
    ax.set_xticklabels(label_names, rotation=75, horizontalalignment='left', x=1)
    ax.xaxis.tick_top()
    ax.set_yticklabels(aug_y_labels)
    
    # other stuff
    plt.tight_layout()
    plt.ylabel('Predicted Labels', fontsize=16)
    if stats:
        # include macro 
        aug_x_label = ("True Labels\n Macro P:%0.2f, R:%0.2f, F1:%0.2f" 
                       % (stats['macro_precision'], stats['macro_recall'], stats['macro_f1']))
    else:
        aug_x_label = "True Label"
    plt.xlabel(aug_x_label, fontsize=16)
    plt.title(title, y=1.12, fontsize=20)
    if save_name:
        plt.savefig(save_name+'.pdf')
        
save_name = raw_input("Enter save name: ")
plot_confusion_matrix(cm, int2label.values(), save_name=save_name, stats=stats)
# Out:
# Enter save name:
# /Users/thomaseffland/.virtualenvs/rel/lib/python2.7/site-packages/ipykernel/__main__.py:6: RuntimeWarning: invalid value encountered in divide
