# %%
from __future__ import print_function
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import re
import collections
import random
from time import time

from gensim.models import Word2Vec
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA, FastICA

import data_handler as dh
import semeval_data_helper as sdh
# plot settings
% matplotlib inline
# print(plt.rcParams.keys())
plt.rcParams['figure.figsize'] = (16,9)

# %%
# reload(sdh)

# %%
# print(DH.max_seq_len)
# paths, targets = DH.readable_data(show_dep=True)
# for p, t in zip(paths, targets) :
#     t = t.split(", ")
#     print("%s (%s) %s" % (t[0], p, t[1]))
# print('<X>' in DH.vocab)

# %%
class RelEmbed(object):
    """ Encapsulation of the dependency RNN lang model
    
    Largely inspired by https://github.com/tensorflow/tensorflow/blob/master/tensorflow/models/rnn/ptb/ptb_word_lm.py
    """
    def __init__(self, config):
#         self.batch_size = config['batch_size']
        self.max_num_steps = config['max_num_steps']
        self.word_embed_size = config['word_embed_size']
        self.dep_embed_size = config['dep_embed_size']
        self.input_size = self.word_embed_size + self.dep_embed_size
        self.hidden_size = 2 * self.word_embed_size #config['hidden_size']
        self.pretrained_word_embeddings = config['pretrained_word_embeddings'] # None if we don't provide them
        if np.any(self.pretrained_word_embeddings):
            assert self.word_embed_size == self.pretrained_word_embeddings.shape[1]
        self.num_classes = config['num_predict_classes']
        self.max_grad_norm = config['max_grad_norm']
        
        self.vocab_size = config['vocab_size']
        self.dep_vocab_size = config['dep_vocab_size']
        self.name = config['model_name']
        self.checkpoint_prefix = config['checkpoint_prefix'] + self.name
        self.summary_prefix = config['summary_prefix'] + self.name
        
        self.initializer = tf.random_uniform_initializer(-1., 1.)
        with tf.name_scope(self.name):
            with tf.name_scope("Forward"):
                self._build_forward_graph()
                self._build_classification_graph()
            with tf.name_scope("Backward"):
                self._build_train_graph()
                self._build_class_train_graph()
            with tf.name_scope("Nearby"):
                self._build_similarity_graph()
        
        self._valid_accuracy = tf.Variable(0.0, trainable=False)
        self._valid_acc_summary = tf.merge_summary([tf.scalar_summary("Valid_accuracy", self._valid_accuracy)])

        self.saver = tf.train.Saver(tf.all_variables())
            
        self.session = tf.InteractiveSession()
        self.session.run(tf.initialize_all_variables())        
        self.summary_writer = tf.train.SummaryWriter(self.summary_prefix, self.session.graph_def)
        
    def save_validation_accuracy(self, new_score):
        assign_op = self._valid_accuracy.assign(new_score)
        _, summary = self.session.run([assign_op, self._valid_acc_summary])
        self.summary_writer.add_summary(summary)
        
    def _build_forward_graph(self):
        # input tensor of zero padded indices to get to max_num_steps
        # None allows for variable batch sizes
        with tf.name_scope("Inputs"):
            self._input_phrases = tf.placeholder(tf.int32, [None, self.max_num_steps, 2]) # [batch_size, w_{1:N}, 2]
            self._input_targets = tf.placeholder(tf.int32, [None, 2]) # [batch_size, w_x]
            self._input_labels = tf.placeholder(tf.int32, [None, 1]) # [batch_size, from true data?] \in {0,1}
            self._input_lengths = tf.placeholder(tf.int32, [None, 1]) # [batch_size, N] (len of each sequence)
            batch_size = tf.shape(self._input_lengths)[0]
            self._keep_prob = tf.placeholder(tf.float32)
        
        with tf.name_scope("Embeddings"):
            if np.any(self.pretrained_word_embeddings):
                self._word_embeddings = tf.Variable(self.pretrained_word_embeddings,name="word_embeddings")
                self._left_target_embeddings = tf.Variable(self.pretrained_word_embeddings, name="left_target_embeddings")
                self._right_target_embeddings = tf.Variable(self.pretrained_word_embeddings, name="right_target_embeddings")
            else:
                self._word_embeddings = tf.get_variable("word_embeddings", 
                                                        [self.vocab_size, self.word_embed_size],
                                                        dtype=tf.float32)
                self._left_target_embeddings = tf.get_variable("left_target_embeddings", 
                                                        [self.vocab_size, self.word_embed_size],
                                                        dtype=tf.float32)
                self._right_target_embeddings = tf.get_variable("right_target_embeddings", 
                                                        [self.vocab_size, self.word_embed_size],
                                                        dtype=tf.float32)
            
            self._dependency_embeddings = tf.get_variable("dependency_embeddings", 
                                                    [self.dep_vocab_size, self.dep_embed_size],
                                                    dtype=tf.float32)
            # TODO: Add POS embeddings
            
            input_embeds = tf.nn.embedding_lookup(self._word_embeddings, 
                                                  tf.slice(self._input_phrases, [0,0,0], [-1, -1, 1]))
            dep_embeds = tf.nn.embedding_lookup(self._dependency_embeddings,
                                                tf.slice(self._input_phrases, [0,0,1], [-1, -1, 1]))
            left_target_embeds = tf.nn.embedding_lookup(self._left_target_embeddings, 
                                                        tf.slice(self._input_targets, [0,0], [-1, 1]))
            right_target_embeds = tf.nn.embedding_lookup(self._right_target_embeddings, 
                                                        tf.slice(self._input_targets, [0,1], [-1, 1]))
#             print(tf.slice(self._input_phrases, [0,0,1], [-1, -1, 1]).get_shape(), dep_embeds.get_shape())
#             print(left_target_embeds.get_shape(), right_target_embeds.get_shape())
            self._target_embeds = tf.nn.dropout(tf.squeeze(tf.concat(2, [left_target_embeds, right_target_embeds]), [1]), 
                                                keep_prob=self._keep_prob)
#             print(target_embeds.get_shape())
            # TODO: Add dropout to embeddings
        
        with tf.name_scope("RNN"):
            # start off with a basic configuration
            self.cell = tf.nn.rnn_cell.GRUCell(self.hidden_size, 
                                                input_size=self.input_size)
            # TODO: Add Dropout wrapper
            # TODO: Make it multilevel
#             self._initial_state = self.cell.zero_state(batch_size, tf.float32)
#             print(self._initial_state.get_shape())
            input_words = [ tf.squeeze(input_, [1, 2]) for input_ in tf.split(1, self.max_num_steps, input_embeds)]
            input_deps = [ tf.squeeze(input_, [1, 2]) for input_ in tf.split(1, self.max_num_steps, dep_embeds)]
            inputs = [ tf.concat(1, [input_word, input_dep]) 
                      for (input_word, input_dep) in zip(input_words, input_deps)]

            _, state = tf.nn.rnn(self.cell, inputs, 
                                 sequence_length=tf.squeeze(self._input_lengths, [1]),
                                 dtype=tf.float32)
#                                  initial_state=self._initial_state)
            self._final_state = tf.nn.dropout(state, keep_prob= self._keep_prob)
            
        with tf.name_scope("Loss"):
            flat_states = tf.reshape(state, [-1])
            flat_target_embeds = tf.reshape(self._target_embeds, [-1])
#             assert self.hidden_size == (self.word_embed_size), "Hidden state must equal concated inputs" 
            flat_logits = tf.mul(flat_states, flat_target_embeds)
            logits = tf.reduce_sum(tf.reshape(flat_logits, tf.pack([batch_size, -1])), 1)
            self._loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits, 
                                                                    tf.to_float(self._input_labels)),
                                        name="neg_sample_loss") + .001*tf.nn.l2_loss(logits)
            
        with tf.name_scope("Summaries"):
            
            self._train_cost_summary = tf.merge_summary([tf.scalar_summary("Train_NEG_Loss", self._loss)])
            self._valid_cost_summary = tf.merge_summary([tf.scalar_summary("Validation_NEG_Loss", self._loss)])
        
    def _build_classification_graph(self):
        with tf.name_scope("Classifier"):
            self._softmax_input = tf.concat(1, [self._final_state, self._target_embeds], name="concat_input")
            self._softmax_w = tf.get_variable("softmax_w", [self._softmax_input.get_shape()[1], self.num_classes])
            self._softmax_b = tf.Variable(tf.zeros([self.num_classes], dtype=tf.float32), name="softmax_b")

            class_logits = tf.matmul(self._softmax_input, self._softmax_w) + self._softmax_b
            self._predictions = tf.argmax(class_logits, 1, name="predict")
            self._predict_probs = tf.nn.softmax(class_logits, name="predict_probabilities")
        
        with tf.name_scope("Loss"):
            self._class_labels = tf.placeholder(tf.int64, [None, 1])
            self._class_loss = tf.nn.sparse_softmax_cross_entropy_with_logits(class_logits, 
                                                                              tf.squeeze(self._class_labels, [1]))
            self._avg_class_loss = tf.reduce_mean(self._class_loss) + .001*(tf.nn.l2_loss(self._softmax_w)
                                                                         + tf.nn.l2_loss(self._softmax_b))
            self._train_class_loss_summary = tf.merge_summary([tf.scalar_summary("Train_Avg_Class_Xent", self._avg_class_loss)])
            self._valid_class_loss_summary = tf.merge_summary([tf.scalar_summary("Valid_Avg_Class_Xent", self._avg_class_loss)])

    def _build_train_graph(self):
        with tf.name_scope("Unsupervised_Trainer"):
            self._global_step = tf.Variable(0, name="global_step", trainable=False)
#             self._lr = tf.Variable(1.0, trainable=False)
            self._optimizer = tf.train.AdagradOptimizer(1.0)
            
            # clip and apply gradients
            grads_and_vars = self._optimizer.compute_gradients(self._loss)
#             for gv in grads_and_vars:
#                 print(gv, gv[1] is self._cost)
            clipped_grads_and_vars = [(tf.clip_by_norm(gv[0], self.max_grad_norm), gv[1]) 
                                      for gv in grads_and_vars if gv[0] is not None] # clip_by_norm doesn't like None
            
            with tf.name_scope("Summaries"):
                grad_summaries = []
                for g, v in grads_and_vars:
                    if g is not None:
                        grad_hist_summary = tf.histogram_summary("{}/grad/hist".format(v.name), g)
                        sparsity_summary = tf.scalar_summary("{}/grad/sparsity".format(v.name), tf.nn.zero_fraction(g))
                        grad_summaries.append(grad_hist_summary)
                        grad_summaries.append(sparsity_summary)
                self._grad_summaries = tf.merge_summary(grad_summaries)
            self._train_op = self._optimizer.apply_gradients(clipped_grads_and_vars, global_step=self._global_step)
            
    def _build_class_train_graph(self):
        with tf.name_scope("Classification_Trainer"):
            self._class_global_step = tf.Variable(0, name="class_global_step", trainable=False)
#             self._lr = tf.Variable(1.0, trainable=False)
            self._class_optimizer = tf.train.AdagradOptimizer(1.0)
            
            # clip and apply gradients
            grads_and_vars = self._class_optimizer.compute_gradients(self._class_loss)
#             for gv in grads_and_vars:
#                 print(gv, gv[1] is self._cost)
            clipped_grads_and_vars = [(tf.clip_by_norm(gv[0], self.max_grad_norm), gv[1]) 
                                      for gv in grads_and_vars if gv[0] is not None] # clip_by_norm doesn't like None
            
            with tf.name_scope("Summaries"):
                grad_summaries = []
                for g, v in grads_and_vars:
                    if g is not None:
                        grad_hist_summary = tf.histogram_summary("class_{}/grad/hist".format(v.name), g)
                        sparsity_summary = tf.scalar_summary("class_{}/grad/sparsity".format(v.name), tf.nn.zero_fraction(g))
                        grad_summaries.append(grad_hist_summary)
                        grad_summaries.append(sparsity_summary)
                self._class_grad_summaries = tf.merge_summary(grad_summaries)
            self._class_train_op = self._class_optimizer.apply_gradients(clipped_grads_and_vars, 
                                                                         global_step=self._class_global_step)
            
    def _build_similarity_graph(self):
        tf.get_variable_scope().reuse_variables()
        with tf.name_scope("Inputs"):
            # word or phrase we want similarities for
#             self._query_word = tf.placeholder(tf.int32, [1], name="q_word")
            self._query_phrase = tf.placeholder(tf.int32, [self.max_num_steps, 2], name="q_phrase")
            self._query_length = tf.placeholder(tf.int32, [1], name="q_len") # lengths for RNN
            # words and phrases to compute similarities over
#             self._sim_words = tf.placeholder(tf.int32, [None, 1])
            self._sim_phrases = tf.placeholder(tf.int32, [None, self.max_num_steps, 2])
            self._sim_lengths = tf.placeholder(tf.int32, [None, 1]) # lengths for RNN
            sim_size = tf.shape(self._sim_lengths)[0]
        
        with tf.name_scope("Embeddings"):
            query_phrase_embed = tf.nn.embedding_lookup(self._word_embeddings, 
                                                  tf.slice(self._query_phrase, [0,0], [-1, 1]))
            query_dep_embed = tf.nn.embedding_lookup(self._dependency_embeddings,
                                                tf.slice(self._query_phrase, [0,1], [-1, 1]))
#             query_word_embed = tf.nn.embedding_lookup(self._word_embeddings, self._query_word)
#             query_phrase_embed = tf.nn.embedding_lookup(self._word_embeddings, self._query_phrase)
#             sim_word_embed = tf.nn.embedding_lookup(self._word_embeddings, tf.squeeze(self._sim_words, [1]))
            sim_phrase_embed = tf.nn.embedding_lookup(self._word_embeddings, 
                                                  tf.slice(self._sim_phrases, [0, 0, 0], [-1, -1, 1]))
            sim_dep_embed = tf.nn.embedding_lookup(self._dependency_embeddings, 
                                                  tf.slice(self._sim_phrases, [0, 0, 1], [-1, -1, 1]))
        
        with tf.name_scope("RNN"):
            # compute rep of a query phrase
            query_phrase = [tf.squeeze(qw, [1]) for qw in tf.split(0, self.max_num_steps, query_phrase_embed)]
            query_dep = [tf.squeeze(qd, [1]) for qd in tf.split(0, self.max_num_steps, query_dep_embed)]
#             print(query_phrase[0].get_shape(), query_dep[0].get_shape())
            query_input = [ tf.concat(1, [qw, qd]) for (qw, qd) in zip(query_phrase, query_dep)]
            _, query_phrase_state = tf.nn.rnn(self.cell, query_input, 
                                              sequence_length=self._query_length, 
                                              dtype=tf.float32)
            # compute reps of similarity phrases
            sim_phrases = [tf.squeeze(qw, [1,2]) for qw in tf.split(1, self.max_num_steps, sim_phrase_embed)]
            sim_deps = [tf.squeeze(qd, [1,2]) for qd in tf.split(1, self.max_num_steps, sim_dep_embed)]
            sim_input = [ tf.concat(1, [qw, qd]) for (qw, qd) in zip(sim_phrases, sim_deps)]
            _, sim_phrase_states = tf.nn.rnn(self.cell, sim_input, 
                                             sequence_length=tf.squeeze(self._sim_lengths, [1]), 
                                             dtype=tf.float32)
            
        with tf.name_scope("Similarities"):
            with tf.name_scope("Normalize"):
#                 print(query_phrase.get_shape())
                query_phrase = tf.nn.l2_normalize(query_phrase_state, 1)
#                 query_word = tf.nn.l2_normalize(query_word_embed, 1)
                sim_phrases = tf.nn.l2_normalize(sim_phrase_states, 1)
#                 sim_word = tf.nn.l2_normalize(sim_word_embed, 1)                

            with tf.name_scope("Calc_distances"):
                # do for words
#                 print(q)
#                 query_word_nearby_dist = tf.matmul(query_word, sim_word, transpose_b=True)
#                 qw_nearby_val, qw_nearby_idx = tf.nn.top_k(query_word_nearby_dist, min(1000, self.vocab_size))
#                 self.qw_nearby_val = tf.squeeze(qw_nearby_val)
#                 self.qw_nearby_idx = tf.squeeze(qw_nearby_idx)
#                 self.qw_nearby_words = tf.squeeze(tf.gather(self._sim_words, qw_nearby_idx))

                # do for phrases
                query_phrase_nearby_dist = tf.matmul(query_phrase, sim_phrases, transpose_b=True)
                qp_nearby_val, qp_nearby_idx = tf.nn.top_k(query_phrase_nearby_dist, min(1000, sim_size))
#                 self.sanity_check = tf.squeeze(tf.matmul(query_phrase, query_phrase, transpose_b=True))
                self.qp_nearby_val = tf.squeeze(qp_nearby_val)
                self.qp_nearby_idx = tf.squeeze(qp_nearby_idx)
#                 self.qp_nearby_lens = tf.squeeze(tf.gather(self._sim_lengths, qp_nearby_idx))
            
    def partial_class_fit(self, input_phrases, input_targets, class_labels, input_lengths):
        """Fit a mini-batch
        
        Expects a batch_x: [self.batch_size, self.max_num_steps]
                  batch_y: the same
                  batch_seq_lens: [self.batch_size]
                  
        Returns average batch perplexity
        """
        loss, _, g_summaries, c_summary = self.session.run([self._avg_class_loss, self._class_train_op, 
                                                            self._class_grad_summaries,
                                                            self._train_class_loss_summary],
                                                           {self._input_phrases:input_phrases,
                                                            self._input_targets:input_targets,
                                                            self._class_labels:class_labels,
                                                            self._input_lengths:input_lengths,
                                                            self._keep_prob:.5})
        self.summary_writer.add_summary(g_summaries)
        self.summary_writer.add_summary(c_summary)
        return loss
    
    def partial_unsup_fit(self, input_phrases, input_targets, input_labels, input_lengths):
        """Fit a mini-batch
        
        Expects a batch_x: [self.batch_size, self.max_num_steps]
                  batch_y: the same
                  batch_seq_lens: [self.batch_size]
                  
        Returns average batch perplexity
        """
        loss, _, g_summaries, c_summary = self.session.run([self._loss, self._train_op, 
                                                            self._grad_summaries,
                                                            self._train_cost_summary],
                                                           {self._input_phrases:input_phrases,
                                                            self._input_targets:input_targets,
                                                            self._input_labels:input_labels,
                                                            self._input_lengths:input_lengths,
                                                            self._keep_prob:.5})
        self.summary_writer.add_summary(g_summaries)
        self.summary_writer.add_summary(c_summary)
        return loss
    
    def validation_loss(self, valid_phrases, valid_targets, valid_labels, valid_lengths):
        """Calculate loss on validation inputs, but don't run trainer"""
        loss, v_summary = self.session.run([self._loss, self._valid_cost_summary],
                                           {self._input_phrases:valid_phrases,
                                            self._input_targets:valid_targets,
                                            self._input_labels:valid_labels,
                                            self._input_lengths:valid_lengths,
                                                            self._keep_prob:1.0})
        self.summary_writer.add_summary(v_summary)
        return loss
    
    def validation_class_loss(self, valid_phrases, valid_targets, valid_labels, valid_lengths):
        """Calculate loss on validation inputs, but don't run trainer"""
        loss, v_summary = self.session.run([self._avg_class_loss, self._valid_class_loss_summary],
                                           {self._input_phrases:valid_phrases,
                                            self._input_targets:valid_targets,
                                            self._class_labels:valid_labels,
                                            self._input_lengths:valid_lengths,
                                                            self._keep_prob:1.0})
        self.summary_writer.add_summary(v_summary)
        return loss
    
    def validation_phrase_nearby(self, q_phrase, q_phrase_len, sim_phrases, sim_phrase_lens):
        """Return nearby phrases from the similarity set
        """
        nearby_vals, nearby_idx = self.session.run([self.qp_nearby_val, self.qp_nearby_idx],
                                                                   {self._query_phrase:q_phrase, 
                                                                    self._query_length:q_phrase_len,
                                                                    self._sim_phrases:sim_phrases,
                                                                    self._sim_lengths:sim_phrase_lens,
                                                            self._keep_prob:1.0})
#         print("Sanity check: %r" % sanity)
        return nearby_vals, nearby_idx
    
    def embed_phrases_and_targets(self, phrases, targets, lengths):
        phrase_reps, target_reps = self.session.run([self._final_state, self._target_embeds],
                                                    { self._input_phrases:phrases,
                                                      self._input_targets:targets,
                                                      self._input_lengths:lengths,
                                                            self._keep_prob:1.0})
        return phrase_reps, target_reps
    
#     def validation_word_nearby(self, q_word, sim_words):
#         """Return nearby phrases from the similarity set
#         """
#         nearby_vals, nearby_idx = self.session.run([self.qw_nearby_val, 
#                                                       self.qw_nearby_idx],
#                                                        {self._query_word:q_word, 
#                                                         self._sim_words:sim_words})
#         return nearby_vals, nearby_idx
        
    def predict(self, paths, targets, path_lens, return_probs=False):
        if return_probs:
            predictions, distributions = self.session.run([self._predictions, self._predict_probs],
                                                          {self._input_phrases:paths,
                                                           self._input_targets:targets,
                                                           self._input_lengths:path_lens,
                                                            self._keep_prob:1.0})
            distributions = distributions.reshape([path_lens.shape[0], -1])
            return list(predictions), list(distributions)
#             pred_list = []
#             dist_list = []
#             for i, seq_len in enumerate(path_lens):
#                 pred_list.append(list(predictions[i, :path_len]))
#                 dist_list.append([distributions[i,j,:] for j in range(path_len)])
#             return pred_list, dist_list
        
        else:
            predictions = self.session.run(self._predictions,
                                           {self._predict_inputs:paths,
                                            self._predict_targets:targets,
                                            self._predict_lengths:path_lens})
            return list(predictions)
#             pred_list = []
#             for i, seq_len in enumerate(seq_lens):
#                 pred_list.append(list(predictions[i, :seq_len])) 
#             return pred_list
            
    def checkpoint(self):
        self.saver.save(self.session, self.checkpoint_prefix + '.ckpt', global_step=self._global_step)
        
    def restore(self, model_ckpt_path):
        self.saver.restore(self.session, model_ckpt_path)
        
    def __repr__(self):
        return ("<DPNN: W:%i, D:%i, H:%i, V:%i>" 
                % (self.word_embed_size, self.dep_embed_size, self.hidden_size, self.vocab_size))

# %%
reload(dh)
DH = dh.DataHandler('data/semeval_train_sdp_8000', valid_percent=10)
# Out:
# Creating Data objects...
# Done creating Data objects
# 7999 total examples :: 7199 training : 800 valid (90:10 split)
# Vocab size: 22683 Dep size: 50

# %%
print('<X>' in DH.vocab)
# Out:
# True

# %%
# %time
# load the pretrained word embeddings
fname = 'data/GoogleNews-vectors-negative300.bin'
word2vec = Word2Vec.load_word2vec_format(fname, binary=True)
# Out:
# CPU times: user 1e+03 ns, sys: 0 ns, total: 1e+03 ns
# Wall time: 4.05 µs

# %%
reload(sdh)
train, valid, test, label2int, int2label = sdh.load_semeval_data()
num_classes = len(int2label.keys())
# Out:
# Didn't find common ancestor
# 1790	"The imams were removed from a US Airways <e1>flight</e1> awaiting departure from the Minneapolis-St. Paul <e2>airport</e2>."
#
# (The imams were removed from a US Airways flight awaiting departure from the Minneapolis - St . Paul airport ., flight , airport )
# Bad sentence: '1790\t"The imams were removed from a US Airways <e1>flight</e1> awaiting departure from the Minneapolis-St. Paul <e2>airport</e2>."\r\n'
# ((The imams were removed from a US Airways flight awaiting departure from the Minneapolis - St . Paul airport ., flight , airport ), None)
# Skipping this one... '1790\t"The imams were removed from a US Airways <e1>flight</e1> awaiting departure from the Minneapolis-St. Paul <e2>airport</e2>."\r\n'
# (None, None, None, 4)
# Num training: 7108
# Num valididation: 891
# Didn't find common ancestor
# 8310	"Tributes have been paid to the <e1>writer</e1> who created Goodness Gracious Me, the hit BBC television <e2>series</e2>."
#
# (Tributes have been paid to the writer who created Goodness Gracious Me , the hit BBC television series ., writer , series )
# Bad sentence: '8310\t"Tributes have been paid to the <e1>writer</e1> who created Goodness Gracious Me, the hit BBC television <e2>series</e2>."\r\n'
# ((Tributes have been paid to the writer who created Goodness Gracious Me , the hit BBC television series ., writer , series ), None)
# Skipping this one... '8000\t"The <e1>surgeon</e1> cuts a small <e2>hole</e2> in the skull and lifts the edge of the brain to expose the nerve."\r\n'
# (None, None, None, 3)
# Num testing: 2717

# %%
# %%bash
# git pull

# %%
# convert the semeval data to indices under the wiki vocab:
train['sdps'] = DH.sentences_to_sequences(train['sdps'])
valid['sdps'] = DH.sentences_to_sequences(valid['sdps'])
test['sdps'] = DH.sentences_to_sequences(test['sdps'])
    
train['targets'] = DH.sentences_to_sequences(train['targets'])
valid['targets'] = DH.sentences_to_sequences(valid['targets'])
test['targets'] = DH.sentences_to_sequences(test['targets'])

# %%
max_seq_len = max([len(path) for path in train['sdps']+valid['sdps']+test['sdps']])
print(max_seq_len, DH.max_seq_len)
DH.max_seq_len = max_seq_len
# Out:
# 13 13

# %%
# the embedding matrix is started of as random uniform [-1,1]
# then we replace everything but the OOV tokens with the approprate google vector
word_embeddings = np.random.uniform(low=-1., high=1., size=[DH.vocab_size, 300]).astype(np.float32)
num_found = 0
for i, token in enumerate(DH.vocab):
    if token in word2vec:
        word_embeddings[i] = word2vec[token]
        num_found += 1
print("%i / %i pretrained" % (num_found, DH.vocab_size))
# Out:
# 19423 / 22683 pretrained

# %%
config = {
    'max_num_steps':DH.max_seq_len,
    'word_embed_size':300,
    'dep_embed_size':25,
    'vocab_size':DH.vocab_size,
    'dep_vocab_size':DH.dep_size,
    'num_predict_classes':num_classes,
    'pretrained_word_embeddings':word_embeddings,
    'max_grad_norm':3.,
    'model_name':'drnn_wiki_semeval_w2v',
    'checkpoint_prefix':'checkpoints/',
    'summary_prefix':'tensor_summaries/'
}
try:
    tf.reset_default_graph()
except:
    pass
try:
    tf.get_default_session().close()
except:
    pass
drnn = RelEmbed(config)
print(drnn)
# Out:
# <DPNN: W:300, D:25, H:600, V:22683>

# %%
def run_validation_test(num_nearby=20):
    valid_phrases, valid_targets , _, valid_lens = DH.validation_batch()
    random_index = int(random.uniform(0, len(valid_lens)))
    query_phrase = valid_phrases[random_index]
    query_len = valid_lens[random_index]
    query_target = valid_targets[random_index]
    padded_qp = np.zeros([DH.max_seq_len, 2]).astype(np.int32)
    padded_qp[:len(query_phrase), 0] = [x[0] for x in query_phrase]
    padded_qp[:len(query_phrase), 1] = [x[1] for x in query_phrase]    
    dists, phrase_idx = drnn.validation_phrase_nearby(padded_qp, query_len, valid_phrases, valid_lens)
    print("="*80)
    print("Top %i closest phrases to <%s> '%s' <%s>" 
          % (num_nearby, DH.vocab_at(query_target[0]), 
             DH.sequence_to_sentence(query_phrase, query_len), 
             DH.vocab_at(query_target[1])))
    for i in range(num_nearby):
        dist = dists[i]
        phrase = valid_phrases[phrase_idx[i]]
        len_ = valid_lens[phrase_idx[i]]
        target = valid_targets[phrase_idx[i]]
        print("%i: %0.3f : <%s> '%s' <%s>" 
              % (i, dist, DH.vocab_at(target[0]),
                 DH.sequence_to_sentence(phrase, len_),
                 DH.vocab_at(target[1])))
    print("="*80)
#     drnn.save_validation_accuracy(frac_correct)

# %%
def time_left(num_epochs, num_steps, fit_time, nearby_time, start_time, nearby_mod):
    total = num_epochs*num_steps*fit_time + ((num_epochs*num_steps)/float(nearby_mod))*nearby_time
    return total - (time() - start_time)

# %% [markdown]
# # Unsupervised Training

# %%
# hyperparameters
num_epochs = 1
batch_size =50
neg_per = 25
num_nearby = 50
nearby_mod = 50
sample_power = .75
DH.scale_vocab_dist(sample_power)

# bookkeeping
num_steps = DH.num_steps(batch_size)
total_step = 1
save_interval = 30 * 60 # half hour in seconds
save_time = time()

#timing stuff
start = time()
fit_time = 0
nearby_time = 0

for epoch in range(num_epochs):
    offset = 0 #if epoch else 400
    DH.shuffle_data()
    for step , batch in enumerate(DH.batches(batch_size, offset=offset, neg_per=neg_per)):
        if not step: step = offset
        t0 = time()
        loss = drnn.partial_unsup_fit(*batch)
        fit_time = (fit_time * float(total_step) +  time() - t0) / (total_step + 1) # running average
        if step % 10 == 0:
            m,s = divmod(time()-start, 60)
            h,m = divmod(m, 60)
            left = time_left(num_epochs, num_steps, fit_time, nearby_time, start, nearby_mod)
            ml,sl = divmod(left, 60)
            hl,ml = divmod(ml, 60)
            pps = batch_size*(neg_per + 1) / fit_time 
            print("(%i:%i:%i) step %i/%i, epoch %i Training Loss = %1.5f :: %0.3f phrases/sec :: (%i:%i:%i) hours left" 
                  % (h,m,s, step, num_steps, epoch, loss, pps, hl, ml, sl))
        if (total_step-1) % nearby_mod == 0: # do one right away so we get a good timing estimate
            t0 = time()
            run_validation_test(num_nearby) # check out the nearby phrases in the validation set
            valid_loss = drnn.validation_loss(*DH.validation_batch())
            print("Validation loss: %0.4f" % valid_loss)
            nearby_time = (nearby_time * float(total_step) + time() - t0) / (total_step + 1) # running average

        if (time() - save_time) > save_interval:
            print("Saving model...")
            drnn.checkpoint()
            save_time = time()
        total_step +=1
drnn.checkpoint()
# Out:
# (0:0:7) step 0/10311, epoch 0 Training Loss = 0.24386 :: 1176.826 phrases/sec :: (3:9:42) hours left
# ================================================================================
# Top 50 closest phrases to <conjunction> '<X> with systems track <Y>' <systems>
# 0: 1.000 : <conjunction> '<X> with systems track <Y>' <systems>
# 1: 0.991 : <weapons> '<X> is systems for <Y>' <army>
# 2: 0.989 : <archdiocese> '<X> in based with <Y>' <dioceses>
# 3: 0.988 : <length> '<X> is running from <Y>' <source>
# 4: 0.988 : <versions> '<X> release called with <Y>' <buffers>
# 5: 0.988 : <director> '<X> systems for <Y>' <intelligence>
# 6: 0.988 : <who> '<X> is out from <Y>' <sentence>
# 7: 0.988 : <foundation> '<X> promotes system for <Y>' <management>
# 8: 0.987 : <event> '<X> events two in <Y>' <kong>
# 9: 0.987 : <season> '<X> end finishing with <Y>' <wickets>
# 10: 0.987 : <m> '<X> in established with <Y>' <time>
# 11: 0.987 : <city> '<X> in located with <Y>' <offices>
# 12: 0.987 : <factory> '<X> factory date from <Y>' <1940s>
# 13: 0.987 : <rivals> '<X> as designated with <Y>' <syracuse>
# 14: 0.987 : <he> '<X> was with <Y>' <pick>
# 15: 0.987 : <it> '<X> was installed in <Y>' <rings>
# 16: 0.987 : <speeds> '<X> as engaged with <Y>' <clutch>
# 17: 0.987 : <half> '<X> be campus for <Y>' <heights>
# 18: 0.987 : <public> '<X> in performing with <Y>' <bands>
# 19: 0.987 : <division> '<X> in were with <Y>' <time>
# 20: 0.987 : <growth> '<X> with is <Y>' <india>
# 21: 0.987 : <ceramics> '<X> indicate date in <Y>' <dynasty>
# 22: 0.987 : <fort> '<X> from take with <Y>' <sea>
# 23: 0.987 : <centre> '<X> as benefits from <Y>' <days>
# 24: 0.987 : <season> '<X> for returning with <Y>' <harbour>
# 25: 0.986 : <name> '<X> combines as in <Y>' <example>
# 26: 0.986 : <dorsum> '<X> with connected by <Y>' <patch>
# 27: 0.986 : <they> '<X> run operations in <Y>' <wing>
# 28: 0.986 : <they> '<X> are used by <Y>' <riders>
# 29: 0.986 : <he> '<X> began working for <Y>' <cards>
# 30: 0.986 : <weapons> '<X> put come with <Y>' <hands>
# 31: 0.986 : <songs> '<X> learn go with <Y>' <him>
# 32: 0.986 : <october> '<X> on confirmed by <Y>' <vote>
# 33: 0.986 : <hero> '<X> is in <Y>' <imagination>
# 34: 0.986 : <groups> '<X> have in <Y>' <russia>
# 35: 0.986 : <states> '<X> state original over <Y>' <suits>
# 36: 0.986 : <christ> '<X> were utilized in <Y>' <practices>
# 37: 0.986 : <government> '<X> announced building system for <Y>' <backbone>
# 38: 0.986 : <who> '<X> had make at <Y>' <ceremony>
# 39: 0.986 : <january> '<X> on called for <Y>' <country>
# 40: 0.986 : <skaters> '<X> be present on <Y>' <ice>
# 41: 0.986 : <record> '<X> set with <Y>' <reception>
# 42: 0.986 : <him> '<X> with were on <Y>' <occasion>
# 43: 0.986 : <november> '<X> on won with <Y>' <%>
# 44: 0.986 : <july> '<X> in wrote as <Y>' <man>
# 45: 0.986 : <sloan> '<X> by started in <Y>' <attempt>
# 46: 0.986 : <beginning> '<X> at request in <Y>' <place>
# 47: 0.986 : <firmly> '<X> established with <Y>' <devotion>
# 48: 0.986 : <region> '<X> been area for <Y>' <arrival>
# 49: 0.986 : <march> '<X> in signed with <Y>' <town>
# ================================================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-199-bd1d24c80898> in <module>()
#      39             t0 = time()
#      40             run_validation_test(num_nearby) # check out the nearby phrases in the validation set
# ---> 41             valid_loss = drnn.validation_loss(*DH.validation_batch())
#      42             print("Validation loss: %0.4f" % valid_loss)
#      43             nearby_time = (nearby_time * float(total_step) + time() - t0) / (total_step + 1) # running average
#
# <ipython-input-64-4099403ccf06> in validation_loss(self, valid_phrases, valid_targets, valid_labels, valid_lengths)
#     308                                             self._input_targets:valid_targets,
#     309                                             self._input_labels:valid_labels,
# --> 310                                             self._input_lengths:valid_lengths})
#     311         self.summary_writer.add_summary(v_summary)
#     312         return loss
#
# /Users/thomaseffland/.virtualenvs/rel/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict)
#     313         `Tensor` that doesn't exist.
#     314     """
# --> 315     return self._run(None, fetches, feed_dict)
#     316
#     317   def partial_run(self, handle, fetches, feed_dict=None):
#
# /Users/thomaseffland/.virtualenvs/rel/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict)
#     509     # Run request and get response.
#     510     results = self._do_run(handle, target_list, unique_fetches,
# --> 511                            feed_dict_string)
#     512
#     513     # User may have fetched the same tensor multiple times, but we
#
# /Users/thomaseffland/.virtualenvs/rel/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict)
#     562     if handle is None:
#     563       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 564                            target_list)
#     565     else:
#     566       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/thomaseffland/.virtualenvs/rel/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#     569   def _do_call(self, fn, *args):
#     570     try:
# --> 571       return fn(*args)
#     572     except tf_session.StatusNotOK as e:
#     573       e_type, e_value, e_traceback = sys.exc_info()
#
# /Users/thomaseffland/.virtualenvs/rel/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list)
#     553       # Ensure any changes to the graph are reflected in the runtime.
#     554       self._extend_graph()
# --> 555       return tf_session.TF_Run(session, feed_dict, fetch_list, target_list)
#     556
#     557     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
drnn.checkpoint()

# %%
# # test the embeddings

# ### VALID ###
# # valid_phrases, valid_targets, _, valid_lens = DH.validation_batch()
# # phrase_embeds, target_embeds = drnn.embed_phrases_and_targets(valid_phrases, valid_targets, valid_lens)
# # phrase_labels, target_labels = DH.readable_data(valid=True)

# ### TRAIN ###
# train_phrases, train_targets, _, train_lens = DH.batches(500, neg_per=0, offset=0).next()
# phrase_embeds, target_embeds = drnn.embed_phrases_and_targets(train_phrases, train_targets, train_lens)
# phrase_labels, target_labels = DH.readable_data(show_dep=False, valid=False)
        
# phrase_embeds /= np.sqrt(np.sum(phrase_embeds**2, 1, keepdims=True))
# target_embeds /= np.sqrt(np.sum(target_embeds**2, 1, keepdims=True))

# %%
# ### JOINT ###
# start = 0
# stride = 40
# end = start + stride

# lowd = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
# # lowd = PCA(n_components=2)

# joint_embeds = np.vstack([phrase_embeds[start:end], target_embeds[start:end]])
# joint_2d = lowd.fit_transform(joint_embeds)
# phrase_2d, target_2d = joint_2d[:stride], joint_2d[stride:]

# fig, ax = plt.subplots(figsize=(20,16))
# for i, label in enumerate(phrase_labels[start:end]):
#     label = "%i: %s" % (i, label)
#     x, y = phrase_2d[i,:]
#     ax.scatter(x, y, color='b')
#     ax.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
#                    ha='right', va='bottom')
# for i, label in enumerate(target_labels[start:end]):
#     label = "%i: %s" % (i, label)
#     x, y = target_2d[i,:]
#     ax.scatter(x, y, color='r')
#     ax.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
#                    ha='right', va='bottom')

# %%
# ### PHRASE ONLY ###
# start = 0
# stride = 50
# end = start + stride

# lowd = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
# # lowd = PCA(n_components=2)

# phrase_2d = lowd.fit_transform(phrase_embeds[start:end])

# fig, ax = plt.subplots(figsize=(20,16))
# for i, label in enumerate(phrase_labels[start:end]):
#     label = "%i: %s" % (i, label)
#     x, y = phrase_2d[i,:]
#     ax.scatter(x, y, color='b')
#     ax.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
#                    ha='right', va='bottom')

# %%
# ### TARGET ONLY ###
# start = 0
# stride = 35
# end = start + stride

# lowd = TSNE(perplexity=20, n_components=2, init='pca', n_iter=5000)
# # lowd = PCA(n_components=2)

# target_2d = lowd.fit_transform(target_embeds[start:end])

# fig, ax = plt.subplots(figsize=(20,16))
# for i, label in enumerate(target_labels[start:end]):
#     label = "%i: %s" % (i, label)
#     x, y = target_2d[i,:]
#     ax.scatter(x, y, color='r')
#     ax.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
#                    ha='right', va='bottom')

# %%
### TW2V demo ###
start = 200
stride = 100
end = start + stride

lowd = TSNE(perplexity=20, n_components=2, init='pca', n_iter=5000)
# lowd = PCA(n_components=2)

target_2d = lowd.fit_transform(word_embeddings[start:end])

fig, ax = plt.subplots(figsize=(28,16))
for i, label in enumerate(DH.vocab[start:end]):
    label = "%s" % (label)
    x, y = target_2d[i,:]
    ax.scatter(x, y, color='b')
    ax.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
    
plt.savefig('word2vec_demo.png', dpi=200)

# %% [markdown]
# # Test out semeval data

# %%
zip_train = zip(train['raws'], train['sents'], train['sdps'], train['targets'], train['labels'])
zip_valid = zip(valid['raws'], valid['sents'], valid['sdps'], valid['targets'], valid['labels'])
zip_test = zip(test['raws'], test['sents'], test['sdps'], test['targets'])

# %%
for i, (raw, _, sdp, target, label) in enumerate(zip_train):
    if i > 5:
        break
    print(raw)
    print("%s :: %s" % (DH.sequence_to_sentence(sdp, show_dep=True), DH.sequence_to_sentence(target)))
    print(int2label[label])
    print("="*80)
# Out:
# 1	"The system as described above has its greatest application in an arrayed <e1>configuration</e1> of antenna <e2>elements</e2>."
#
# (<X>, pobj) (of, prep) (<Y>, pobj) :: configuration elements
# Component-Whole(e2,e1)
# ================================================================================
# 2	"The <e1>child</e1> was carefully wrapped and bound into the <e2>cradle</e2> by means of a cord."
#
# (<X>, nsubjpass) (wrapped, ROOT) (bound, conj) (into, prep) (<Y>, pobj) :: child cradle
# Other
# ================================================================================
# 3	"The <e1>author</e1> of a keygen uses a <e2>disassembler</e2> to look at the raw assembly code."
#
# (<X>, nsubj) (uses, ROOT) (<Y>, dobj) :: author disassembler
# Instrument-Agency(e2,e1)
# ================================================================================
# 4	"A misty <e1>ridge</e1> uprises from the <e2>surge</e2>."
#
# (<X>, nsubj) (uprises, ROOT) (from, prep) (<Y>, pobj) :: ridge surge
# Other
# ================================================================================
# 5	"The <e1>student</e1> <e2>association</e2> is the voice of the undergraduate student population of the State University of New York at Buffalo."
#
# (<X>, compound) (<Y>, nsubj) :: student association
# Member-Collection(e1,e2)
# ================================================================================
# 6	"This is the sprawling <e1>complex</e1> that is Peru's largest <e2>producer</e2> of silver."
#
# (<X>, attr) (is, relcl) (<Y>, attr) :: complex producer
# Other
# ================================================================================

# %% [markdown]
# # Supervised Training

# %%
batch_size = 50
num_steps = len(train['labels']) // batch_size
num_epochs = 25
display_mod = 10
valid_mod = 50



print(num_steps)

start = time()
for epoch in range(num_epochs):
#     class_batch = DH.classification_batch(batch_size, train['sdps'], train['targets'], train['labels'], offset=0)
#     random.shuffle(class_batch)

    for step in range(10): # num_steps
        inputs, targets, labels, lens = DH.classification_batch(batch_size, train['sdps'], train['targets'], train['labels'], offset=step)
        class_batch = zip(inputs, targets, labels, lens)
        random.shuffle(class_batch)
        class_batch = zip(*class_batch)
        xent = drnn.partial_class_fit(*class_batch)
        if step % display_mod == 0:   
            m,s = divmod(time()-start, 60)
            h,m = divmod(m, 60)
            print("(%i:%i:%i) s %i/%i, e %i avg class xent loss = %0.4f" % (h,m,s, step, num_steps, epoch, xent))
        if step % valid_mod == 0:
            valid_batch = DH.classification_batch(len(valid['labels']), valid['sdps'], valid['targets'], valid['labels'])
            valid_xent = drnn.validation_class_loss(*valid_batch)
            m,s = divmod(time()-start, 60)
            h,m = divmod(m, 60)
            print("="*80)
            print("(%i:%i:%i) s %i/%i, e %i validation avg class xent loss = %0.4f" % (h,m,s, step, num_steps, epoch, valid_xent))
            print("="*80)
#             print("Saving model...")
#             drnn.checkpoint()
    label_set = set(train['labels'])
    preds, dists = drnn.predict(valid_batch[0], valid_batch[1], valid_batch[3], return_probs=True)
    cm, stats = confusion_matrix(preds, valid['labels'], label_set)
    print("Macro P: %2.4f, R: %3.4f, F1: %0.4f" % (stats['macro_precision'], stats['macro_recall'], stats['macro_f1']))
drnn.checkpoint()
print("Done")
# Out:
# 142
# (0:0:0) s 0/142, e 0 avg class xent loss = 3.0705
# ================================================================================
# (0:0:1) s 0/142, e 0 validation avg class xent loss = 12.6294
# ================================================================================
# Macro P: 0.0311, R: 0.0553, F1: 0.0398
# (0:0:6) s 0/142, e 1 avg class xent loss = 12.0206
# ================================================================================
# (0:0:6) s 0/142, e 1 validation avg class xent loss = 14.6648
# ================================================================================
# Macro P: 0.0673, R: 0.0697, F1: 0.0685
# (0:0:11) s 0/142, e 2 avg class xent loss = 6.0985
# ================================================================================
# (0:0:12) s 0/142, e 2 validation avg class xent loss = 8.6265
# ================================================================================
# Macro P: 0.1544, R: 0.1761, F1: 0.1646
# (0:0:17) s 0/142, e 3 avg class xent loss = 1.0158
# ================================================================================
# (0:0:18) s 0/142, e 3 validation avg class xent loss = 13.2326
# ================================================================================
# Macro P: 0.1558, R: 0.2112, F1: 0.1794
# (0:0:23) s 0/142, e 4 avg class xent loss = 1.3836
# ================================================================================
# (0:0:24) s 0/142, e 4 validation avg class xent loss = 7.8732
# ================================================================================
# Macro P: 0.2541, R: 0.1785, F1: 0.2097
# (0:0:29) s 0/142, e 5 avg class xent loss = 2.2380
# ================================================================================
# (0:0:29) s 0/142, e 5 validation avg class xent loss = 16.2512
# ================================================================================
# Macro P: 0.2201, R: 0.2109, F1: 0.2154
# (0:0:34) s 0/142, e 6 avg class xent loss = 1.2723
# ================================================================================
# (0:0:35) s 0/142, e 6 validation avg class xent loss = 15.0406
# ================================================================================
# Macro P: 0.2061, R: 0.2082, F1: 0.2072
# (0:0:40) s 0/142, e 7 avg class xent loss = 1.4894
# ================================================================================
# (0:0:41) s 0/142, e 7 validation avg class xent loss = 16.6982
# ================================================================================
# Macro P: 0.2125, R: 0.1528, F1: 0.1778
# (0:0:46) s 0/142, e 8 avg class xent loss = 1.7978
# ================================================================================
# (0:0:47) s 0/142, e 8 validation avg class xent loss = 14.3031
# ================================================================================
# Macro P: 0.2613, R: 0.2198, F1: 0.2387
# (0:0:53) s 0/142, e 9 avg class xent loss = 1.9046
# ================================================================================
# (0:0:53) s 0/142, e 9 validation avg class xent loss = 14.2017
# ================================================================================
# Macro P: 0.2398, R: 0.1888, F1: 0.2113
# (0:1:0) s 0/142, e 10 avg class xent loss = 2.0631
# ================================================================================
# (0:1:1) s 0/142, e 10 validation avg class xent loss = 16.0489
# ================================================================================
# Macro P: 0.2138, R: 0.2141, F1: 0.2139
# (0:1:8) s 0/142, e 11 avg class xent loss = 2.2245
# ================================================================================
# (0:1:9) s 0/142, e 11 validation avg class xent loss = 14.3068
# ================================================================================
# Macro P: 0.2169, R: 0.2598, F1: 0.2364
# (0:1:16) s 0/142, e 12 avg class xent loss = 2.3414
# ================================================================================
# (0:1:16) s 0/142, e 12 validation avg class xent loss = 16.4961
# ================================================================================
# Macro P: 0.2244, R: 0.1546, F1: 0.1831
# (0:1:23) s 0/142, e 13 avg class xent loss = 2.5517
# ================================================================================
# (0:1:23) s 0/142, e 13 validation avg class xent loss = 26.9857
# ================================================================================
# Macro P: 0.2339, R: 0.1790, F1: 0.2028
# (0:1:30) s 0/142, e 14 avg class xent loss = 2.9059
# ================================================================================
# (0:1:31) s 0/142, e 14 validation avg class xent loss = 16.6659
# ================================================================================
# Macro P: 0.2282, R: 0.1721, F1: 0.1962
# (0:1:38) s 0/142, e 15 avg class xent loss = 2.7887
# ================================================================================
# (0:1:39) s 0/142, e 15 validation avg class xent loss = 21.7851
# ================================================================================
# Macro P: 0.1975, R: 0.1669, F1: 0.1809
# (0:1:46) s 0/142, e 16 avg class xent loss = 2.8840
# ================================================================================
# (0:1:46) s 0/142, e 16 validation avg class xent loss = 20.0247
# ================================================================================
# Macro P: 0.2354, R: 0.2277, F1: 0.2314
# (0:1:54) s 0/142, e 17 avg class xent loss = 3.0831
# ================================================================================
# (0:1:54) s 0/142, e 17 validation avg class xent loss = 16.9189
# ================================================================================
# Macro P: 0.2005, R: 0.1764, F1: 0.1877
# (0:2:1) s 0/142, e 18 avg class xent loss = 3.2055
# ================================================================================
# (0:2:2) s 0/142, e 18 validation avg class xent loss = 19.1024
# ================================================================================
# Macro P: 0.2106, R: 0.1876, F1: 0.1984
# (0:2:10) s 0/142, e 19 avg class xent loss = 3.3289
# ================================================================================
# (0:2:10) s 0/142, e 19 validation avg class xent loss = 17.8690
# ================================================================================
# Macro P: 0.2105, R: 0.1792, F1: 0.1936
# (0:2:18) s 0/142, e 20 avg class xent loss = 3.4638
# ================================================================================
# (0:2:19) s 0/142, e 20 validation avg class xent loss = 23.1096
# ================================================================================
# Macro P: 0.2003, R: 0.1573, F1: 0.1762
# (0:2:27) s 0/142, e 21 avg class xent loss = 3.5687
# ================================================================================
# (0:2:27) s 0/142, e 21 validation avg class xent loss = 25.4918
# ================================================================================
# Macro P: 0.1998, R: 0.1525, F1: 0.1730
# (0:2:36) s 0/142, e 22 avg class xent loss = 3.7945
# ================================================================================
# (0:2:37) s 0/142, e 22 validation avg class xent loss = 19.8756
# ================================================================================
# Macro P: 0.1847, R: 0.1882, F1: 0.1864
# (0:2:46) s 0/142, e 23 avg class xent loss = 3.7164
# ================================================================================
# (0:2:46) s 0/142, e 23 validation avg class xent loss = 22.9692
# ================================================================================
# Macro P: 0.1865, R: 0.1998, F1: 0.1929
# (0:2:55) s 0/142, e 24 avg class xent loss = 3.9902
# ================================================================================
# (0:2:56) s 0/142, e 24 validation avg class xent loss = 39.0681
# ================================================================================
# Macro P: 0.1799, R: 0.1497, F1: 0.1634
# Done

# %% [markdown]
# # Unsupervised 10 then Supervised 25

# %%
# hyperparameters
num_epochs = 5
batch_size =50
neg_per = 25
num_nearby = 20
nearby_mod = 50
sample_power = .75
DH.scale_vocab_dist(sample_power)

# # bookkeeping
num_steps = DH.num_steps(batch_size)
total_step = 1
save_interval = 30 * 60 # half hour in seconds
save_time = time()

#timing stuff
start = time()
fit_time = 0
nearby_time = 0

for epoch in range(num_epochs):
    offset = 0 #if epoch else 400
    DH.shuffle_data()
    for step , batch in enumerate(DH.batches(batch_size, offset=offset, neg_per=neg_per)):
        if not step: step = offset
        t0 = time()
        loss = drnn.partial_unsup_fit(*batch)
        fit_time = (fit_time * float(total_step) +  time() - t0) / (total_step + 1) # running average
        if step % 10 == 0:
            m,s = divmod(time()-start, 60)
            h,m = divmod(m, 60)
            left = time_left(num_epochs, num_steps, fit_time, nearby_time, start, nearby_mod)
            ml,sl = divmod(left, 60)
            hl,ml = divmod(ml, 60)
            pps = batch_size*(neg_per + 1) / fit_time 
            print("(%i:%i:%i) step %i/%i, epoch %i Training Loss = %1.5f :: %0.3f phrases/sec :: (%i:%i:%i) hours left" 
                  % (h,m,s, step, num_steps, epoch, loss, pps, hl, ml, sl))
        if (total_step-1) % nearby_mod == 0: # do one right away so we get a good timing estimate
            t0 = time()
            run_validation_test(num_nearby) # check out the nearby phrases in the validation set
            valid_loss = drnn.validation_loss(*DH.validation_batch())
            print("Validation loss: %0.4f" % valid_loss)
            nearby_time = (nearby_time * float(total_step) + time() - t0) / (total_step + 1) # running average

        if (time() - save_time) > save_interval:
            print("Saving model...")
            drnn.checkpoint()
            save_time = time()
        total_step +=1
    valid_batch = DH.classification_batch(len(valid['labels']), valid['sdps'], valid['targets'], valid['labels'])
    label_set = set(train['labels'])
    preds, dists = drnn.predict(valid_batch[0], valid_batch[1], valid_batch[3], return_probs=True)
    cm, stats = confusion_matrix(preds, valid['labels'], label_set)
    print("Macro P: %2.4f, R: %3.4f, F1: %0.4f" % (stats['macro_precision'], stats['macro_recall'], stats['macro_f1']))
drnn.checkpoint()

batch_size = 50
num_steps = len(train['labels']) // batch_size
num_epochs = 25
display_mod = 10
valid_mod = 50



print(num_steps)

start = time()
for epoch in range(num_epochs):
#     class_batch = DH.classification_batch(batch_size, train['sdps'], train['targets'], train['labels'], offset=0)
#     random.shuffle(class_batch)

    for step in range(10): # num_steps
        inputs, targets, labels, lens = DH.classification_batch(batch_size, train['sdps'], train['targets'], train['labels'], offset=step)
        class_batch = zip(inputs, targets, labels, lens)
        random.shuffle(class_batch)
        class_batch = zip(*class_batch)
        xent = drnn.partial_class_fit(*class_batch)
        if step % display_mod == 0:   
            m,s = divmod(time()-start, 60)
            h,m = divmod(m, 60)
            print("(%i:%i:%i) s %i/%i, e %i avg class xent loss = %0.4f" % (h,m,s, step, num_steps, epoch, xent))
        if step % valid_mod == 0:
            valid_batch = DH.classification_batch(len(valid['labels']), valid['sdps'], valid['targets'], valid['labels'])
            valid_xent = drnn.validation_class_loss(*valid_batch)
            m,s = divmod(time()-start, 60)
            h,m = divmod(m, 60)
            print("="*80)
            print("(%i:%i:%i) s %i/%i, e %i validation avg class xent loss = %0.4f" % (h,m,s, step, num_steps, epoch, valid_xent))
            print("="*80)
#             print("Saving model...")
#             drnn.checkpoint()
    label_set = set(train['labels'])
    preds, dists = drnn.predict(valid_batch[0], valid_batch[1], valid_batch[3], return_probs=True)
    cm, stats = confusion_matrix(preds, valid['labels'], label_set)
    print("Macro P: %2.4f, R: %3.4f, F1: %0.4f" % (stats['macro_precision'], stats['macro_recall'], stats['macro_f1']))
drnn.checkpoint()
print("Done")
# Out:
# 142
# (0:0:0) s 0/142, e 0 avg class xent loss = 2.9507
# ================================================================================
# (0:0:1) s 0/142, e 0 validation avg class xent loss = 2.9824
# ================================================================================
# Macro P: 0.0714, R: 0.0926, F1: 0.0806
# (0:0:6) s 0/142, e 1 avg class xent loss = 6.3099
# ================================================================================
# (0:0:6) s 0/142, e 1 validation avg class xent loss = 6.1716
# ================================================================================
# Macro P: 0.1217, R: 0.1216, F1: 0.1216
# (0:0:11) s 0/142, e 2 avg class xent loss = 0.7476
# ================================================================================
# (0:0:11) s 0/142, e 2 validation avg class xent loss = 7.5546
# ================================================================================
# Macro P: 0.1918, R: 0.1112, F1: 0.1408
# (0:0:16) s 0/142, e 3 avg class xent loss = 3.1162
# ================================================================================
# (0:0:17) s 0/142, e 3 validation avg class xent loss = 6.6212
# ================================================================================
# Macro P: 0.2148, R: 0.0867, F1: 0.1235
# (0:0:21) s 0/142, e 4 avg class xent loss = 1.4145
# ================================================================================
# (0:0:22) s 0/142, e 4 validation avg class xent loss = 8.7477
# ================================================================================
# Macro P: 0.2576, R: 0.1558, F1: 0.1942
# (0:0:27) s 0/142, e 5 avg class xent loss = 1.3885
# ================================================================================
# (0:0:27) s 0/142, e 5 validation avg class xent loss = 13.7181
# ================================================================================
# Macro P: 0.2284, R: 0.1759, F1: 0.1987
# (0:0:32) s 0/142, e 6 avg class xent loss = 1.3523
# ================================================================================
# (0:0:33) s 0/142, e 6 validation avg class xent loss = 12.7970
# ================================================================================
# Macro P: 0.2054, R: 0.2427, F1: 0.2225
# (0:0:38) s 0/142, e 7 avg class xent loss = 1.6371
# ================================================================================
# (0:0:39) s 0/142, e 7 validation avg class xent loss = 13.8121
# ================================================================================
# Macro P: 0.2071, R: 0.1732, F1: 0.1887
# (0:0:44) s 0/142, e 8 avg class xent loss = 1.7319
# ================================================================================
# (0:0:45) s 0/142, e 8 validation avg class xent loss = 13.4383
# ================================================================================
# Macro P: 0.2390, R: 0.1245, F1: 0.1637
# (0:0:51) s 0/142, e 9 avg class xent loss = 2.2234
# ================================================================================
# (0:0:51) s 0/142, e 9 validation avg class xent loss = 19.4009
# ================================================================================
# Macro P: 0.2340, R: 0.1827, F1: 0.2052
# (0:0:57) s 0/142, e 10 avg class xent loss = 3.4848
# ================================================================================
# (0:0:58) s 0/142, e 10 validation avg class xent loss = 12.9925
# ================================================================================
# Macro P: 0.2578, R: 0.1757, F1: 0.2090
# (0:1:4) s 0/142, e 11 avg class xent loss = 2.2765
# ================================================================================
# (0:1:5) s 0/142, e 11 validation avg class xent loss = 20.0309
# ================================================================================
# Macro P: 0.1964, R: 0.1402, F1: 0.1636
# (0:1:11) s 0/142, e 12 avg class xent loss = 2.5782
# ================================================================================
# (0:1:12) s 0/142, e 12 validation avg class xent loss = 15.4127
# ================================================================================
# Macro P: 0.2088, R: 0.1755, F1: 0.1907
# (0:1:19) s 0/142, e 13 avg class xent loss = 2.5166
# ================================================================================
# (0:1:19) s 0/142, e 13 validation avg class xent loss = 19.4894
# ================================================================================
# Macro P: 0.2351, R: 0.1680, F1: 0.1959
# (0:1:26) s 0/142, e 14 avg class xent loss = 2.6093
# ================================================================================
# (0:1:27) s 0/142, e 14 validation avg class xent loss = 19.3402
# ================================================================================
# Macro P: 0.2073, R: 0.1635, F1: 0.1828
# (0:1:34) s 0/142, e 15 avg class xent loss = 2.6904
# ================================================================================
# (0:1:34) s 0/142, e 15 validation avg class xent loss = 16.6035
# ================================================================================
# Macro P: 0.1981, R: 0.1755, F1: 0.1861
# (0:1:42) s 0/142, e 16 avg class xent loss = 2.7928
# ================================================================================
# (0:1:42) s 0/142, e 16 validation avg class xent loss = 15.4184
# ================================================================================
# Macro P: 0.2586, R: 0.1460, F1: 0.1866
# (0:1:49) s 0/142, e 17 avg class xent loss = 3.0306
# ================================================================================
# (0:1:50) s 0/142, e 17 validation avg class xent loss = 23.6081
# ================================================================================
# Macro P: 0.2539, R: 0.1438, F1: 0.1836
# (0:1:57) s 0/142, e 18 avg class xent loss = 2.9989
# ================================================================================
# (0:1:57) s 0/142, e 18 validation avg class xent loss = 24.6599
# ================================================================================
# Macro P: 0.2080, R: 0.1601, F1: 0.1810
# (0:2:5) s 0/142, e 19 avg class xent loss = 3.3322
# ================================================================================
# (0:2:5) s 0/142, e 19 validation avg class xent loss = 27.1683
# ================================================================================
# Macro P: 0.2384, R: 0.1781, F1: 0.2039
# (0:2:13) s 0/142, e 20 avg class xent loss = 3.2079
# ================================================================================
# (0:2:13) s 0/142, e 20 validation avg class xent loss = 19.9885
# ================================================================================
# Macro P: 0.2105, R: 0.1447, F1: 0.1715
# (0:2:21) s 0/142, e 21 avg class xent loss = 3.9483
# ================================================================================
# (0:2:21) s 0/142, e 21 validation avg class xent loss = 20.0404
# ================================================================================
# Macro P: 0.2103, R: 0.1736, F1: 0.1902
# (0:2:29) s 0/142, e 22 avg class xent loss = 3.3271
# ================================================================================
# (0:2:30) s 0/142, e 22 validation avg class xent loss = 21.0416
# ================================================================================
# Macro P: 0.2273, R: 0.1542, F1: 0.1837
# (0:2:37) s 0/142, e 23 avg class xent loss = 3.4691
# ================================================================================
# (0:2:38) s 0/142, e 23 validation avg class xent loss = 20.7716
# ================================================================================
# Macro P: 0.2089, R: 0.1614, F1: 0.1821
# (0:2:45) s 0/142, e 24 avg class xent loss = 3.6129
# ================================================================================
# (0:2:46) s 0/142, e 24 validation avg class xent loss = 35.8205
# ================================================================================
# Macro P: 0.2060, R: 0.1594, F1: 0.1797
# Done

# %% [markdown]
# # Alternating

# %%
for cycle in range(5):
    # hyperparameters
    num_epochs = 1
    batch_size =50
    neg_per = 25
    num_nearby = 20
    nearby_mod = 50
    sample_power = .75
    DH.scale_vocab_dist(sample_power)

    # # bookkeeping
    num_steps = DH.num_steps(batch_size)
    total_step = 1
    save_interval = 30 * 60 # half hour in seconds
    save_time = time()

    #timing stuff
    start = time()
    fit_time = 0
    nearby_time = 0
    for epoch in range(num_epochs):
        offset = 0 #if epoch else 400
        DH.shuffle_data()
        for step , batch in enumerate(DH.batches(batch_size, offset=offset, neg_per=neg_per)):
            if not step: step = offset
            t0 = time()
            loss = drnn.partial_unsup_fit(*batch)
            fit_time = (fit_time * float(total_step) +  time() - t0) / (total_step + 1) # running average
            if step % 10 == 0:
                m,s = divmod(time()-start, 60)
                h,m = divmod(m, 60)
                left = time_left(num_epochs, num_steps, fit_time, nearby_time, start, nearby_mod)
                ml,sl = divmod(left, 60)
                hl,ml = divmod(ml, 60)
                pps = batch_size*(neg_per + 1) / fit_time 
                print("(%i:%i:%i) step %i/%i, epoch %i Training Loss = %1.5f :: %0.3f phrases/sec :: (%i:%i:%i) hours left" 
                      % (h,m,s, step, num_steps, epoch, loss, pps, hl, ml, sl))
            if (total_step-1) % nearby_mod == 0: # do one right away so we get a good timing estimate
                t0 = time()
                run_validation_test(num_nearby) # check out the nearby phrases in the validation set
                valid_loss = drnn.validation_loss(*DH.validation_batch())
                print("Validation loss: %0.4f" % valid_loss)
                nearby_time = (nearby_time * float(total_step) + time() - t0) / (total_step + 1) # running average

            if (time() - save_time) > save_interval:
                print("Saving model...")
                drnn.checkpoint()
                save_time = time()
            total_step +=1
        valid_batch = DH.classification_batch(len(valid['labels']), valid['sdps'], valid['targets'], valid['labels'])
        label_set = set(train['labels'])
        preds, dists = drnn.predict(valid_batch[0], valid_batch[1], valid_batch[3], return_probs=True)
        cm, stats = confusion_matrix(preds, valid['labels'], label_set)
        print("Macro P: %2.4f, R: %3.4f, F1: %0.4f" % (stats['macro_precision'], stats['macro_recall'], stats['macro_f1']))
    drnn.checkpoint()

    batch_size = 50
    num_steps = len(train['labels']) // batch_size
    num_epochs = 5
    display_mod = 10
    valid_mod = 50



    print(num_steps)

    start = time()
    for class_epoch in range(3):
    #     class_batch = DH.classification_batch(batch_size, train['sdps'], train['targets'], train['labels'], offset=0)
    #     random.shuffle(class_batch)

        for class_step in range(10): # num_steps
            inputs, targets, labels, lens = DH.classification_batch(batch_size, train['sdps'], train['targets'], train['labels'], offset=class_step)
            class_batch = zip(inputs, targets, labels, lens)
            random.shuffle(class_batch)
            class_batch = zip(*class_batch)
            xent = drnn.partial_class_fit(*class_batch)
            if step % display_mod == 0:   
                m,s = divmod(time()-start, 60)
                h,m = divmod(m, 60)
                print("(%i:%i:%i) s %i/%i, e %i avg class xent loss = %0.4f" % (h,m,s, class_step, num_steps, class_epoch, xent))
            if step % valid_mod == 0:
                valid_batch = DH.classification_batch(len(valid['labels']), valid['sdps'], valid['targets'], valid['labels'])
                valid_xent = drnn.validation_class_loss(*valid_batch)
                m,s = divmod(time()-start, 60)
                h,m = divmod(m, 60)
                print("="*80)
                print("(%i:%i:%i) s %i/%i, e %i validation avg class xent loss = %0.4f" % (h,m,s, class_step, num_steps, class_epoch, valid_xent))
                print("="*80)
    #             print("Saving model...")
    #             drnn.checkpoint()
        label_set = set(train['labels'])
        preds, dists = drnn.predict(valid_batch[0], valid_batch[1], valid_batch[3], return_probs=True)
        cm, stats = confusion_matrix(preds, valid['labels'], label_set)
        print("Macro P: %2.4f, R: %3.4f, F1: %0.4f" % (stats['macro_precision'], stats['macro_recall'], stats['macro_f1']))
    drnn.checkpoint()
    print("Done")
# Out:
# (0:0:3) step 0/143, epoch 0 Training Loss = 2.05785 :: 1048.321 phrases/sec :: (0:2:53) hours left
# ================================================================================
# Top 20 closest phrases to <net> '<X> enables <Y>' <fisherman>
# 0: 1.000 : <net> '<X> enables <Y>' <fisherman>
# 1: 0.973 : <assembly> '<X> composed <Y>' <statement>
# 2: 0.973 : <demonstrators> '<X> composed <Y>' <figure>
# 3: 0.971 : <decrease> '<X> with <Y>' <control>
# 4: 0.971 : <plowing> '<X> with <Y>' <plow>
# 5: 0.971 : <fish> '<X> with <Y>' <lungs>
# 6: 0.971 : <purse> '<X> with <Y>' <money>
# 7: 0.971 : <bottle> '<X> with <Y>' <wine>
# 8: 0.971 : <bottle> '<X> with <Y>' <water>
# 9: 0.971 : <blouse> '<X> with <Y>' <sleeves>
# 10: 0.971 : <purse> '<X> with <Y>' <money>
# 11: 0.971 : <satellite> '<X> with <Y>' <rotors>
# 12: 0.968 : <worker> '<X> using <Y>' <hammer>
# 13: 0.967 : <enzyme> '<X> builds <Y>' <strawberries>
# 14: 0.965 : <play> '<X> reflects <Y>' <questions>
# 15: 0.965 : <frame> '<X> fits <Y>' <photographs>
# 16: 0.964 : <hobo> '<X> leaves <Y>' <morning>
# 17: 0.963 : <asterisk> '<X> denotes <Y>' <observation>
# 18: 0.963 : <crowd> '<X> radiated <Y>' <optimism>
# 19: 0.963 : <report> '<X> by <Y>' <arm>
# ================================================================================
# Validation loss: 1.0330
# (0:0:34) step 10/143, epoch 0 Training Loss = 1.79500 :: 662.914 phrases/sec :: (0:4:7) hours left
# (0:1:3) step 20/143, epoch 0 Training Loss = 0.80334 :: 658.897 phrases/sec :: (0:3:40) hours left
# (0:1:35) step 30/143, epoch 0 Training Loss = 0.78647 :: 632.015 phrases/sec :: (0:3:20) hours left
# (0:2:8) step 40/143, epoch 0 Training Loss = 0.72080 :: 607.634 phrases/sec :: (0:2:59) hours left
# (0:2:39) step 50/143, epoch 0 Training Loss = 0.70905 :: 606.424 phrases/sec :: (0:2:29) hours left
# ================================================================================
# Top 20 closest phrases to <reboot> '<X> produced <Y>' <message>
# 0: 1.000 : <reboot> '<X> produced <Y>' <message>
# 1: 0.877 : <rennet> '<X> produced by <Y>' <animals>
# 2: 0.877 : <steam> '<X> produced by <Y>' <heat>
# 3: 0.863 : <president> '<X> used <Y>' <pretext>
# 4: 0.852 : <oil> '<X> produced from <Y>' <reservoirs>
# 5: 0.838 : <method> '<X> used <Y>' <mathematicians>
# 6: 0.815 : <cigarettes> '<X> used by <Y>' <women>
# 7: 0.801 : <companies> '<X> used by <Y>' <governments>
# 8: 0.791 : <electricity> '<X> used for <Y>' <operations>
# 9: 0.791 : <chemicals> '<X> used for <Y>' <reclamation>
# 10: 0.784 : <sculptor> '<X> makes <Y>' <deal>
# 11: 0.784 : <prisoner> '<X> released into <Y>' <family>
# 12: 0.776 : <coat> '<X> evolved from <Y>' <cassock>
# 13: 0.774 : <birds> '<X> flown into <Y>' <subway>
# 14: 0.770 : <beakers> '<X> pouring into <Y>' <formula>
# 15: 0.770 : <consignment> '<X> brought into <Y>' <port>
# 16: 0.769 : <citizens> '<X> farmed for <Y>' <living>
# 17: 0.768 : <book> '<X> placed into <Y>' <store>
# 18: 0.768 : <child> '<X> placed into <Y>' <care>
# 19: 0.766 : <famine> '<X> used following <Y>' <feast>
# ================================================================================
# Validation loss: 0.8876
# (0:3:11) step 60/143, epoch 0 Training Loss = 0.71303 :: 603.069 phrases/sec :: (0:1:57) hours left
# (0:3:42) step 70/143, epoch 0 Training Loss = 0.68527 :: 608.034 phrases/sec :: (0:1:24) hours left
# (0:4:12) step 80/143, epoch 0 Training Loss = 0.68797 :: 611.567 phrases/sec :: (0:0:53) hours left
# (0:4:43) step 90/143, epoch 0 Training Loss = 0.67446 :: 609.678 phrases/sec :: (0:0:22) hours left
# (0:5:15) step 100/143, epoch 0 Training Loss = 0.66674 :: 607.624 phrases/sec :: (-1:59:51) hours left
# ================================================================================
# Top 20 closest phrases to <clip> '<X> using on back of <Y>' <alarm>
# 0: 1.000 : <clip> '<X> using on back of <Y>' <alarm>
# 1: 0.902 : <cleats> '<X> located on side of <Y>' <boat>
# 2: 0.894 : <speeches> '<X> were on subject of <Y>' <relationship>
# 3: 0.889 : <robot> '<X> reached using number of <Y>' <states>
# 4: 0.886 : <preview> '<X> below highlights some of <Y>' <features>
# 5: 0.877 : <girl> '<X> came out of <Y>' <closet>
# 6: 0.858 : <photo> '<X> took out of <Y>' <window>
# 7: 0.840 : <patterns> '<X> derived from variety of <Y>' <textiles>
# 8: 0.838 : <agency> '<X> provides third of <Y>' <supply>
# 9: 0.836 : <knobs> '<X> popped out of <Y>' <slots>
# 10: 0.835 : <police> '<X> rebuilt out of <Y>' <mud>
# 11: 0.828 : <molecules> '<X> at site of <Y>' <synapse>
# 12: 0.822 : <music> '<X> was part of <Y>' <culture>
# 13: 0.819 : <songs> '<X> of several in reflected on <Y>' <identity>
# 14: 0.815 : <relationship> '<X> is subject of <Y>' <controversy>
# 15: 0.815 : <books> '<X> on topic of <Y>' <knitting>
# 16: 0.811 : <owner> '<X> installed nuts with dab of <Y>' <grease>
# 17: 0.810 : <hitting> '<X> out of <Y>' <anger>
# 18: 0.810 : <incidents> '<X> related in succession of <Y>' <books>
# 19: 0.809 : <estate> '<X> builds out of <Y>' <downturn>
# ================================================================================
# Validation loss: 0.8875
# (0:5:46) step 110/143, epoch 0 Training Loss = 0.67461 :: 609.899 phrases/sec :: (-1:59:19) hours left
# (0:6:16) step 120/143, epoch 0 Training Loss = 0.68988 :: 610.508 phrases/sec :: (-1:58:49) hours left
# (0:6:46) step 130/143, epoch 0 Training Loss = 0.68141 :: 612.312 phrases/sec :: (-1:58:19) hours left
# (0:7:19) step 140/143, epoch 0 Training Loss = 0.67922 :: 608.759 phrases/sec :: (-1:57:47) hours left
# Macro P: 0.0559, R: 0.1051, F1: 0.0730
# 142
# Macro P: 0.1152, R: 0.0833, F1: 0.0967
# Macro P: 0.1288, R: 0.0937, F1: 0.1085
# Macro P: 0.1718, R: 0.1612, F1: 0.1664
# Done
# (0:0:2) step 0/143, epoch 0 Training Loss = 2.97345 :: 1309.383 phrases/sec :: (0:2:19) hours left
# ================================================================================
# Top 20 closest phrases to <insomnia> '<X> caused by <Y>' <depression>
# 0: 1.000 : <insomnia> '<X> caused by <Y>' <depression>
# 1: 1.000 : <loss> '<X> caused by <Y>' <quake>
# 2: 1.000 : <steam> '<X> produced by <Y>' <heat>
# 3: 0.994 : <fever> '<X> triggered by <Y>' <vaccine>
# 4: 0.992 : <rennet> '<X> produced by <Y>' <animals>
# 5: 0.988 : <problem> '<X> caused by <Y>' <state>
# 6: 0.988 : <losses> '<X> caused by <Y>' <earthquake>
# 7: 0.988 : <mania> '<X> caused by <Y>' <influx>
# 8: 0.988 : <frustration> '<X> caused by <Y>' <system>
# 9: 0.988 : <insecurity> '<X> caused by <Y>' <war>
# 10: 0.987 : <spill> '<X> caused by <Y>' <collision>
# 11: 0.987 : <damage> '<X> caused by <Y>' <crisis>
# 12: 0.987 : <threat> '<X> caused by <Y>' <spell>
# 13: 0.987 : <damage> '<X> caused by <Y>' <destruction>
# 14: 0.987 : <calamities> '<X> caused by <Y>' <subversion>
# 15: 0.987 : <disease> '<X> caused by <Y>' <organism>
# 16: 0.987 : <confusion> '<X> caused by <Y>' <coup>
# 17: 0.985 : <meningitis> '<X> caused by <Y>' <bacteria>
# 18: 0.985 : <splints> '<X> caused by <Y>' <muscles>
# 19: 0.985 : <burst> '<X> caused by <Y>' <pressure>
# ================================================================================
# Validation loss: 1.5295
# (0:0:35) step 10/143, epoch 0 Training Loss = 2.36900 :: 599.913 phrases/sec :: (0:4:36) hours left
# (0:1:5) step 20/143, epoch 0 Training Loss = 2.91358 :: 582.277 phrases/sec :: (0:4:15) hours left
# (0:1:37) step 30/143, epoch 0 Training Loss = 2.56858 :: 569.302 phrases/sec :: (0:3:50) hours left
# (0:2:6) step 40/143, epoch 0 Training Loss = 2.91050 :: 576.179 phrases/sec :: (0:3:18) hours left
# (0:2:37) step 50/143, epoch 0 Training Loss = 2.33740 :: 571.048 phrases/sec :: (0:2:49) hours left
# ================================================================================
# Top 20 closest phrases to <player> '<X> played with <Y>' <smile>
# 0: 1.000 : <player> '<X> played with <Y>' <smile>
# 1: 1.000 : <machine> '<X> has with <Y>' <button>
# 2: 0.999 : <farmers> '<X> negotiated with <Y>' <market>
# 3: 0.998 : <band> '<X> explained decision with <Y>' <statement>
# 4: 0.998 : <tier> '<X> made with <Y>' <towels>
# 5: 0.998 : <santur> '<X> made with <Y>' <bark>
# 6: 0.998 : <side> '<X> indicated with <Y>' <light>
# 7: 0.998 : <parents> '<X> killed with <Y>' <pills>
# 8: 0.997 : <photographer> '<X> took with <Y>' <filter>
# 9: 0.997 : <programme> '<X> began with speech <Y>' <welcome>
# 10: 0.997 : <policeman> '<X> hit with <Y>' <truncheon>
# 11: 0.996 : <diner> '<X> relaxes with <Y>' <delight>
# 12: 0.995 : <missis> '<X> won with <Y>' <ticket>
# 13: 0.995 : <user> '<X> machined wrenches with <Y>' <broach>
# 14: 0.994 : <man> '<X> sent with <Y>' <chisel>
# 15: 0.993 : <ascent> '<X> making with <Y>' <backpack>
# 16: 0.993 : <builder> '<X> targeted with <Y>' <product>
# 17: 0.993 : <user> '<X> accesses menu with <Y>' <keyboard>
# 18: 0.993 : <boy> '<X> left fighting with <Y>' <stick>
# 19: 0.992 : <violin> '<X> is instrument with <Y>' <strings>
# ================================================================================
# Validation loss: 1.5927
# (0:3:8) step 60/143, epoch 0 Training Loss = 2.33055 :: 567.907 phrases/sec :: (0:2:19) hours left
# (0:3:39) step 70/143, epoch 0 Training Loss = 2.45145 :: 567.725 phrases/sec :: (0:1:49) hours left
# (0:4:5) step 80/143, epoch 0 Training Loss = 2.20366 :: 577.380 phrases/sec :: (0:1:17) hours left
# (0:4:34) step 90/143, epoch 0 Training Loss = 1.94305 :: 580.051 phrases/sec :: (0:0:47) hours left
# (0:5:1) step 100/143, epoch 0 Training Loss = 2.89937 :: 583.753 phrases/sec :: (0:0:18) hours left
# ================================================================================
# Top 20 closest phrases to <difficulties> '<X> stemmed from <Y>' <structure>
# 0: 1.000 : <talent> '<X> stemmed from <Y>' <teaching>
# 1: 1.000 : <interest> '<X> stemmed from <Y>' <internship>
# 2: 1.000 : <difficulties> '<X> stemmed from <Y>' <structure>
# 3: 0.999 : <convention> '<X> covered <Y>' <kidnapping>
# 4: 0.999 : <star> '<X> blinded from <Y>' <insight>
# 5: 0.999 : <company> '<X> issued <Y>' <statement>
# 6: 0.999 : <scene> '<X> shows <Y>' <meeting>
# 7: 0.999 : <notes> '<X> survey <Y>' <state>
# 8: 0.999 : <play> '<X> reflects <Y>' <questions>
# 9: 0.999 : <soybean> '<X> meeting <Y>' <oil>
# 10: 0.998 : <discussion> '<X> ensued from <Y>' <contingent>
# 11: 0.998 : <router> '<X> manipulates <Y>' <information>
# 12: 0.998 : <player> '<X> manipulates <Y>' <keyboard>
# 13: 0.998 : <science> '<X> fiction <Y>' <novel>
# 14: 0.998 : <grandmother> '<X> applied <Y>' <poultice>
# 15: 0.998 : <hobo> '<X> leaves <Y>' <morning>
# 16: 0.998 : <equipment> '<X> adopts <Y>' <engine>
# 17: 0.998 : <princess> '<X> married descended from <Y>' <family>
# 18: 0.998 : <manager> '<X> saw fire <Y>' <male>
# 19: 0.998 : <crowd> '<X> radiated <Y>' <optimism>
# ================================================================================
# Validation loss: 1.6420
# (0:5:30) step 110/143, epoch 0 Training Loss = 2.26203 :: 586.986 phrases/sec :: (-1:59:47) hours left
# (0:5:58) step 120/143, epoch 0 Training Loss = 2.10824 :: 588.222 phrases/sec :: (-1:59:18) hours left
# (0:6:26) step 130/143, epoch 0 Training Loss = 1.96509 :: 591.882 phrases/sec :: (-1:58:49) hours left
# (0:6:54) step 140/143, epoch 0 Training Loss = 1.64659 :: 592.691 phrases/sec :: (-1:58:20) hours left
# Macro P: 0.1661, R: 0.1861, F1: 0.1755
# 142
# Macro P: 0.2013, R: 0.1838, F1: 0.1922
# Macro P: 0.2271, R: 0.1525, F1: 0.1825
# Macro P: 0.2436, R: 0.1975, F1: 0.2182
# Done
# (0:0:2) step 0/143, epoch 0 Training Loss = 3.38820 :: 1275.501 phrases/sec :: (0:2:23) hours left
# ================================================================================
# Top 20 closest phrases to <pollen> '<X> derived from <Y>' <forest>
# 0: 1.000 : <pollen> '<X> derived from <Y>' <forest>
# 1: 1.000 : <name> '<X> derived from <Y>' <word>
# 2: 0.999 : <term> '<X> originates from <Y>' <article>
# 3: 0.999 : <energy> '<X> originates from <Y>' <source>
# 4: 0.998 : <food> '<X> made from <Y>' <scratch>
# 5: 0.998 : <flood> '<X> arrives from <Y>' <reaches>
# 6: 0.997 : <court> '<X> started from <Y>' <assumption>
# 7: 0.997 : <cyclotron> '<X> started from <Y>' <beginning>
# 8: 0.996 : <ministers> '<X> went away from <Y>' <conference>
# 9: 0.994 : <act> '<X> includes everything from <Y>' <oldies>
# 10: 0.992 : <present> '<X> constructed from <Y>' <past>
# 11: 0.991 : <satisfaction> '<X> gained from <Y>' <feelings>
# 12: 0.990 : <vocals> '<X> are from <Y>' <female>
# 13: 0.990 : <streaks> '<X> are from <Y>' <truck>
# 14: 0.987 : <man> '<X> ran away from <Y>' <beach>
# 15: 0.984 : <headache> '<X> get from <Y>' <wine>
# 16: 0.984 : <plane> '<X> took from <Y>' <runway>
# 17: 0.982 : <discussion> '<X> ensued from <Y>' <contingent>
# 18: 0.981 : <cricketers> '<X> eluded from <Y>' <team>
# 19: 0.981 : <plane> '<X> taxies from <Y>' <runway>
# ================================================================================
# Validation loss: 2.0496
# (0:0:31) step 10/143, epoch 0 Training Loss = 3.43312 :: 675.000 phrases/sec :: (0:4:5) hours left
# (0:1:9) step 20/143, epoch 0 Training Loss = 5.76625 :: 540.758 phrases/sec :: (0:4:35) hours left
# (0:1:54) step 30/143, epoch 0 Training Loss = 3.82068 :: 468.355 phrases/sec :: (0:4:43) hours left
# (0:2:35) step 40/143, epoch 0 Training Loss = 5.86730 :: 455.416 phrases/sec :: (0:4:14) hours left
# (0:3:15) step 50/143, epoch 0 Training Loss = 3.01671 :: 448.598 phrases/sec :: (0:3:40) hours left
# ================================================================================
# Top 20 closest phrases to <barren> '<X> of <Y>' <mules>
# 0: 1.000 : <corps> '<X> of <Y>' <engineers>
# 1: 1.000 : <litter> '<X> of <Y>' <pups>
# 2: 1.000 : <covey> '<X> of <Y>' <quail>
# 3: 1.000 : <horde> '<X> of <Y>' <heroes>
# 4: 1.000 : <battery> '<X> of <Y>' <measures>
# 5: 1.000 : <pod> '<X> of <Y>' <seals>
# 6: 1.000 : <barren> '<X> of <Y>' <mules>
# 7: 1.000 : <stable> '<X> of <Y>' <horses>
# 8: 1.000 : <padlock> '<X> of <Y>' <cage>
# 9: 1.000 : <arm> '<X> of <Y>' <veterinarian>
# 10: 1.000 : <glut> '<X> of <Y>' <savings>
# 11: 1.000 : <litter> '<X> of <Y>' <kittens>
# 12: 1.000 : <bed> '<X> of <Y>' <clams>
# 13: 1.000 : <facade> '<X> of <Y>' <building>
# 14: 1.000 : <bank> '<X> of <Y>' <monitors>
# 15: 1.000 : <phalanx> '<X> of <Y>' <artists>
# 16: 1.000 : <constellation> '<X> of <Y>' <points>
# 17: 1.000 : <yoke> '<X> of <Y>' <oxen>
# 18: 1.000 : <roots> '<X> of <Y>' <teeth>
# 19: 1.000 : <lobes> '<X> of <Y>' <brain>
# ================================================================================
# Validation loss: 2.5461
# (0:3:59) step 60/143, epoch 0 Training Loss = 3.54708 :: 439.200 phrases/sec :: (0:3:5) hours left
# (0:4:39) step 70/143, epoch 0 Training Loss = 2.86399 :: 436.806 phrases/sec :: (0:2:27) hours left
# (0:5:22) step 80/143, epoch 0 Training Loss = 3.80210 :: 430.703 phrases/sec :: (0:1:50) hours left
# (0:6:3) step 90/143, epoch 0 Training Loss = 3.59016 :: 428.497 phrases/sec :: (0:1:11) hours left
# (0:6:47) step 100/143, epoch 0 Training Loss = 3.22465 :: 423.340 phrases/sec :: (0:0:32) hours left
# ================================================================================
# Top 20 closest phrases to <room> '<X> contains <Y>' <remains>
# 0: 1.000 : <room> '<X> contains <Y>' <remains>
# 1: 0.999 : <memorandum> '<X> outlined <Y>' <changes>
# 2: 0.999 : <bondholders> '<X> drafted <Y>' <plan>
# 3: 0.998 : <boy> '<X> made <Y>' <threat>
# 4: 0.997 : <company> '<X> making soaps <Y>' <perfumes>
# 5: 0.995 : <people> '<X> create <Y>' <designs>
# 6: 0.995 : <songwriter> '<X> is someone writes <Y>' <lyrics>
# 7: 0.993 : <room> '<X> contains table <Y>' <billiard>
# 8: 0.992 : <manager> '<X> uses <Y>' <resources>
# 9: 0.990 : <club> '<X> made seasons <Y>' <playoffs>
# 10: 0.989 : <wife> '<X> prepared eggs <Y>' <coffee>
# 11: 0.989 : <collections> '<X> illustrate history <Y>' <natural>
# 12: 0.989 : <tsunami> '<X> for minutes took cause <Y>' <havoc>
# 13: 0.989 : <scientists> '<X> made batteries <Y>' <supercapacitors>
# 14: 0.989 : <book> '<X> of theme is <Y>' <development>
# 15: 0.988 : <lodge> '<X> combines atmosphere <Y>' <colonial>
# 16: 0.988 : <building> '<X> contained facilities <Y>' <laboratory>
# 17: 0.988 : <winds> '<X> caused delays <Y>' <cancellations>
# 18: 0.988 : <wallet> '<X> contained license <Y>' <passport>
# 19: 0.988 : <building> '<X> contained school <Y>' <grammar>
# ================================================================================
# Validation loss: 2.2800
# (0:7:31) step 110/143, epoch 0 Training Loss = 4.03291 :: 421.689 phrases/sec :: (-1:59:50) hours left
# (0:8:15) step 120/143, epoch 0 Training Loss = 3.10256 :: 418.063 phrases/sec :: (-1:59:10) hours left
# (0:8:58) step 130/143, epoch 0 Training Loss = 4.04616 :: 415.736 phrases/sec :: (-1:58:29) hours left
# (0:9:42) step 140/143, epoch 0 Training Loss = 3.70730 :: 413.627 phrases/sec :: (-1:57:48) hours left
# Macro P: 0.2128, R: 0.2412, F1: 0.2261
# 142
# Macro P: 0.2181, R: 0.1805, F1: 0.1975
# Macro P: 0.2294, R: 0.2223, F1: 0.2258
# Macro P: 0.2269, R: 0.2108, F1: 0.2185
# Done
# (0:0:4) step 0/143, epoch 0 Training Loss = 5.57272 :: 827.689 phrases/sec :: (0:3:40) hours left
# ================================================================================
# Top 20 closest phrases to <horseshoes> '<X> was part of life of <Y>' <blacksmith>
# 0: 1.000 : <horseshoes> '<X> was part of life of <Y>' <blacksmith>
# 1: 0.957 : <music> '<X> was part of <Y>' <culture>
# 2: 0.955 : <cortex> '<X> composed of sheet of <Y>' <neurons>
# 3: 0.953 : <molecules> '<X> at site of <Y>' <synapse>
# 4: 0.950 : <tract> '<X> contains description of <Y>' <method>
# 5: 0.945 : <mews> '<X> hounds of <Y>' <hawks>
# 6: 0.944 : <agency> '<X> provides third of <Y>' <supply>
# 7: 0.944 : <books> '<X> on topic of <Y>' <knitting>
# 8: 0.943 : <vapor> '<X> of most evaporated from surface of <Y>' <oceans>
# 9: 0.943 : <cleats> '<X> located on side of <Y>' <boat>
# 10: 0.941 : <driver> '<X> seat of <Y>' <car>
# 11: 0.939 : <factory> '<X> produced versions of <Y>' <minibuses>
# 12: 0.937 : <users> '<X> experience of <Y>' <software>
# 13: 0.937 : <speeches> '<X> were on subject of <Y>' <relationship>
# 14: 0.935 : <dashboard> '<X> area of <Y>' <car>
# 15: 0.934 : <preview> '<X> below highlights some of <Y>' <features>
# 16: 0.934 : <company> '<X> builds many of <Y>' <machines>
# 17: 0.933 : <refugee> '<X> on run from <Y>' <nation>
# 18: 0.931 : <train> '<X> for departure from <Y>' <station>
# 19: 0.931 : <patterns> '<X> derived from variety of <Y>' <textiles>
# ================================================================================
# Validation loss: 3.3245
# (0:0:49) step 10/143, epoch 0 Training Loss = 7.16848 :: 418.011 phrases/sec :: (0:6:36) hours left
# (0:1:30) step 20/143, epoch 0 Training Loss = 9.75696 :: 426.039 phrases/sec :: (0:5:48) hours left
# (0:2:14) step 30/143, epoch 0 Training Loss = 7.30822 :: 410.460 phrases/sec :: (0:5:20) hours left
# (0:2:57) step 40/143, epoch 0 Training Loss = 5.79132 :: 407.616 phrases/sec :: (0:4:39) hours left
# (0:3:41) step 50/143, epoch 0 Training Loss = 8.23594 :: 406.604 phrases/sec :: (0:3:58) hours left
# ================================================================================
# Top 20 closest phrases to <argument> '<X> is from <Y>' <source>
# 0: 1.000 : <argument> '<X> is from <Y>' <source>
# 1: 1.000 : <stakes> '<X> from <Y>' <perspective>
# 2: 1.000 : <grease> '<X> from <Y>' <soap>
# 3: 1.000 : <damage> '<X> from <Y>' <hurricanes>
# 4: 1.000 : <risk> '<X> from <Y>' <loss>
# 5: 1.000 : <joy> '<X> from <Y>' <dogs>
# 6: 1.000 : <damage> '<X> from <Y>' <spills>
# 7: 1.000 : <suffocation> '<X> from <Y>' <smoke>
# 8: 1.000 : <profits> '<X> from <Y>' <inflation>
# 9: 1.000 : <abstinence> '<X> from <Y>' <laughter>
# 10: 1.000 : <suffering> '<X> from <Y>' <exhaustion>
# 11: 1.000 : <journalist> '<X> from <Y>' <newspaper>
# 12: 1.000 : <headache> '<X> from <Y>' <wine>
# 13: 1.000 : <pollution> '<X> from <Y>' <fuels>
# 14: 1.000 : <dehydration> '<X> from <Y>' <loss>
# 15: 1.000 : <scars> '<X> from <Y>' <stitches>
# 16: 1.000 : <discomfort> '<X> from <Y>' <braces>
# 17: 1.000 : <content> '<X> from <Y>' <encyclopedia>
# 18: 1.000 : <move> '<X> from <Y>' <access>
# 19: 1.000 : <deformation> '<X> from <Y>' <form>
# ================================================================================
# Validation loss: 5.6818
# (0:4:25) step 60/143, epoch 0 Training Loss = 8.70519 :: 405.832 phrases/sec :: (0:3:14) hours left
# (0:5:5) step 70/143, epoch 0 Training Loss = 6.85895 :: 409.482 phrases/sec :: (0:2:30) hours left
# (0:5:46) step 80/143, epoch 0 Training Loss = 9.44069 :: 410.850 phrases/sec :: (0:1:48) hours left
# (0:6:28) step 90/143, epoch 0 Training Loss = 12.78508 :: 411.434 phrases/sec :: (0:1:5) hours left
# (0:7:14) step 100/143, epoch 0 Training Loss = 8.20624 :: 407.688 phrases/sec :: (0:0:23) hours left
# ================================================================================
# Top 20 closest phrases to <damage> '<X> caused by smoke <Y>' <water>
# 0: 1.000 : <damage> '<X> caused by smoke <Y>' <water>
# 1: 0.999 : <darkness> '<X> caused by horrors <Y>' <plague>
# 2: 0.998 : <cancers> '<X> of many caused by exposures <Y>' <radiation>
# 3: 0.997 : <landslides> '<X> caused by earthquakes <Y>' <aftershocks>
# 4: 0.995 : <stings> '<X> caused by midges horseflies bees <Y>' <wasps>
# 5: 0.994 : <plan> '<X> presented by committee <Y>' <study>
# 6: 0.987 : <fever> '<X> triggered by <Y>' <vaccine>
# 7: 0.987 : <demise> '<X> caused by globalization of <Y>' <commerce>
# 8: 0.984 : <tofu> '<X> is food made by coagulating <Y>' <milk>
# 9: 0.981 : <riot> '<X> breaks instigated by <Y>' <silversmiths>
# 10: 0.981 : <wildfires> '<X> of percent caused by <Y>' <humans>
# 11: 0.978 : <monasteries> '<X> founded by <Y>' <river>
# 12: 0.974 : <dust> '<X> noise deprivation produced by <Y>' <construction>
# 13: 0.973 : <restaurant> '<X> advertised by <Y>' <website>
# 14: 0.970 : <island> '<X> discovered by <Y>' <explorer>
# 15: 0.968 : <visit> '<X> made by <Y>' <staff>
# 16: 0.968 : <publication> '<X> supported by <Y>' <grant>
# 17: 0.967 : <volunteer> '<X> sent by <Y>' <organization>
# 18: 0.966 : <book> '<X> requested by <Y>' <editor>
# 19: 0.964 : <deed> '<X> drawn by <Y>' <public>
# ================================================================================
# Validation loss: 5.8636
# (0:7:55) step 110/143, epoch 0 Training Loss = 8.92576 :: 409.979 phrases/sec :: (-1:59:39) hours left
# (0:8:39) step 120/143, epoch 0 Training Loss = 5.80259 :: 407.673 phrases/sec :: (-1:58:58) hours left
# (0:9:24) step 130/143, epoch 0 Training Loss = 10.47348 :: 406.189 phrases/sec :: (-1:58:15) hours left
# (0:10:8) step 140/143, epoch 0 Training Loss = 8.04888 :: 405.495 phrases/sec :: (-1:57:32) hours left
# Macro P: 0.2097, R: 0.2795, F1: 0.2396
# 142
# Macro P: 0.2078, R: 0.2239, F1: 0.2156
# Macro P: 0.2054, R: 0.2616, F1: 0.2301
# Macro P: 0.2262, R: 0.2139, F1: 0.2198
# Done
# (0:0:3) step 0/143, epoch 0 Training Loss = 9.69735 :: 889.377 phrases/sec :: (0:3:25) hours left
# ================================================================================
# Top 20 closest phrases to <items> '<X> transport to <Y>' <home>
# 0: 1.000 : <items> '<X> transport to <Y>' <home>
# 1: 1.000 : <explanation> '<X> added to <Y>' <comments>
# 2: 1.000 : <infection> '<X> spread to <Y>' <people>
# 3: 1.000 : <disease> '<X> spreads to <Y>' <dogs>
# 4: 1.000 : <oxygen> '<X> deliver to <Y>' <cell>
# 5: 1.000 : <grains> '<X> exports to <Y>' <countries>
# 6: 1.000 : <reports> '<X> subjected to <Y>' <examination>
# 7: 1.000 : <cargo> '<X> shipped to <Y>' <factory>
# 8: 1.000 : <information> '<X> leaked to <Y>' <public>
# 9: 1.000 : <emails> '<X> leaked to <Y>' <broadcasting>
# 10: 1.000 : <wafers> '<X> shipped to <Y>' <sites>
# 11: 1.000 : <magnet> '<X> delivered to <Y>' <facility>
# 12: 1.000 : <line> '<X> refers to <Y>' <data>
# 13: 1.000 : <tutorial> '<X> introduced to <Y>' <methods>
# 14: 1.000 : <awards> '<X> bestowed to <Y>' <individuals>
# 15: 1.000 : <snow> '<X> lead to <Y>' <spill>
# 16: 0.999 : <chapter> '<X> devoted to <Y>' <architecture>
# 17: 0.999 : <speech> '<X> devoted to <Y>' <affairs>
# 18: 0.999 : <publication> '<X> has connection to <Y>' <project>
# 19: 0.999 : <interschool> '<X> rescheduled to <Y>' <week>
# ================================================================================
# Validation loss: 4.3839
# (0:0:48) step 10/143, epoch 0 Training Loss = 9.96310 :: 422.953 phrases/sec :: (0:6:32) hours left
# (0:1:32) step 20/143, epoch 0 Training Loss = 12.57292 :: 408.103 phrases/sec :: (0:6:5) hours left
# (0:2:14) step 30/143, epoch 0 Training Loss = 9.36069 :: 409.403 phrases/sec :: (0:5:21) hours left
# (0:2:57) step 40/143, epoch 0 Training Loss = 13.05665 :: 406.194 phrases/sec :: (0:4:42) hours left
# (0:3:38) step 50/143, epoch 0 Training Loss = 12.06468 :: 408.710 phrases/sec :: (0:3:58) hours left
# ================================================================================
# Top 20 closest phrases to <pie> '<X> served caused <Y>' <poisoning>
# 0: 1.000 : <pie> '<X> served caused <Y>' <poisoning>
# 1: 1.000 : <scientists> '<X> sliced <Y>' <brain>
# 2: 1.000 : <players> '<X> flew on <Y>' <plane>
# 3: 1.000 : <terrorist> '<X> planted <Y>' <bomb>
# 4: 1.000 : <convention> '<X> covered <Y>' <kidnapping>
# 5: 1.000 : <marmalade> '<X> made of <Y>' <oranges>
# 6: 1.000 : <programmer> '<X> made <Y>' <mistake>
# 7: 1.000 : <party> '<X> made <Y>' <crazies>
# 8: 1.000 : <leader> '<X> made <Y>' <comments>
# 9: 1.000 : <president> '<X> made <Y>' <taxes>
# 10: 1.000 : <firm> '<X> assembled <Y>' <team>
# 11: 1.000 : <committee> '<X> developed <Y>' <protocol>
# 12: 1.000 : <artist> '<X> listed <Y>' <song>
# 13: 1.000 : <users> '<X> experience of <Y>' <software>
# 14: 1.000 : <images> '<X> show <Y>' <group>
# 15: 1.000 : <grammars> '<X> generate <Y>' <languages>
# 16: 1.000 : <clause> '<X> tells of <Y>' <pension>
# 17: 1.000 : <assemblies> '<X> used for cutting <Y>' <strips>
# 18: 1.000 : <movie> '<X> received <Y>' <review>
# 19: 0.999 : <draft> '<X> declared <Y>' <borders>
# ================================================================================
# Validation loss: 5.0361
# (0:4:23) step 60/143, epoch 0 Training Loss = 10.94642 :: 408.304 phrases/sec :: (0:3:14) hours left
# (0:5:6) step 70/143, epoch 0 Training Loss = 9.93992 :: 405.767 phrases/sec :: (0:2:33) hours left
# (0:5:48) step 80/143, epoch 0 Training Loss = 7.90440 :: 407.721 phrases/sec :: (0:1:49) hours left
# (0:6:31) step 90/143, epoch 0 Training Loss = 8.38901 :: 408.589 phrases/sec :: (0:1:5) hours left
# (0:7:14) step 100/143, epoch 0 Training Loss = 8.29983 :: 407.930 phrases/sec :: (0:0:23) hours left
# ================================================================================
# Top 20 closest phrases to <chair> '<X> leg being carried in bag <Y>' <plastic>
# 0: 1.000 : <chair> '<X> leg being carried in bag <Y>' <plastic>
# 1: 0.999 : <ferrets> '<X> in show <Y>' <sack>
# 2: 0.999 : <golden> '<X> retriever was in <Y>' <crate>
# 3: 0.999 : <involvement> '<X> participation in governance <Y>' <the>
# 4: 0.999 : <offer> '<X> in call <Y>' <phone>
# 5: 0.999 : <body> '<X> was in freezer <Y>' <chest>
# 6: 0.999 : <ingredients> '<X> of many in <Y>' <basket>
# 7: 0.999 : <revelation> '<X> made in call <Y>' <phone>
# 8: 0.999 : <data> '<X> of some presented in read <Y>' <paper>
# 9: 0.999 : <the> '<X> world got in jug <Y>' <a>
# 10: 0.998 : <songs> '<X> of several in reflected on <Y>' <identity>
# 11: 0.998 : <picric> '<X> acid kept in solution <Y>' <aqueous>
# 12: 0.998 : <e> '<X> mail in referred <Y>' <manager>
# 13: 0.998 : <nitric> '<X> oxide contained in cylinder plated <Y>' <gold>
# 14: 0.998 : <incidents> '<X> related in succession of <Y>' <books>
# 15: 0.998 : <combustion> '<X> for technique in <Y>' <flask>
# 16: 0.998 : <individual> '<X> is participant in unconscious <Y>' <collective>
# 17: 0.997 : <cleaner> '<X> was in <Y>' <cistern>
# 18: 0.997 : <torso> '<X> was in <Y>' <suitcase>
# 19: 0.996 : <mah> '<X> jongg set was in <Y>' <trunk>
# ================================================================================
# Validation loss: 4.5851
# (0:7:59) step 110/143, epoch 0 Training Loss = 6.93078 :: 406.387 phrases/sec :: (-1:59:39) hours left
# (0:8:41) step 120/143, epoch 0 Training Loss = 9.57461 :: 407.471 phrases/sec :: (-1:58:56) hours left
# (0:9:26) step 130/143, epoch 0 Training Loss = 7.17837 :: 405.313 phrases/sec :: (-1:58:14) hours left
# (0:10:6) step 140/143, epoch 0 Training Loss = 7.86422 :: 407.171 phrases/sec :: (-1:57:31) hours left
# Macro P: 0.1950, R: 0.2762, F1: 0.2286
# 142
# Macro P: 0.2168, R: 0.2140, F1: 0.2154
# Macro P: 0.2059, R: 0.1809, F1: 0.1926
# Macro P: 0.2167, R: 0.2322, F1: 0.2242
# Done

# %%
# check out predictions
# valid_batch = DH.classification_batch(len(train['labels']), train['sdps'], train['targets'], train['labels'])

valid_batch = DH.classification_batch(len(valid['labels']), valid['sdps'], valid['targets'], valid['labels'])
preds, dists = drnn.predict(valid_batch[0], valid_batch[1], valid_batch[3], return_probs=True)

# %%
# for i, p in enumerate(preds):
#     print("%i, pred: %s, true: %s" %(i, int2label[p], int2label[valid['labels'][i]]))
#     target = DH.sequence_to_sentence(valid['targets'][i]).split(' ')
#     sdp = DH.sequence_to_sentence(valid['sdps'][i], show_dep=True)
#     print('<%s> "%s" <%s>' % (target[0], sdp, target[1]))
#     print(valid['raws'][i])
#     print(valid['comments'][i])
#     print("="*80)

# %%
def confusion_matrix(preds, labels, label_set):
    size = len(label_set)
    matrix = np.zeros([size, size]) # rows are predictions, columns are truths
    # fill in matrix
    for p, l in zip(preds, labels):
        matrix[p,l] += 1
    # compute class specific scores
    class_precision = np.zeros(size)
    class_recall = np.zeros(size)
    for label in range(size):
        tp = matrix[label, label]
        fp = np.sum(matrix[label, :]) - tp
        fn = np.sum(matrix[:, label]) - tp
        class_precision[label] = tp/float(tp + fp) if tp or fp else 0
        class_recall[label] = tp/float(tp + fn) if tp or fn else 0
    micro_f1 = np.array([2*(p*r)/(p+r) if p or r else 0 for (p, r) in zip(class_precision, class_recall)])
    avg_precision = np.mean(class_precision)
    avg_recall = np.mean(class_recall)
    macro_f1 = (2*avg_precision*avg_recall) / (avg_precision + avg_recall)
    stats = {'micro_precision':class_precision,
             'micro_recall':class_recall, 
             'micro_f1':micro_f1,
             'macro_precision':avg_precision, 
             'macro_recall':avg_recall,
             'macro_f1':macro_f1}
    return matrix, stats
label_set = set(train['labels'])
cm, stats = confusion_matrix(preds, valid['labels'], label_set)
print("Macro F1: %0.4f" % stats['macro_f1'])
# Out:
# Macro F1: 0.1797

# %%
def plot_confusion_matrix(cm, label_names, save_name=None, title='Normed Confusion matrix', cmap=plt.cm.Blues, stats=None):
    fig, ax = plt.subplots(figsize=(20,20))
    
    # calc normalized cm
    x, y = np.meshgrid(range(cm.shape[0]), range(cm.shape[1]))
    cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)
    cm_normalized[np.isnan(cm_normalized)] = 0.0
    
    # print nonzero raw counts
    for x_val, y_val in zip(x.flatten(), y.flatten()):
        norm = cm_normalized[x_val, y_val]
        c = "%i" % (cm.astype('int')[x_val, y_val])
        if norm > 0.0:
            color = 'white' if norm > .5 else 'black'
            ax.text(y_val, x_val, c, va='center', ha='center', color=color)
    
    # actual plot
    im = ax.imshow(cm_normalized, interpolation='nearest', origin='upper', cmap=cmap)
#     divider = plt.make_axes_locatable(ax)
#     cax = divider.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(im, fraction=0.046, pad=0.04)
    
    # set ticks and offset grid
    tick_marks = np.arange(len(label_names))
    tick_marks_offset = np.arange(len(label_names)) - .5
    ax.set_xticks(tick_marks, minor=False)
    ax.set_yticks(tick_marks, minor=False)
    ax.set_xticks(tick_marks_offset, minor=True)
    ax.set_yticks(tick_marks_offset, minor=True)
    ax.grid(which='minor')
    if stats:
        # include micro precisio, recall, and f1
        aug_y_labels = []
        for i in range(len(label_names)):
            aug = ("%s\nP:%0.2f, R:%0.2f, F1:%0.2f" 
                   % (label_names[i],
                      stats['micro_precision'][i],
                      stats['micro_recall'][i],
                      stats['micro_f1'][i],))
            aug_y_labels.append(aug)
    else:
        aug_x_labels = label_names
    ax.set_xticklabels(label_names, rotation=75, horizontalalignment='left', x=1)
    ax.xaxis.tick_top()
    ax.set_yticklabels(aug_y_labels)
    
    # other stuff
    plt.tight_layout()
    plt.ylabel('Predicted Labels', fontsize=16)
    if stats:
        # include macro 
        aug_x_label = ("True Labels\n Macro P:%0.2f, R:%0.2f, F1:%0.2f" 
                       % (stats['macro_precision'], stats['macro_recall'], stats['macro_f1']))
    else:
        aug_x_label = "True Label"
    plt.xlabel(aug_x_label, fontsize=16)
    plt.title(title, y=1.12, fontsize=20)
    if save_name:
        plt.savefig(save_name+'.pdf')
        
save_name = raw_input("Enter save name: ")
plot_confusion_matrix(cm, int2label.values(), save_name=save_name, stats=stats)
# Out:
# Enter save name:
# /Users/thomaseffland/.virtualenvs/rel/lib/python2.7/site-packages/ipykernel/__main__.py:6: RuntimeWarning: invalid value encountered in divide
